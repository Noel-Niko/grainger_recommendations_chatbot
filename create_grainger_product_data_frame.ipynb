# %%
import os
from urllib.parse import urlparse

domain = "https://www.grainger.com"
local_domain = urlparse(domain).netloc
# Create necessary directories if they don't exist
if not os.path.exists("text/"):
    os.mkdir("text/")
if not os.path.exists(f"text/{local_domain}/"):
    os.mkdir(f"text/{local_domain}/")
if not os.path.exists("processed"):
    os.mkdir("processed")

# %%
# import requests
# import json
# 
# 
# # List of part numbers to query
# part_number = "1VCE8"  # Add more part numbers as needed
# 
# # Base URL for the endpoint
# base_url = "https://mobile-rest-qa.nonprod.graingercloud.com/v1/product/detail"
# 
# # File to store the results
# file_path = f"text/{local_domain}/{part_number}.txt"
# 
# # Headers for the request
# headers = {
#     "Content-Type": "application/json"
# }
# 
# # Function to fetch and process data
# def fetch_product_details(part_number):
#     params = {
#         "partNumbers": part_number,
#         "extraInfo": "false"
#     }
#     
#     response = requests.get(base_url, headers=headers, params=params)
#     if response.status_code == 200:
#         data = response.json()[0]  # Assuming the response contains a list with one item
# 
#         brand = data.get("brand", {}).get("name", "N/A")
#         code = data.get("code", "N/A")
#         name = data.get("name", "N/A")
#         picture_url = data.get("pictureUrl600", "N/A")
#         price = data.get("priceData", {}).get("formattedPrice", "N/A")
#         description = data.get("productDetailsDescription", "N/A")
# 
#         return {
#             "Brand": brand,
#             "Code": code,
#             "Name": name,
#             "PictureUrl600": picture_url,
#             "Price": price,
#             "Description": description
#         }
#     else:
#         return None
# 
# # Fetch details for each part number and write to file
# with open(file_path, "w") as file:
#     details = fetch_product_details(part_number)
#     if details:           
#         # file.write(json.dumps(details) + "\n")
#         print(details)
#     else:
#         file.write(f"Failed to fetch details for part number: {part_number}\n")
# 
# print("Product details have been written to", file_path)
# Out:
# {'Brand': 'DAYTON', 'Code': '1VCE8', 'Name': 'DAYTON Standard-Duty Industrial Fan: 24 in Blade Dia, 2 Speeds, 3,850/6,200 cfm, 115 V AC', 'PictureUrl600': 'https://static.grainger.com/rp/s/is/image/Grainger/1VCF3_AS02?$lgmain$', 'Price': '$474.08', 'Description': '<p>Standard-duty industrial fan heads provide cooling in heavy manufacturing areas and other dusty or dirty environments. These fan blade, motor, and guard assemblies can be paired with a new or existing bracket or base.</p>'}
# Product details have been written to text/www.grainger.com/1VCE8.txt

# %%
# TEST 
import re

# Pattern to match product skus/codes
regex_pattern = re.compile(r'[A-Z0-9]{5,7}')
# Test strings
test_strings = [
    "1DKW3_1.pdf",
    "3VE59C-Operating-Instructions-and-Parts-Manual.pdf",
    "_3M-Disposable-Respirator-Dual-4JF99?opr=PDPBRDSP&analytics=dsbrItems_5ZZZ6.txt"
]

# Extract product codes from test strings
for test in test_strings:
    matches = regex_pattern.findall(test)
    print(f"Matches in '{test}': {matches}")
# Out:
# Matches in '1DKW3_1.pdf': ['1DKW3']
# Matches in '3VE59C-Operating-Instructions-and-Parts-Manual.pdf': ['3VE59C']
# Matches in '_3M-Disposable-Respirator-Dual-4JF99?opr=PDPBRDSP&analytics=dsbrItems_5ZZZ6.txt': ['4JF99', 'PDPBRDS', '5ZZZ6']

# %%
# PULL product codes from web scraped data and save as jsin

import os
import re
import json

# Define the regex pattern for product codes
regex_pattern = re.compile(r'[A-Z0-9]{5,7}')

# Directory containing the files
directory = 'GraingerWebScrape/www.grainger.com'

# List to store found product codes
product_codes = []

# Function to extract product codes from text
def extract_product_codes(text):
    return regex_pattern.findall(text)

# Iterate through all files in the directory
for root, dirs, files in os.walk(directory):
    for file in files:
        file_path = os.path.join(root, file)

        # Check for product codes in the file name
        codes_in_filename = extract_product_codes(file)
        product_codes.extend(codes_in_filename)

        # Check for product codes in the file content
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read()
                codes_in_content = extract_product_codes(content)
                product_codes.extend(codes_in_content)
        except Exception as e:
            print(f"Could not read file {file_path}: {e}")

# Remove duplicates by converting the list to a set and back to a list
product_codes = list(set(product_codes))

# Save all product codes to a single JSON file
with open('all_product_codes.json', 'w') as f:
    json.dump(product_codes, f, indent=4)

print(f"Total product codes found: {len(product_codes)}")
print(f"Product codes saved in 'all_product_codes.json'")
# Out:
# Could not read file GraingerWebScrape/www.grainger.com/1DKW3_2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/4NHG9_1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/1DKW3_3.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/1DKW3_1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/4NHG9_2.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/TraumaCube__XE7K_v1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/1106-1600_PI_en_US1__JQ1I.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/3VE59C-Operating-Instructions-and-Parts-Manual.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/QMARK-Radiant-Desk-Heater-Installation-Instructions.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/3PEA8_1.pdf: 'utf-8' codec can't decode byte 0xc7 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/53TY91_1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/55KH88Manual__LFV2_v1.pdf: 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# Could not read file GraingerWebScrape/www.grainger.com/2MY17_1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Could not read file GraingerWebScrape/www.grainger.com/53TY90_1.pdf: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# Total product codes found: 9651
# Product codes saved in 'all_product_codes.json'

# %%
# Fetch product details method
import pandas as pd

# Base URL and headers for the API
base_url = "https://mobile-rest-qa.nonprod.graingercloud.com/v1/product/detail"
headers = {
    "Content-Type": "application/json"
}

# Function to fetch and process data
def fetch_product_details(skus):
    params = {
        "partNumbers": skus,
        "extraInfo": "false"
    }
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()[0]  # Assuming the response contains a list with one item
        brand = data.get("brand", {}).get("name", "N/A")
        code = data.get("code", "N/A")
        name = data.get("name", "N/A")
        picture_url = data.get("pictureUrl600", "N/A")
        price = data.get("priceData", {}).get("formattedPrice", "N/A")
        description = data.get("productDetailsDescription", "N/A")

        return {
            "Brand": brand,
            "Code": code,
            "Name": name,
            "PictureUrl600": picture_url,
            "Price": price,
            "Description": description
        }
    else:
        return None

# %%
# TEST 
import json

# Load the product codes from the JSON file
with open('all_product_codes.json', 'r') as f:
    json.load(f)

# Product codes in chunks of 100
chunk_size = 100
chunks = [product_codes[i:i + chunk_size] for i in range(0, len(product_codes), chunk_size)]

# Iterate over each chunk for API requests
df = pd.DataFrame(columns=["Brand", "Code", "Name", "PictureUrl600", "Price", "Description"])
for chunk in chunks:
    try:
        details = fetch_product_details(chunk)
        df = pd.concat([df, pd.DataFrame([details])], ignore_index=True)
    except Exception as e:
        print(f"Failed to fetch details for chunk: {chunk}")

print("All product details have been processed.")
# Remove rows where all columns are NaN
df = df.dropna(how='all')
# Ensure all column names are strings
df.columns = df.columns.astype(str)
# Save to Parquet
df.to_parquet('processed/grainger_products.parquet', index=False)
print("Product details have been saved to 'processed/grainger_products.parquet'")
print("\nHead of DataFrame:")
print(df.head(), "\n")
print("Tail of DataFrame:")
print(df.tail(), "\n")
print("Size of DataFrame:", df.size, "\n")
print("Values in DataFrame:")
print(df.values)
# Out:
# All product details have been processed.
# Product details have been saved to 'processed/grainger_products.parquet'
#
# Head of DataFrame:
#   Brand    Code                        Name  \
# 0   CRC  20HC15  Window and Display Cleaner
#
#                                        PictureUrl600   Price Description
# 0  https://static.grainger.com/rp/s/is/image/Grai...  $10.20        None
#
# Tail of DataFrame:
#   Brand    Code                        Name  \
# 0   CRC  20HC15  Window and Display Cleaner
#
#                                        PictureUrl600   Price Description
# 0  https://static.grainger.com/rp/s/is/image/Grai...  $10.20        None
#
# Size of DataFrame: 6
#
# Values in DataFrame:
# [['CRC' '20HC15' 'Window and Display Cleaner'
#   'https://static.grainger.com/rp/s/is/image/Grainger/20HC15_AS01?$lgmain$'
#   '$10.20' None]]

# %%
# import requests
# import pandas as pd
# import json
# 
# # Base URL and headers for the API
# base_url = "https://mobile-rest-qa.nonprod.graingercloud.com/v1/product/detail"
# headers = {
#     "Content-Type": "application/json"
# }
# 
# # Function to fetch and process data
# def fetch_product_details(skus):
#     params = {
#         "partNumbers": skus,
#         "extraInfo": "false"
#     }
#     response = requests.get(base_url, headers=headers, params=params)
#     if response.status_code == 200:
#         try:
#             data = response.json()
#             results = []
#             for item in data:
#                 brand = item.get("brand", {}).get("name", "N/A")
#                 code = item.get("code", "N/A")
#                 name = item.get("name", "N/A")
#                 picture_url = item.get("pictureUrl600", "N/A")
#                 price = item.get("priceData", {}).get("formattedPrice", "N/A")
#                 description = item.get("productDetailsDescription", "N/A")
# 
#                 results.append({
#                     "Brand": brand,
#                     "Code": code,
#                     "Name": name,
#                     "PictureUrl600": picture_url,
#                     "Price": price,
#                     "Description": description
#                 })
# 
#             return pd.DataFrame(results) if results else None
#         except Exception as e:
#             print(f"Error parsing response for {skus}: {e}")
#             return None
#     else:
#         print(f"Failed to fetch details for {skus}: Status code {response.status_code}")
#         return None
# 
# # Load the product codes from the JSON file
# with open('all_product_codes.json', 'r') as f:
#     product_codes = json.load(f)
# 
# # For testing, use a smaller subset of product codes
# # product_codes = ["1VCE8", "2KNK4", "20HC15"]
# 
# # Product codes in chunks of 100
# chunk_size = 1
# chunks = [product_codes[i:i + chunk_size] for i in range(0, len(product_codes), chunk_size)]
# 
# # Iterate over each chunk for API requests
# df = pd.DataFrame(columns=["Brand", "Code", "Name", "PictureUrl600", "Price", "Description"])
# for chunk in chunks:
#     try:
#         details = fetch_product_details(chunk)
#         if details is not None:
#             df = pd.concat([df, details], ignore_index=True)
#         else:
#             print(f"No details fetched for chunk: {chunk}. Removing from source.")
#             
#     except Exception as e:
#         print(f"Failed to fetch details for chunk: {chunk}, Error: {e}")
# 
# print("All product details have been processed.")
# 
# # Remove rows where all columns are NaN
# df = df.dropna(how='all')
# 
# # Ensure all column names are strings
# df.columns = df.columns.astype(str)
# 
# # Save to Parquet
# df.to_parquet('processed/grainger_products.parquet', index=False)
# print("Product details have been saved to 'processed/grainger_products.parquet'")
# print("\nHead of DataFrame:")
# print(df.head(), "\n")
# print("Tail of DataFrame:")
# print(df.tail(), "\n")
# print("Size of DataFrame:", df.size, "\n")
# print("Values in DataFrame:")
# print(df.values)
# Out:
# Failed to fetch details for ['182UFW9']: Status code 400
# No details fetched for chunk: ['182UFW9']
# Failed to fetch details for ['04103']: Status code 400
# No details fetched for chunk: ['04103']
# Failed to fetch details for ['97429T7']: Status code 400
# No details fetched for chunk: ['97429T7']
# Failed to fetch details for ['ZEREXH']: Status code 400
# No details fetched for chunk: ['ZEREXH']
# Failed to fetch details for ['ICHELIN']: Status code 400
# No details fetched for chunk: ['ICHELIN']
# Failed to fetch details for ['6391H']: Status code 400
# No details fetched for chunk: ['6391H']
# Failed to fetch details for ['00818HC']: Status code 400
# No details fetched for chunk: ['00818HC']
# Failed to fetch details for ['40R19']: Status code 400
# No details fetched for chunk: ['40R19']
# Failed to fetch details for ['ALTERNA']: Status code 400
# No details fetched for chunk: ['ALTERNA']
# Failed to fetch details for ['FOOTWEA']: Status code 400
# No details fetched for chunk: ['FOOTWEA']
# Failed to fetch details for ['0846C11']: Status code 400
# No details fetched for chunk: ['0846C11']
# Failed to fetch details for ['MERET']: Status code 400
# No details fetched for chunk: ['MERET']
# Failed to fetch details for ['2L18018']: Status code 400
# No details fetched for chunk: ['2L18018']
# Failed to fetch details for ['2813X77']: Status code 400
# No details fetched for chunk: ['2813X77']
# Failed to fetch details for ['10031DL']: Status code 400
# No details fetched for chunk: ['10031DL']
# Failed to fetch details for ['341UKH6']: Status code 400
# No details fetched for chunk: ['341UKH6']
# Failed to fetch details for ['4C13794']: Status code 400
# No details fetched for chunk: ['4C13794']
# Failed to fetch details for ['504YPD1']: Status code 400
# No details fetched for chunk: ['504YPD1']
# Failed to fetch details for ['EM7252E']: Status code 400
# No details fetched for chunk: ['EM7252E']
# Failed to fetch details for ['40KJ09C']: Status code 400
# No details fetched for chunk: ['40KJ09C']
# Failed to fetch details for ['9WX7043']: Status code 400
# No details fetched for chunk: ['9WX7043']
# Failed to fetch details for ['90670']: Status code 400
# No details fetched for chunk: ['90670']
# Failed to fetch details for ['0515F21']: Status code 400
# No details fetched for chunk: ['0515F21']
# Failed to fetch details for ['65R17']: Status code 400
# No details fetched for chunk: ['65R17']
# Failed to fetch details for ['274GB90']: Status code 400
# No details fetched for chunk: ['274GB90']
# Failed to fetch details for ['OVERINE']: Status code 400
# No details fetched for chunk: ['OVERINE']
# Failed to fetch details for ['TC02C']: Status code 400
# No details fetched for chunk: ['TC02C']
# Failed to fetch details for ['173MUE5']: Status code 400
# No details fetched for chunk: ['173MUE5']
# Failed to fetch details for ['8553WN5']: Status code 400
# No details fetched for chunk: ['8553WN5']
# Failed to fetch details for ['2REEBOK']: Status code 400
# No details fetched for chunk: ['2REEBOK']
# Failed to fetch details for ['992TGC7']: Status code 400
# No details fetched for chunk: ['992TGC7']
# Failed to fetch details for ['8G843']: Status code 500
# No details fetched for chunk: ['8G843']
# Failed to fetch details for ['116765']: Status code 400
# No details fetched for chunk: ['116765']
# Failed to fetch details for ['817F52']: Status code 400
# No details fetched for chunk: ['817F52']
# Failed to fetch details for ['116207']: Status code 400
# No details fetched for chunk: ['116207']
# Failed to fetch details for ['39R839L']: Status code 400
# No details fetched for chunk: ['39R839L']
# Failed to fetch details for ['P89135W']: Status code 400
# No details fetched for chunk: ['P89135W']
# Failed to fetch details for ['WOOSTER']: Status code 400
# No details fetched for chunk: ['WOOSTER']
# Failed to fetch details for ['P90439D']: Status code 400
# No details fetched for chunk: ['P90439D']
# Failed to fetch details for ['846KEC3']: Status code 400
# No details fetched for chunk: ['846KEC3']
# Failed to fetch details for ['FS2650C']: Status code 400
# No details fetched for chunk: ['FS2650C']
# Failed to fetch details for ['1029XM5']: Status code 400
# No details fetched for chunk: ['1029XM5']
# Failed to fetch details for ['VA225']: Status code 400
# No details fetched for chunk: ['VA225']
# Failed to fetch details for ['86515TI']: Status code 400
# No details fetched for chunk: ['86515TI']
# Failed to fetch details for ['3A1F297']: Status code 400
# No details fetched for chunk: ['3A1F297']
# Failed to fetch details for ['ASSISTA']: Status code 400
# No details fetched for chunk: ['ASSISTA']
# Failed to fetch details for ['RB4310K']: Status code 400
# No details fetched for chunk: ['RB4310K']
# Failed to fetch details for ['92641KE']: Status code 400
# No details fetched for chunk: ['92641KE']
# Failed to fetch details for ['53531AR']: Status code 400
# No details fetched for chunk: ['53531AR']
# Failed to fetch details for ['43A5954']: Status code 400
# No details fetched for chunk: ['43A5954']
# Failed to fetch details for ['543A706']: Status code 400
# No details fetched for chunk: ['543A706']
# Failed to fetch details for ['246KEA0']: Status code 400
# No details fetched for chunk: ['246KEA0']
# Failed to fetch details for ['1652WH3']: Status code 400
# No details fetched for chunk: ['1652WH3']
# Failed to fetch details for ['46256']: Status code 400
# No details fetched for chunk: ['46256']
# Failed to fetch details for ['404K74M']: Status code 400
# No details fetched for chunk: ['404K74M']
# Failed to fetch details for ['FUNCTIO']: Status code 400
# No details fetched for chunk: ['FUNCTIO']
# Failed to fetch details for ['49430']: Status code 400
# No details fetched for chunk: ['49430']
# Failed to fetch details for ['955EC12']: Status code 400
# No details fetched for chunk: ['955EC12']
# Failed to fetch details for ['355JK37']: Status code 400
# No details fetched for chunk: ['355JK37']
# Failed to fetch details for ['985RXG3']: Status code 400
# No details fetched for chunk: ['985RXG3']
# Failed to fetch details for ['43C0314']: Status code 400
# No details fetched for chunk: ['43C0314']
# Failed to fetch details for ['6804AZ5']: Status code 400
# No details fetched for chunk: ['6804AZ5']
# Failed to fetch details for ['IP54I']: Status code 400
# No details fetched for chunk: ['IP54I']
# Failed to fetch details for ['8044208']: Status code 400
# No details fetched for chunk: ['8044208']
# Failed to fetch details for ['30R20']: Status code 400
# No details fetched for chunk: ['30R20']
# Failed to fetch details for ['6638M50']: Status code 400
# No details fetched for chunk: ['6638M50']
# Failed to fetch details for ['91712M']: Status code 400
# No details fetched for chunk: ['91712M']
# Failed to fetch details for ['1505BB5']: Status code 400
# No details fetched for chunk: ['1505BB5']
# Failed to fetch details for ['43A6034']: Status code 400
# No details fetched for chunk: ['43A6034']
# Failed to fetch details for ['77055W']: Status code 400
# No details fetched for chunk: ['77055W']
# Failed to fetch details for ['EHSLP']: Status code 400
# No details fetched for chunk: ['EHSLP']
# Failed to fetch details for ['83JY32S']: Status code 400
# No details fetched for chunk: ['83JY32S']
# Failed to fetch details for ['SQWINCH']: Status code 400
# No details fetched for chunk: ['SQWINCH']
# Failed to fetch details for ['U53490U']: Status code 400
# No details fetched for chunk: ['U53490U']
# Failed to fetch details for ['LOCKOUT']: Status code 400
# No details fetched for chunk: ['LOCKOUT']
# Failed to fetch details for ['JOHNSON']: Status code 400
# No details fetched for chunk: ['JOHNSON']
# Failed to fetch details for ['1849ZY4']: Status code 400
# No details fetched for chunk: ['1849ZY4']
# Failed to fetch details for ['FALCON']: Status code 400
# No details fetched for chunk: ['FALCON']
# Failed to fetch details for ['2515X10']: Status code 400
# No details fetched for chunk: ['2515X10']
# Failed to fetch details for ['OTHERWI']: Status code 400
# No details fetched for chunk: ['OTHERWI']
# Failed to fetch details for ['W10765R']: Status code 400
# No details fetched for chunk: ['W10765R']
# Failed to fetch details for ['32814']: Status code 400
# No details fetched for chunk: ['32814']
# Failed to fetch details for ['CA7521A']: Status code 400
# No details fetched for chunk: ['CA7521A']
# Failed to fetch details for ['5004KN3']: Status code 400
# No details fetched for chunk: ['5004KN3']
# Failed to fetch details for ['152EM59']: Status code 400
# No details fetched for chunk: ['152EM59']
# Failed to fetch details for ['A60543A']: Status code 400
# No details fetched for chunk: ['A60543A']
# Failed to fetch details for ['23L220M']: Status code 400
# No details fetched for chunk: ['23L220M']
# Failed to fetch details for ['A7751DE']: Status code 400
# No details fetched for chunk: ['A7751DE']
# Failed to fetch details for ['2Z61012']: Status code 400
# No details fetched for chunk: ['2Z61012']
# Failed to fetch details for ['EXTENT']: Status code 400
# No details fetched for chunk: ['EXTENT']
# Failed to fetch details for ['5149YN1']: Status code 400
# No details fetched for chunk: ['5149YN1']
# Failed to fetch details for ['56JH14M']: Status code 400
# No details fetched for chunk: ['56JH14M']
# Failed to fetch details for ['9PAE1']: Status code 500
# No details fetched for chunk: ['9PAE1']
# Failed to fetch details for ['2561UU3']: Status code 400
# No details fetched for chunk: ['2561UU3']
# Failed to fetch details for ['240VI']: Status code 400
# No details fetched for chunk: ['240VI']
# Failed to fetch details for ['V18111C']: Status code 400
# No details fetched for chunk: ['V18111C']
# Failed to fetch details for ['4660YG4']: Status code 400
# No details fetched for chunk: ['4660YG4']
# Failed to fetch details for ['3800W60']: Status code 400
# No details fetched for chunk: ['3800W60']
# Failed to fetch details for ['3360NN2']: Status code 400
# No details fetched for chunk: ['3360NN2']
# Failed to fetch details for ['STANLEY']: Status code 400
# No details fetched for chunk: ['STANLEY']
# Failed to fetch details for ['3A1LSI0']: Status code 400
# No details fetched for chunk: ['3A1LSI0']
# Failed to fetch details for ['68491V6']: Status code 400
# No details fetched for chunk: ['68491V6']
# Failed to fetch details for ['512TGE4']: Status code 400
# No details fetched for chunk: ['512TGE4']
# Failed to fetch details for ['43A6104']: Status code 400
# No details fetched for chunk: ['43A6104']
# Failed to fetch details for ['1PKC7M']: Status code 400
# No details fetched for chunk: ['1PKC7M']
# Failed to fetch details for ['749ZY38']: Status code 400
# No details fetched for chunk: ['749ZY38']
# Failed to fetch details for ['99404K0']: Status code 400
# No details fetched for chunk: ['99404K0']
# Failed to fetch details for ['EMAIL']: Status code 400
# No details fetched for chunk: ['EMAIL']
# Failed to fetch details for ['84643P9']: Status code 400
# No details fetched for chunk: ['84643P9']
# Failed to fetch details for ['21687']: Status code 400
# No details fetched for chunk: ['21687']
# Failed to fetch details for ['0JV4800']: Status code 400
# No details fetched for chunk: ['0JV4800']
# Failed to fetch details for ['F2100']: Status code 400
# No details fetched for chunk: ['F2100']
# Failed to fetch details for ['213BB62']: Status code 400
# No details fetched for chunk: ['213BB62']
# Failed to fetch details for ['35WX79C']: Status code 400
# No details fetched for chunk: ['35WX79C']
# Failed to fetch details for ['13860RE']: Status code 400
# No details fetched for chunk: ['13860RE']
# Failed to fetch details for ['1027109']: Status code 400
# No details fetched for chunk: ['1027109']
# Failed to fetch details for ['MISUSE']: Status code 400
# No details fetched for chunk: ['MISUSE']
# Failed to fetch details for ['0724EM4']: Status code 400
# No details fetched for chunk: ['0724EM4']
# Failed to fetch details for ['15631']: Status code 400
# No details fetched for chunk: ['15631']
# Failed to fetch details for ['44491K3']: Status code 400
# No details fetched for chunk: ['44491K3']
# Failed to fetch details for ['71109']: Status code 400
# No details fetched for chunk: ['71109']
# Failed to fetch details for ['53797T8']: Status code 400
# No details fetched for chunk: ['53797T8']
# Failed to fetch details for ['RD7860R']: Status code 400
# No details fetched for chunk: ['RD7860R']
# Failed to fetch details for ['T498B15']: Status code 400
# No details fetched for chunk: ['T498B15']
# Failed to fetch details for ['48089']: Status code 400
# No details fetched for chunk: ['48089']
# Failed to fetch details for ['35797T9']: Status code 400
# No details fetched for chunk: ['35797T9']
# Failed to fetch details for ['15PEERL']: Status code 400
# No details fetched for chunk: ['15PEERL']
# Failed to fetch details for ['802LK0']: Status code 400
# No details fetched for chunk: ['802LK0']
# Failed to fetch details for ['00717']: Status code 400
# No details fetched for chunk: ['00717']
# Failed to fetch details for ['8806XU8']: Status code 400
# No details fetched for chunk: ['8806XU8']
# Failed to fetch details for ['16813X4']: Status code 400
# No details fetched for chunk: ['16813X4']
# Failed to fetch details for ['818HC2']: Status code 400
# No details fetched for chunk: ['818HC2']
# Failed to fetch details for ['BABCOCK']: Status code 400
# No details fetched for chunk: ['BABCOCK']
# Failed to fetch details for ['2L090']: Status code 500
# No details fetched for chunk: ['2L090']
# Failed to fetch details for ['35WX78C']: Status code 400
# No details fetched for chunk: ['35WX78C']
# Failed to fetch details for ['94800HY']: Status code 400
# No details fetched for chunk: ['94800HY']
# Failed to fetch details for ['Y001THO']: Status code 400
# No details fetched for chunk: ['Y001THO']
# Failed to fetch details for ['113628C']: Status code 400
# No details fetched for chunk: ['113628C']
# Failed to fetch details for ['55EC30']: Status code 500
# No details fetched for chunk: ['55EC30']
# Failed to fetch details for ['464XT29']: Status code 400
# No details fetched for chunk: ['464XT29']
# Failed to fetch details for ['312KVP1']: Status code 400
# No details fetched for chunk: ['312KVP1']
# Failed to fetch details for ['1011242']: Status code 400
# No details fetched for chunk: ['1011242']
# Failed to fetch details for ['TB0A42F']: Status code 400
# No details fetched for chunk: ['TB0A42F']
# Failed to fetch details for ['5153WN5']: Status code 400
# No details fetched for chunk: ['5153WN5']
# Failed to fetch details for ['P0121AP']: Status code 400
# No details fetched for chunk: ['P0121AP']
# Failed to fetch details for ['20115TH']: Status code 400
# No details fetched for chunk: ['20115TH']
# Failed to fetch details for ['22452D7']: Status code 400
# No details fetched for chunk: ['22452D7']
# Failed to fetch details for ['89628']: Status code 400
# No details fetched for chunk: ['89628']
# Failed to fetch details for ['DB019IR']: Status code 400
# No details fetched for chunk: ['DB019IR']
# Failed to fetch details for ['2491V83']: Status code 400
# No details fetched for chunk: ['2491V83']
# Failed to fetch details for ['GRAINGE']: Status code 400
# No details fetched for chunk: ['GRAINGE']
# Failed to fetch details for ['2005C']: Status code 400
# No details fetched for chunk: ['2005C']
# Failed to fetch details for ['SEARCH']: Status code 400
# No details fetched for chunk: ['SEARCH']
# Failed to fetch details for ['794D127']: Status code 400
# No details fetched for chunk: ['794D127']
# Failed to fetch details for ['TURES']: Status code 400
# No details fetched for chunk: ['TURES']
# Failed to fetch details for ['CUX08CZ']: Status code 400
# No details fetched for chunk: ['CUX08CZ']
# Failed to fetch details for ['NONINFR']: Status code 400
# No details fetched for chunk: ['NONINFR']
# Failed to fetch details for ['1401R']: Status code 400
# No details fetched for chunk: ['1401R']
# Failed to fetch details for ['3813X54']: Status code 400
# No details fetched for chunk: ['3813X54']
# Failed to fetch details for ['999ZF9']: Status code 500
# No details fetched for chunk: ['999ZF9']
# Failed to fetch details for ['2EM4952']: Status code 400
# No details fetched for chunk: ['2EM4952']
# Failed to fetch details for ['ETHANOL']: Status code 400
# No details fetched for chunk: ['ETHANOL']
# Failed to fetch details for ['1V66491']: Status code 400
# No details fetched for chunk: ['1V66491']
# Failed to fetch details for ['C62814C']: Status code 400
# No details fetched for chunk: ['C62814C']
# Failed to fetch details for ['95797T8']: Status code 400
# No details fetched for chunk: ['95797T8']
# Failed to fetch details for ['TRENDS']: Status code 400
# No details fetched for chunk: ['TRENDS']
# Failed to fetch details for ['9113V77']: Status code 400
# No details fetched for chunk: ['9113V77']
# Failed to fetch details for ['146DWL3']: Status code 400
# No details fetched for chunk: ['146DWL3']
# Failed to fetch details for ['4568KA0']: Status code 400
# No details fetched for chunk: ['4568KA0']
# Failed to fetch details for ['30PL5']: Status code 400
# No details fetched for chunk: ['30PL5']
# Failed to fetch details for ['115962']: Status code 400
# No details fetched for chunk: ['115962']
# Failed to fetch details for ['WTEMPCO']: Status code 400
# No details fetched for chunk: ['WTEMPCO']
# Failed to fetch details for ['2843A76']: Status code 400
# No details fetched for chunk: ['2843A76']
# Failed to fetch details for ['A1KBWTI']: Status code 400
# No details fetched for chunk: ['A1KBWTI']
# Failed to fetch details for ['BENEFIT']: Status code 400
# No details fetched for chunk: ['BENEFIT']
# Failed to fetch details for ['SPSC261']: Status code 400
# No details fetched for chunk: ['SPSC261']
# Failed to fetch details for ['4HPU1']: Status code 500
# No details fetched for chunk: ['4HPU1']
# Failed to fetch details for ['13552CG']: Status code 400
# No details fetched for chunk: ['13552CG']
# Failed to fetch details for ['116378']: Status code 400
# No details fetched for chunk: ['116378']
# Failed to fetch details for ['JK5655J']: Status code 400
# No details fetched for chunk: ['JK5655J']
# Failed to fetch details for ['HOMELAN']: Status code 400
# No details fetched for chunk: ['HOMELAN']
# Failed to fetch details for ['43A8474']: Status code 400
# No details fetched for chunk: ['43A8474']
# Failed to fetch details for ['843C019']: Status code 400
# No details fetched for chunk: ['843C019']
# Failed to fetch details for ['093VRZ8']: Status code 400
# No details fetched for chunk: ['093VRZ8']
# Failed to fetch details for ['35XF763']: Status code 400
# No details fetched for chunk: ['35XF763']
# Failed to fetch details for ['RB417RE']: Status code 400
# No details fetched for chunk: ['RB417RE']
# Failed to fetch details for ['CORTECH']: Status code 400
# No details fetched for chunk: ['CORTECH']
# Failed to fetch details for ['DNESS']: Status code 400
# No details fetched for chunk: ['DNESS']
# Failed to fetch details for ['02458T2']: Status code 400
# No details fetched for chunk: ['02458T2']
# Failed to fetch details for ['4241HG9']: Status code 400
# No details fetched for chunk: ['4241HG9']
# Failed to fetch details for ['5LE23C']: Status code 400
# No details fetched for chunk: ['5LE23C']
# Failed to fetch details for ['3955EE6']: Status code 400
# No details fetched for chunk: ['3955EE6']
# Failed to fetch details for ['48799H7']: Status code 400
# No details fetched for chunk: ['48799H7']
# Failed to fetch details for ['6VTG8']: Status code 500
# No details fetched for chunk: ['6VTG8']
# Failed to fetch details for ['014GB73']: Status code 400
# No details fetched for chunk: ['014GB73']
# Failed to fetch details for ['XRP53XR']: Status code 400
# No details fetched for chunk: ['XRP53XR']
# Failed to fetch details for ['SLOAN']: Status code 400
# No details fetched for chunk: ['SLOAN']
# Failed to fetch details for ['ASMEIND']: Status code 400
# No details fetched for chunk: ['ASMEIND']
# Failed to fetch details for ['DRAEGER']: Status code 400
# No details fetched for chunk: ['DRAEGER']
# Failed to fetch details for ['CLEAN']: Status code 400
# No details fetched for chunk: ['CLEAN']
# Failed to fetch details for ['W10633T']: Status code 400
# No details fetched for chunk: ['W10633T']
# Failed to fetch details for ['SIMPLEH']: Status code 400
# No details fetched for chunk: ['SIMPLEH']
# Failed to fetch details for ['5043Y97']: Status code 400
# No details fetched for chunk: ['5043Y97']
# Failed to fetch details for ['63103']: Status code 400
# No details fetched for chunk: ['63103']
# Failed to fetch details for ['6849VU2']: Status code 400
# No details fetched for chunk: ['6849VU2']
# Failed to fetch details for ['QMARKO']: Status code 400
# No details fetched for chunk: ['QMARKO']
# Failed to fetch details for ['8RWK7']: Status code 500
# No details fetched for chunk: ['8RWK7']
# Failed to fetch details for ['1003577']: Status code 400
# No details fetched for chunk: ['1003577']
# Failed to fetch details for ['TB0A1Z4']: Status code 400
# No details fetched for chunk: ['TB0A1Z4']
# Failed to fetch details for ['RB4555R']: Status code 400
# No details fetched for chunk: ['RB4555R']
# Failed to fetch details for ['XLKLEEN']: Status code 400
# No details fetched for chunk: ['XLKLEEN']
# Failed to fetch details for ['4255EE4']: Status code 400
# No details fetched for chunk: ['4255EE4']
# Failed to fetch details for ['G8374NE']: Status code 400
# No details fetched for chunk: ['G8374NE']
# Failed to fetch details for ['REARR12']: Status code 400
# No details fetched for chunk: ['REARR12']
# Failed to fetch details for ['91459H3']: Status code 400
# No details fetched for chunk: ['91459H3']
# Failed to fetch details for ['T4J171']: Status code 400
# No details fetched for chunk: ['T4J171']
# Failed to fetch details for ['42796FY']: Status code 400
# No details fetched for chunk: ['42796FY']
# Failed to fetch details for ['14817GV']: Status code 400
# No details fetched for chunk: ['14817GV']
# Failed to fetch details for ['M474WR9']: Status code 400
# No details fetched for chunk: ['M474WR9']
# Failed to fetch details for ['9LGA88R']: Status code 400
# No details fetched for chunk: ['9LGA88R']
# Failed to fetch details for ['55420']: Status code 400
# No details fetched for chunk: ['55420']
# Failed to fetch details for ['35R19']: Status code 400
# No details fetched for chunk: ['35R19']
# Failed to fetch details for ['25002']: Status code 400
# No details fetched for chunk: ['25002']
# Failed to fetch details for ['813X81']: Status code 400
# No details fetched for chunk: ['813X81']
# Failed to fetch details for ['392UFW5']: Status code 400
# No details fetched for chunk: ['392UFW5']
# Failed to fetch details for ['84343A8']: Status code 400
# No details fetched for chunk: ['84343A8']
# Failed to fetch details for ['01353']: Status code 400
# No details fetched for chunk: ['01353']
# Failed to fetch details for ['2112V']: Status code 400
# No details fetched for chunk: ['2112V']
# Failed to fetch details for ['9054DF2']: Status code 400
# No details fetched for chunk: ['9054DF2']
# Failed to fetch details for ['799Z41']: Status code 500
# No details fetched for chunk: ['799Z41']
# Failed to fetch details for ['6AGK7M']: Status code 400
# No details fetched for chunk: ['6AGK7M']
# Failed to fetch details for ['103WUP6']: Status code 400
# No details fetched for chunk: ['103WUP6']
# Failed to fetch details for ['26078AR']: Status code 400
# No details fetched for chunk: ['26078AR']
# Failed to fetch details for ['BLNEW']: Status code 400
# No details fetched for chunk: ['BLNEW']
# Failed to fetch details for ['16501']: Status code 400
# No details fetched for chunk: ['16501']
# Failed to fetch details for ['AMETEK']: Status code 400
# No details fetched for chunk: ['AMETEK']
# Failed to fetch details for ['FQ00062']: Status code 400
# No details fetched for chunk: ['FQ00062']
# Failed to fetch details for ['TB1A1XJ']: Status code 400
# No details fetched for chunk: ['TB1A1XJ']
# Failed to fetch details for ['6512N63']: Status code 400
# No details fetched for chunk: ['6512N63']
# Failed to fetch details for ['MEDICF']: Status code 400
# No details fetched for chunk: ['MEDICF']
# Failed to fetch details for ['91U4149']: Status code 400
# No details fetched for chunk: ['91U4149']
# Failed to fetch details for ['23443']: Status code 400
# No details fetched for chunk: ['23443']
# Failed to fetch details for ['36794DV']: Status code 400
# No details fetched for chunk: ['36794DV']
# Failed to fetch details for ['87813X6']: Status code 400
# No details fetched for chunk: ['87813X6']
# Failed to fetch details for ['59101']: Status code 400
# No details fetched for chunk: ['59101']
# Failed to fetch details for ['117TH']: Status code 400
# No details fetched for chunk: ['117TH']
# Failed to fetch details for ['1002949']: Status code 400
# No details fetched for chunk: ['1002949']
# Failed to fetch details for ['VITAL']: Status code 400
# No details fetched for chunk: ['VITAL']
# Failed to fetch details for ['ARIES']: Status code 400
# No details fetched for chunk: ['ARIES']
# Failed to fetch details for ['7552WX8']: Status code 400
# No details fetched for chunk: ['7552WX8']
# Failed to fetch details for ['PL78RMF']: Status code 400
# No details fetched for chunk: ['PL78RMF']
# Failed to fetch details for ['3491U94']: Status code 400
# No details fetched for chunk: ['3491U94']
# Failed to fetch details for ['41CR16M']: Status code 400
# No details fetched for chunk: ['41CR16M']
# Failed to fetch details for ['PARTITI']: Status code 400
# No details fetched for chunk: ['PARTITI']
# Failed to fetch details for ['CROSS']: Status code 400
# No details fetched for chunk: ['CROSS']
# Failed to fetch details for ['1023228']: Status code 400
# No details fetched for chunk: ['1023228']
# Failed to fetch details for ['BUYERS']: Status code 400
# No details fetched for chunk: ['BUYERS']
# Failed to fetch details for ['LOG9200']: Status code 400
# No details fetched for chunk: ['LOG9200']
# Failed to fetch details for ['PREMIUM']: Status code 400
# No details fetched for chunk: ['PREMIUM']
# Failed to fetch details for ['920025C']: Status code 400
# No details fetched for chunk: ['920025C']
# Failed to fetch details for ['3001TIM']: Status code 400
# No details fetched for chunk: ['3001TIM']
# Failed to fetch details for ['714GB71']: Status code 400
# No details fetched for chunk: ['714GB71']
# Failed to fetch details for ['CANCELL']: Status code 400
# No details fetched for chunk: ['CANCELL']
# Failed to fetch details for ['584DJW3']: Status code 400
# No details fetched for chunk: ['584DJW3']
# Failed to fetch details for ['CUSTOME']: Status code 400
# No details fetched for chunk: ['CUSTOME']
# Failed to fetch details for ['974GB68']: Status code 400
# No details fetched for chunk: ['974GB68']
# Failed to fetch details for ['3ANBE98']: Status code 400
# No details fetched for chunk: ['3ANBE98']
# Failed to fetch details for ['433DRN1']: Status code 400
# No details fetched for chunk: ['433DRN1']
# Failed to fetch details for ['4C62414']: Status code 400
# No details fetched for chunk: ['4C62414']
# Failed to fetch details for ['745VK78']: Status code 400
# No details fetched for chunk: ['745VK78']
# Failed to fetch details for ['L59FAX2']: Status code 400
# No details fetched for chunk: ['L59FAX2']
# Failed to fetch details for ['878ADP8']: Status code 400
# No details fetched for chunk: ['878ADP8']
# Failed to fetch details for ['132RB16']: Status code 400
# No details fetched for chunk: ['132RB16']
# Failed to fetch details for ['DIVERSE']: Status code 400
# No details fetched for chunk: ['DIVERSE']
# Failed to fetch details for ['01243C0']: Status code 400
# No details fetched for chunk: ['01243C0']
# Failed to fetch details for ['2XN3732']: Status code 400
# No details fetched for chunk: ['2XN3732']
# Failed to fetch details for ['VP32KVP']: Status code 400
# No details fetched for chunk: ['VP32KVP']
# Failed to fetch details for ['18197JM']: Status code 400
# No details fetched for chunk: ['18197JM']
# Failed to fetch details for ['NSPSC41']: Status code 400
# No details fetched for chunk: ['NSPSC41']
# Failed to fetch details for ['INTELLE']: Status code 400
# No details fetched for chunk: ['INTELLE']
# Failed to fetch details for ['1492U32']: Status code 400
# No details fetched for chunk: ['1492U32']
# Failed to fetch details for ['CME8355']: Status code 400
# No details fetched for chunk: ['CME8355']
# Failed to fetch details for ['TECHNOL']: Status code 400
# No details fetched for chunk: ['TECHNOL']
# Failed to fetch details for ['RB874GR']: Status code 400
# No details fetched for chunk: ['RB874GR']
# Failed to fetch details for ['A7402']: Status code 400
# No details fetched for chunk: ['A7402']
# Failed to fetch details for ['78408']: Status code 400
# No details fetched for chunk: ['78408']
# Failed to fetch details for ['6660JD2']: Status code 400
# No details fetched for chunk: ['6660JD2']
# Failed to fetch details for ['70498X6']: Status code 400
# No details fetched for chunk: ['70498X6']
# Failed to fetch details for ['75247']: Status code 400
# No details fetched for chunk: ['75247']
# Failed to fetch details for ['6529RW0']: Status code 400
# No details fetched for chunk: ['6529RW0']
# Failed to fetch details for ['HTRAM']: Status code 400
# No details fetched for chunk: ['HTRAM']
# Failed to fetch details for ['00J1780']: Status code 400
# No details fetched for chunk: ['00J1780']
# Failed to fetch details for ['8038101']: Status code 400
# No details fetched for chunk: ['8038101']
# Failed to fetch details for ['976UTD1']: Status code 400
# No details fetched for chunk: ['976UTD1']
# Failed to fetch details for ['8242TIM']: Status code 400
# No details fetched for chunk: ['8242TIM']
# Failed to fetch details for ['1YNG3']: Status code 500
# No details fetched for chunk: ['1YNG3']
# Failed to fetch details for ['92507']: Status code 400
# No details fetched for chunk: ['92507']
# Failed to fetch details for ['M7752EM']: Status code 400
# No details fetched for chunk: ['M7752EM']
# Failed to fetch details for ['6860NT6']: Status code 400
# No details fetched for chunk: ['6860NT6']
# Failed to fetch details for ['SECTION']: Status code 400
# No details fetched for chunk: ['SECTION']
# Failed to fetch details for ['90U5449']: Status code 400
# No details fetched for chunk: ['90U5449']
# Failed to fetch details for ['91447Y5']: Status code 400
# No details fetched for chunk: ['91447Y5']
# Failed to fetch details for ['3345EU4']: Status code 400
# No details fetched for chunk: ['3345EU4']
# Failed to fetch details for ['521U996']: Status code 400
# No details fetched for chunk: ['521U996']
# Failed to fetch details for ['JL88VPG']: Status code 400
# No details fetched for chunk: ['JL88VPG']
# Failed to fetch details for ['108AAM3']: Status code 400
# No details fetched for chunk: ['108AAM3']
# Failed to fetch details for ['V71420V']: Status code 400
# No details fetched for chunk: ['V71420V']
# Failed to fetch details for ['1UHG8']: Status code 500
# No details fetched for chunk: ['1UHG8']
# Failed to fetch details for ['RB4251S']: Status code 400
# No details fetched for chunk: ['RB4251S']
# Failed to fetch details for ['71043A7']: Status code 400
# No details fetched for chunk: ['71043A7']
# Failed to fetch details for ['8543A78']: Status code 400
# No details fetched for chunk: ['8543A78']
# Failed to fetch details for ['512JDF3']: Status code 400
# No details fetched for chunk: ['512JDF3']
# Failed to fetch details for ['45EF934']: Status code 400
# No details fetched for chunk: ['45EF934']
# Failed to fetch details for ['CA7921C']: Status code 400
# No details fetched for chunk: ['CA7921C']
# Failed to fetch details for ['1020086']: Status code 400
# No details fetched for chunk: ['1020086']
# Failed to fetch details for ['0439C30']: Status code 400
# No details fetched for chunk: ['0439C30']
# Failed to fetch details for ['TORNADO']: Status code 400
# No details fetched for chunk: ['TORNADO']
# Failed to fetch details for ['W240V']: Status code 400
# No details fetched for chunk: ['W240V']
# Failed to fetch details for ['HOTHAND']: Status code 400
# No details fetched for chunk: ['HOTHAND']
# Failed to fetch details for ['116111']: Status code 400
# No details fetched for chunk: ['116111']
# Failed to fetch details for ['403XHT5']: Status code 400
# No details fetched for chunk: ['403XHT5']
# Failed to fetch details for ['DXWP100']: Status code 400
# No details fetched for chunk: ['DXWP100']
# Failed to fetch details for ['GRNEW']: Status code 400
# No details fetched for chunk: ['GRNEW']
# Failed to fetch details for ['75796JC']: Status code 400
# No details fetched for chunk: ['75796JC']
# Failed to fetch details for ['W10181']: Status code 400
# No details fetched for chunk: ['W10181']
# Failed to fetch details for ['481C08']: Status code 404
# No details fetched for chunk: ['481C08']
# Failed to fetch details for ['17010']: Status code 400
# No details fetched for chunk: ['17010']
# Failed to fetch details for ['5142020']: Status code 400
# No details fetched for chunk: ['5142020']
# Failed to fetch details for ['TB1A2QV']: Status code 400
# No details fetched for chunk: ['TB1A2QV']
# Failed to fetch details for ['3T843C']: Status code 400
# No details fetched for chunk: ['3T843C']
# Failed to fetch details for ['SOLEAIR']: Status code 400
# No details fetched for chunk: ['SOLEAIR']
# Failed to fetch details for ['06P9180']: Status code 400
# No details fetched for chunk: ['06P9180']
# Failed to fetch details for ['A7450']: Status code 400
# No details fetched for chunk: ['A7450']
# Failed to fetch details for ['X719KDJ']: Status code 400
# No details fetched for chunk: ['X719KDJ']
# Failed to fetch details for ['NFC15']: Status code 400
# No details fetched for chunk: ['NFC15']
# Failed to fetch details for ['RB4177C']: Status code 400
# No details fetched for chunk: ['RB4177C']
# Failed to fetch details for ['11232']: Status code 400
# No details fetched for chunk: ['11232']
# Failed to fetch details for ['85R17']: Status code 400
# No details fetched for chunk: ['85R17']
# Failed to fetch details for ['DH5143K']: Status code 400
# No details fetched for chunk: ['DH5143K']
# Failed to fetch details for ['LT295']: Status code 400
# No details fetched for chunk: ['LT295']
# Failed to fetch details for ['0818HC1']: Status code 400
# No details fetched for chunk: ['0818HC1']
# Failed to fetch details for ['XLARGE']: Status code 400
# No details fetched for chunk: ['XLARGE']
# Failed to fetch details for ['AABILIT']: Status code 400
# No details fetched for chunk: ['AABILIT']
# Failed to fetch details for ['66439M6']: Status code 400
# No details fetched for chunk: ['66439M6']
# Failed to fetch details for ['MASTER']: Status code 400
# No details fetched for chunk: ['MASTER']
# Failed to fetch details for ['34471']: Status code 400
# No details fetched for chunk: ['34471']
# Failed to fetch details for ['809WX8']: Status code 400
# No details fetched for chunk: ['809WX8']
# Failed to fetch details for ['4643A64']: Status code 400
# No details fetched for chunk: ['4643A64']
# Failed to fetch details for ['813X93']: Status code 400
# No details fetched for chunk: ['813X93']
# Failed to fetch details for ['813X67']: Status code 400
# No details fetched for chunk: ['813X67']
# Failed to fetch details for ['9CS21']: Status code 400
# No details fetched for chunk: ['9CS21']
# Failed to fetch details for ['6516W53']: Status code 400
# No details fetched for chunk: ['6516W53']
# Failed to fetch details for ['22UV778']: Status code 400
# No details fetched for chunk: ['22UV778']
# Failed to fetch details for ['RB8807D']: Status code 400
# No details fetched for chunk: ['RB8807D']
# Failed to fetch details for ['2421EK3']: Status code 400
# No details fetched for chunk: ['2421EK3']
# Failed to fetch details for ['GMM9900']: Status code 400
# No details fetched for chunk: ['GMM9900']
# Failed to fetch details for ['91CSPST']: Status code 400
# No details fetched for chunk: ['91CSPST']
# Failed to fetch details for ['70R16']: Status code 400
# No details fetched for chunk: ['70R16']
# Failed to fetch details for ['43A6394']: Status code 400
# No details fetched for chunk: ['43A6394']
# Failed to fetch details for ['MILWAUK']: Status code 400
# No details fetched for chunk: ['MILWAUK']
# Failed to fetch details for ['TB0A5RS']: Status code 400
# No details fetched for chunk: ['TB0A5RS']
# Failed to fetch details for ['865E874']: Status code 400
# No details fetched for chunk: ['865E874']
# Failed to fetch details for ['92841']: Status code 400
# No details fetched for chunk: ['92841']
# Failed to fetch details for ['84439M5']: Status code 400
# No details fetched for chunk: ['84439M5']
# Failed to fetch details for ['COVID']: Status code 400
# No details fetched for chunk: ['COVID']
# Failed to fetch details for ['UNSPSC4']: Status code 400
# No details fetched for chunk: ['UNSPSC4']
# Failed to fetch details for ['023XGC7']: Status code 400
# No details fetched for chunk: ['023XGC7']
# Failed to fetch details for ['TB1A1I5']: Status code 400
# No details fetched for chunk: ['TB1A1I5']
# Failed to fetch details for ['19GEK19']: Status code 400
# No details fetched for chunk: ['19GEK19']
# Failed to fetch details for ['32439F2']: Status code 400
# No details fetched for chunk: ['32439F2']
# Failed to fetch details for ['PC1300C']: Status code 400
# No details fetched for chunk: ['PC1300C']
# Failed to fetch details for ['575PB37']: Status code 400
# No details fetched for chunk: ['575PB37']
# Failed to fetch details for ['3731AC6']: Status code 400
# No details fetched for chunk: ['3731AC6']
# Failed to fetch details for ['NOAAL']: Status code 400
# No details fetched for chunk: ['NOAAL']
# Failed to fetch details for ['3352ZX9']: Status code 400
# No details fetched for chunk: ['3352ZX9']
# Failed to fetch details for ['5145MP7']: Status code 400
# No details fetched for chunk: ['5145MP7']
# Failed to fetch details for ['HOROGOO']: Status code 400
# No details fetched for chunk: ['HOROGOO']
# Failed to fetch details for ['CA4525W']: Status code 400
# No details fetched for chunk: ['CA4525W']
# Failed to fetch details for ['491V844']: Status code 400
# No details fetched for chunk: ['491V844']
# Failed to fetch details for ['74438X2']: Status code 400
# No details fetched for chunk: ['74438X2']
# Failed to fetch details for ['GB00562']: Status code 400
# No details fetched for chunk: ['GB00562']
# Failed to fetch details for ['843A609']: Status code 400
# No details fetched for chunk: ['843A609']
# Failed to fetch details for ['02472']: Status code 400
# No details fetched for chunk: ['02472']
# Failed to fetch details for ['W10717R']: Status code 400
# No details fetched for chunk: ['W10717R']
# Failed to fetch details for ['2441HG9']: Status code 400
# No details fetched for chunk: ['2441HG9']
# Failed to fetch details for ['07012']: Status code 400
# No details fetched for chunk: ['07012']
# Failed to fetch details for ['CA1435W']: Status code 400
# No details fetched for chunk: ['CA1435W']
# Failed to fetch details for ['1TC63C']: Status code 400
# No details fetched for chunk: ['1TC63C']
# Failed to fetch details for ['LT265']: Status code 400
# No details fetched for chunk: ['LT265']
# Failed to fetch details for ['402109M']: Status code 400
# No details fetched for chunk: ['402109M']
# Failed to fetch details for ['4418D82']: Status code 400
# No details fetched for chunk: ['4418D82']
# Failed to fetch details for ['91V4249']: Status code 400
# No details fetched for chunk: ['91V4249']
# Failed to fetch details for ['00443C0']: Status code 400
# No details fetched for chunk: ['00443C0']
# Failed to fetch details for ['SKILCRA']: Status code 400
# No details fetched for chunk: ['SKILCRA']
# Failed to fetch details for ['HANDLER']: Status code 400
# No details fetched for chunk: ['HANDLER']
# Failed to fetch details for ['6490DAN']: Status code 400
# No details fetched for chunk: ['6490DAN']
# Failed to fetch details for ['FW09LH9']: Status code 400
# No details fetched for chunk: ['FW09LH9']
# Failed to fetch details for ['491M69']: Status code 500
# No details fetched for chunk: ['491M69']
# Failed to fetch details for ['8231HH3']: Status code 400
# No details fetched for chunk: ['8231HH3']
# Failed to fetch details for ['9214TIM']: Status code 400
# No details fetched for chunk: ['9214TIM']
# Failed to fetch details for ['21883']: Status code 400
# No details fetched for chunk: ['21883']
# Failed to fetch details for ['TOOLS']: Status code 400
# No details fetched for chunk: ['TOOLS']
# Failed to fetch details for ['22W828M']: Status code 400
# No details fetched for chunk: ['22W828M']
# Failed to fetch details for ['NBE986']: Status code 400
# No details fetched for chunk: ['NBE986']
# Failed to fetch details for ['A1KJ8JU']: Status code 400
# No details fetched for chunk: ['A1KJ8JU']
# Failed to fetch details for ['BLADES']: Status code 400
# No details fetched for chunk: ['BLADES']
# Failed to fetch details for ['4545AE8']: Status code 400
# No details fetched for chunk: ['4545AE8']
# Failed to fetch details for ['G6633AV']: Status code 400
# No details fetched for chunk: ['G6633AV']
# Failed to fetch details for ['6365450']: Status code 400
# No details fetched for chunk: ['6365450']
# Failed to fetch details for ['TB1A5P1']: Status code 400
# No details fetched for chunk: ['TB1A5P1']
# Failed to fetch details for ['3222021']: Status code 400
# No details fetched for chunk: ['3222021']
# Failed to fetch details for ['AWG30']: Status code 400
# No details fetched for chunk: ['AWG30']
# Failed to fetch details for ['2022EL7']: Status code 400
# No details fetched for chunk: ['2022EL7']
# Failed to fetch details for ['9MICHEL']: Status code 400
# No details fetched for chunk: ['9MICHEL']
# Failed to fetch details for ['OPERATI']: Status code 400
# No details fetched for chunk: ['OPERATI']
# Failed to fetch details for ['24479X0']: Status code 400
# No details fetched for chunk: ['24479X0']
# Failed to fetch details for ['014A103']: Status code 400
# No details fetched for chunk: ['014A103']
# Failed to fetch details for ['2FDY3C']: Status code 400
# No details fetched for chunk: ['2FDY3C']
# Failed to fetch details for ['2CSPDT']: Status code 400
# No details fetched for chunk: ['2CSPDT']
# Failed to fetch details for ['786V56']: Status code 500
# No details fetched for chunk: ['786V56']
# Failed to fetch details for ['581YNF1']: Status code 400
# No details fetched for chunk: ['581YNF1']
# Failed to fetch details for ['ERINE']: Status code 400
# No details fetched for chunk: ['ERINE']
# Failed to fetch details for ['642855I']: Status code 400
# No details fetched for chunk: ['642855I']
# Failed to fetch details for ['35816']: Status code 400
# No details fetched for chunk: ['35816']
# Failed to fetch details for ['8783PZ3']: Status code 400
# No details fetched for chunk: ['8783PZ3']
# Failed to fetch details for ['6055ED6']: Status code 400
# No details fetched for chunk: ['6055ED6']
# Failed to fetch details for ['IPN0DO']: Status code 400
# No details fetched for chunk: ['IPN0DO']
# Failed to fetch details for ['EMERGEN']: Status code 400
# No details fetched for chunk: ['EMERGEN']
# Failed to fetch details for ['P969V12']: Status code 400
# No details fetched for chunk: ['P969V12']
# Failed to fetch details for ['TANCES']: Status code 400
# No details fetched for chunk: ['TANCES']
# Failed to fetch details for ['W03258R']: Status code 400
# No details fetched for chunk: ['W03258R']
# Failed to fetch details for ['1491V02']: Status code 400
# No details fetched for chunk: ['1491V02']
# Failed to fetch details for ['XRL73XR']: Status code 400
# No details fetched for chunk: ['XRL73XR']
# Failed to fetch details for ['034GB70']: Status code 400
# No details fetched for chunk: ['034GB70']
# Failed to fetch details for ['5LE21M']: Status code 400
# No details fetched for chunk: ['5LE21M']
# Failed to fetch details for ['68CXL09']: Status code 400
# No details fetched for chunk: ['68CXL09']
# Failed to fetch details for ['36445K7']: Status code 400
# No details fetched for chunk: ['36445K7']
# Failed to fetch details for ['2839EP3']: Status code 400
# No details fetched for chunk: ['2839EP3']
# Failed to fetch details for ['43A6424']: Status code 400
# No details fetched for chunk: ['43A6424']
# Failed to fetch details for ['RB195CA']: Status code 400
# No details fetched for chunk: ['RB195CA']
# Failed to fetch details for ['32RT41M']: Status code 400
# No details fetched for chunk: ['32RT41M']
# Failed to fetch details for ['8345VK8']: Status code 400
# No details fetched for chunk: ['8345VK8']
# Failed to fetch details for ['3AY2FAV']: Status code 400
# No details fetched for chunk: ['3AY2FAV']
# Failed to fetch details for ['5242TIM']: Status code 400
# No details fetched for chunk: ['5242TIM']
# Failed to fetch details for ['1813X84']: Status code 400
# No details fetched for chunk: ['1813X84']
# Failed to fetch details for ['CA1421C']: Status code 400
# No details fetched for chunk: ['CA1421C']
# Failed to fetch details for ['116474']: Status code 400
# No details fetched for chunk: ['116474']
# Failed to fetch details for ['FINAL']: Status code 400
# No details fetched for chunk: ['FINAL']
# Failed to fetch details for ['11747']: Status code 400
# No details fetched for chunk: ['11747']
# Failed to fetch details for ['3RKU6O']: Status code 400
# No details fetched for chunk: ['3RKU6O']
# Failed to fetch details for ['2KVP94F']: Status code 400
# No details fetched for chunk: ['2KVP94F']
# Failed to fetch details for ['12817U2']: Status code 400
# No details fetched for chunk: ['12817U2']
# Failed to fetch details for ['6003THO']: Status code 400
# No details fetched for chunk: ['6003THO']
# Failed to fetch details for ['041TDH8']: Status code 400
# No details fetched for chunk: ['041TDH8']
# Failed to fetch details for ['09382']: Status code 400
# No details fetched for chunk: ['09382']
# Failed to fetch details for ['1011243']: Status code 400
# No details fetched for chunk: ['1011243']
# Failed to fetch details for ['9453CT5']: Status code 400
# No details fetched for chunk: ['9453CT5']
# Failed to fetch details for ['813X55']: Status code 400
# No details fetched for chunk: ['813X55']
# Failed to fetch details for ['43C0014']: Status code 400
# No details fetched for chunk: ['43C0014']
# Failed to fetch details for ['A89243A']: Status code 400
# No details fetched for chunk: ['A89243A']
# Failed to fetch details for ['61YNE2']: Status code 400
# No details fetched for chunk: ['61YNE2']
# Failed to fetch details for ['22L3203']: Status code 400
# No details fetched for chunk: ['22L3203']
# Failed to fetch details for ['TB12600']: Status code 400
# No details fetched for chunk: ['TB12600']
# Failed to fetch details for ['FRIGIWE']: Status code 400
# No details fetched for chunk: ['FRIGIWE']
# Failed to fetch details for ['A7127DA']: Status code 400
# No details fetched for chunk: ['A7127DA']
# Failed to fetch details for ['EVENTS']: Status code 400
# No details fetched for chunk: ['EVENTS']
# Failed to fetch details for ['THWIRE']: Status code 400
# No details fetched for chunk: ['THWIRE']
# Failed to fetch details for ['N1357RO']: Status code 400
# No details fetched for chunk: ['N1357RO']
# Failed to fetch details for ['42X497']: Status code 500
# No details fetched for chunk: ['42X497']
# Failed to fetch details for ['ARMOR']: Status code 400
# No details fetched for chunk: ['ARMOR']
# Failed to fetch details for ['HARTT']: Status code 400
# No details fetched for chunk: ['HARTT']
# Failed to fetch details for ['AWG60S']: Status code 400
# No details fetched for chunk: ['AWG60S']
# Failed to fetch details for ['05873C']: Status code 400
# No details fetched for chunk: ['05873C']
# Failed to fetch details for ['974GB80']: Status code 400
# No details fetched for chunk: ['974GB80']
# Failed to fetch details for ['SUBCONT']: Status code 400
# No details fetched for chunk: ['SUBCONT']
# Failed to fetch details for ['TITAN']: Status code 400
# No details fetched for chunk: ['TITAN']
# Failed to fetch details for ['CMP1258']: Status code 400
# No details fetched for chunk: ['CMP1258']
# Failed to fetch details for ['ISEA107']: Status code 400
# No details fetched for chunk: ['ISEA107']
# Failed to fetch details for ['1648ZJ7']: Status code 400
# No details fetched for chunk: ['1648ZJ7']
# Failed to fetch details for ['WK682CA']: Status code 400
# No details fetched for chunk: ['WK682CA']
# Failed to fetch details for ['2MY32C']: Status code 400
# No details fetched for chunk: ['2MY32C']
# Failed to fetch details for ['1001XEA']: Status code 400
# No details fetched for chunk: ['1001XEA']
# Failed to fetch details for ['9J1919N']: Status code 400
# No details fetched for chunk: ['9J1919N']
# Failed to fetch details for ['73805G6']: Status code 400
# No details fetched for chunk: ['73805G6']
# Failed to fetch details for ['STEINER']: Status code 400
# No details fetched for chunk: ['STEINER']
# Failed to fetch details for ['D6868']: Status code 400
# No details fetched for chunk: ['D6868']
# Failed to fetch details for ['A7402AV']: Status code 400
# No details fetched for chunk: ['A7402AV']
# Failed to fetch details for ['54643P1']: Status code 400
# No details fetched for chunk: ['54643P1']
# Failed to fetch details for ['3943A74']: Status code 400
# No details fetched for chunk: ['3943A74']
# ...
# No details fetched for chunk: ['6182020']
# Failed to fetch details for ['CA5679K']: Status code 400
# No details fetched for chunk: ['CA5679K']
# Failed to fetch details for ['PEOPLE']: Status code 400
# No details fetched for chunk: ['PEOPLE']
# Failed to fetch details for ['38N654M']: Status code 400
# No details fetched for chunk: ['38N654M']
# Failed to fetch details for ['SHIPMEN']: Status code 400
# No details fetched for chunk: ['SHIPMEN']
# Failed to fetch details for ['MEDIUM']: Status code 400
# No details fetched for chunk: ['MEDIUM']
# Failed to fetch details for ['14159']: Status code 400
# No details fetched for chunk: ['14159']
# Failed to fetch details for ['5608AGT']: Status code 400
# No details fetched for chunk: ['5608AGT']
# Failed to fetch details for ['616KEA7']: Status code 400
# No details fetched for chunk: ['616KEA7']
# Failed to fetch details for ['ARBITRA']: Status code 400
# No details fetched for chunk: ['ARBITRA']
# Failed to fetch details for ['843A955']: Status code 400
# No details fetched for chunk: ['843A955']
# Failed to fetch details for ['1029XM7']: Status code 400
# No details fetched for chunk: ['1029XM7']
# Failed to fetch details for ['LUMAPRO']: Status code 400
# No details fetched for chunk: ['LUMAPRO']
# Failed to fetch details for ['ORSHEIM']: Status code 400
# No details fetched for chunk: ['ORSHEIM']
# Failed to fetch details for ['RB4251T']: Status code 400
# No details fetched for chunk: ['RB4251T']
# Failed to fetch details for ['38E566C']: Status code 400
# No details fetched for chunk: ['38E566C']
# Failed to fetch details for ['52197JY']: Status code 400
# No details fetched for chunk: ['52197JY']
# Failed to fetch details for ['43A9664']: Status code 400
# No details fetched for chunk: ['43A9664']
# Failed to fetch details for ['X7725AX']: Status code 400
# No details fetched for chunk: ['X7725AX']
# Failed to fetch details for ['GW2546C']: Status code 400
# No details fetched for chunk: ['GW2546C']
# Failed to fetch details for ['MOBILD']: Status code 400
# No details fetched for chunk: ['MOBILD']
# Failed to fetch details for ['PRESTON']: Status code 400
# No details fetched for chunk: ['PRESTON']
# Failed to fetch details for ['76553']: Status code 400
# No details fetched for chunk: ['76553']
# Failed to fetch details for ['CHECKER']: Status code 400
# No details fetched for chunk: ['CHECKER']
# Failed to fetch details for ['243A653']: Status code 400
# No details fetched for chunk: ['243A653']
# Failed to fetch details for ['35439M5']: Status code 400
# No details fetched for chunk: ['35439M5']
# Failed to fetch details for ['40511']: Status code 400
# No details fetched for chunk: ['40511']
# Failed to fetch details for ['A83543A']: Status code 400
# No details fetched for chunk: ['A83543A']
# Failed to fetch details for ['BAYCO']: Status code 400
# No details fetched for chunk: ['BAYCO']
# Failed to fetch details for ['SPEND']: Status code 400
# No details fetched for chunk: ['SPEND']
# Failed to fetch details for ['A7124AV']: Status code 400
# No details fetched for chunk: ['A7124AV']
# Failed to fetch details for ['30R21']: Status code 400
# No details fetched for chunk: ['30R21']
# Failed to fetch details for ['4653DD4']: Status code 400
# No details fetched for chunk: ['4653DD4']
# Failed to fetch details for ['00JV380']: Status code 400
# No details fetched for chunk: ['00JV380']
# Failed to fetch details for ['48024']: Status code 400
# No details fetched for chunk: ['48024']
# Failed to fetch details for ['W211042']: Status code 400
# No details fetched for chunk: ['W211042']
# Failed to fetch details for ['91V2349']: Status code 400
# No details fetched for chunk: ['91V2349']
# Failed to fetch details for ['U001ARI']: Status code 400
# No details fetched for chunk: ['U001ARI']
# Failed to fetch details for ['20E892C']: Status code 400
# No details fetched for chunk: ['20E892C']
# Failed to fetch details for ['43C0404']: Status code 400
# No details fetched for chunk: ['43C0404']
# Failed to fetch details for ['07812']: Status code 400
# No details fetched for chunk: ['07812']
# Failed to fetch details for ['492T86M']: Status code 400
# No details fetched for chunk: ['492T86M']
# Failed to fetch details for ['764FKR2']: Status code 400
# No details fetched for chunk: ['764FKR2']
# Failed to fetch details for ['3032TL9']: Status code 400
# No details fetched for chunk: ['3032TL9']
# Failed to fetch details for ['56LN43C']: Status code 400
# No details fetched for chunk: ['56LN43C']
# Failed to fetch details for ['BROWSE']: Status code 400
# No details fetched for chunk: ['BROWSE']
# Failed to fetch details for ['8214TIM']: Status code 400
# No details fetched for chunk: ['8214TIM']
# Failed to fetch details for ['IMAGEWE']: Status code 400
# No details fetched for chunk: ['IMAGEWE']
# Failed to fetch details for ['34382']: Status code 400
# No details fetched for chunk: ['34382']
# Failed to fetch details for ['55EC19']: Status code 500
# No details fetched for chunk: ['55EC19']
# Failed to fetch details for ['6360XN2']: Status code 400
# No details fetched for chunk: ['6360XN2']
# Failed to fetch details for ['47809MZ']: Status code 400
# No details fetched for chunk: ['47809MZ']
# Failed to fetch details for ['786UZ6']: Status code 500
# No details fetched for chunk: ['786UZ6']
# Failed to fetch details for ['38E571M']: Status code 400
# No details fetched for chunk: ['38E571M']
# Failed to fetch details for ['39F190S']: Status code 400
# No details fetched for chunk: ['39F190S']
# Failed to fetch details for ['006KDZ8']: Status code 400
# No details fetched for chunk: ['006KDZ8']
# Failed to fetch details for ['W05680S']: Status code 400
# No details fetched for chunk: ['W05680S']
# Failed to fetch details for ['ALLOW']: Status code 400
# No details fetched for chunk: ['ALLOW']
# Failed to fetch details for ['9938ZD4']: Status code 400
# No details fetched for chunk: ['9938ZD4']
# Failed to fetch details for ['94438X1']: Status code 400
# No details fetched for chunk: ['94438X1']
# Failed to fetch details for ['5492U26']: Status code 400
# No details fetched for chunk: ['5492U26']
# Failed to fetch details for ['12579']: Status code 400
# No details fetched for chunk: ['12579']
# Failed to fetch details for ['3C04243']: Status code 400
# No details fetched for chunk: ['3C04243']
# Failed to fetch details for ['11353']: Status code 400
# No details fetched for chunk: ['11353']
# Failed to fetch details for ['4NE56M']: Status code 400
# No details fetched for chunk: ['4NE56M']
# Failed to fetch details for ['116309']: Status code 400
# No details fetched for chunk: ['116309']
# Failed to fetch details for ['B1L57']: Status code 400
# No details fetched for chunk: ['B1L57']
# Failed to fetch details for ['708AAM2']: Status code 400
# No details fetched for chunk: ['708AAM2']
# Failed to fetch details for ['3JUSTIN']: Status code 400
# No details fetched for chunk: ['3JUSTIN']
# Failed to fetch details for ['60TRITA']: Status code 400
# No details fetched for chunk: ['60TRITA']
# Failed to fetch details for ['6613M54']: Status code 400
# No details fetched for chunk: ['6613M54']
# Failed to fetch details for ['PROCESS']: Status code 400
# No details fetched for chunk: ['PROCESS']
# Failed to fetch details for ['29PG42M']: Status code 400
# No details fetched for chunk: ['29PG42M']
# Failed to fetch details for ['A7125RE']: Status code 400
# No details fetched for chunk: ['A7125RE']
# Failed to fetch details for ['491V644']: Status code 400
# No details fetched for chunk: ['491V644']
# Failed to fetch details for ['6455JK6']: Status code 400
# No details fetched for chunk: ['6455JK6']
# Failed to fetch details for ['3Z16793']: Status code 400
# No details fetched for chunk: ['3Z16793']
# Failed to fetch details for ['7643P20']: Status code 400
# No details fetched for chunk: ['7643P20']
# Failed to fetch details for ['1039FK8']: Status code 400
# No details fetched for chunk: ['1039FK8']
# Failed to fetch details for ['6JP9956']: Status code 400
# No details fetched for chunk: ['6JP9956']
# Failed to fetch details for ['61VG686']: Status code 400
# No details fetched for chunk: ['61VG686']
# Failed to fetch details for ['55EC32']: Status code 500
# No details fetched for chunk: ['55EC32']
# Failed to fetch details for ['TRIMCO']: Status code 400
# No details fetched for chunk: ['TRIMCO']
# Failed to fetch details for ['XG96E']: Status code 400
# No details fetched for chunk: ['XG96E']
# Failed to fetch details for ['4311C66']: Status code 400
# No details fetched for chunk: ['4311C66']
# Failed to fetch details for ['50507TI']: Status code 400
# No details fetched for chunk: ['50507TI']
# Failed to fetch details for ['INSTALL']: Status code 400
# No details fetched for chunk: ['INSTALL']
# Failed to fetch details for ['86515AV']: Status code 400
# No details fetched for chunk: ['86515AV']
# Failed to fetch details for ['TB1A1I4']: Status code 400
# No details fetched for chunk: ['TB1A1I4']
# Failed to fetch details for ['7800NEX']: Status code 400
# No details fetched for chunk: ['7800NEX']
# Failed to fetch details for ['53530WO']: Status code 400
# No details fetched for chunk: ['53530WO']
# Failed to fetch details for ['DZ2BBQ']: Status code 400
# No details fetched for chunk: ['DZ2BBQ']
# Failed to fetch details for ['U53491U']: Status code 400
# No details fetched for chunk: ['U53491U']
# Failed to fetch details for ['075C734']: Status code 400
# No details fetched for chunk: ['075C734']
# Failed to fetch details for ['303UP44']: Status code 400
# No details fetched for chunk: ['303UP44']
# Failed to fetch details for ['VENDORB']: Status code 400
# No details fetched for chunk: ['VENDORB']
# Failed to fetch details for ['56VTG6']: Status code 400
# No details fetched for chunk: ['56VTG6']
# Failed to fetch details for ['RK6640']: Status code 400
# No details fetched for chunk: ['RK6640']
# Failed to fetch details for ['2655EA9']: Status code 400
# No details fetched for chunk: ['2655EA9']
# Failed to fetch details for ['421V004']: Status code 400
# No details fetched for chunk: ['421V004']
# Failed to fetch details for ['7793Z08']: Status code 400
# No details fetched for chunk: ['7793Z08']
# Failed to fetch details for ['55PK985']: Status code 400
# No details fetched for chunk: ['55PK985']
# Failed to fetch details for ['6379T']: Status code 400
# No details fetched for chunk: ['6379T']
# Failed to fetch details for ['W04714R']: Status code 400
# No details fetched for chunk: ['W04714R']
# All product details have been processed.
# Product details have been saved to 'processed/grainger_products.parquet'
#
# Head of DataFrame:
#                           Brand    Code  \
# 0                       TSUBAKI   1A912
# 1  LION FIRE BOOTS BY THOROGOOD   3XRG7
# 2           GLOWEAR BY ERGODYNE   1CXK5
# 3                      PEERLESS  39R838
# 4                     TOUGH GUY   4KN42
#
#                                                 Name  \
# 0                  TSUBAKI Chain Detacher: 60 to 100
# 1  Insulated Firefighter Boots: Insulated, Steel,...
# 2  GLOWEAR BY ERGODYNE Baseball Cap: Orange, Univ...
# 3                          Tire Chain: Passenger, Pr
# 4  TOUGH GUY Trash Bags: 56 gal Capacity, 43 in W...
#
#                                        PictureUrl600    Price  \
# 0  https://static.grainger.com/rp/s/is/image/Grai...  $137.57
# 1  https://static.grainger.com/rp/s/is/image/Grai...  $197.55
# 2  https://static.grainger.com/rp/s/is/image/Grai...   $13.93
# 3  https://static.grainger.com/rp/s/is/image/Grai...  $102.33
# 4  https://static.grainger.com/rp/s/is/image/Grai...   $75.73
#
#                                          Description
# 0  <p>Chain breakers, also called detachers, are ...
# 1  <p>Thorogood® 807-6003 Insulated Boots are des...
# 2  <p>Baseball hats have a curved brim that shade...
# 3
# 4  <p>Trash bags for soft refuse are made of HDPE...
#
# Tail of DataFrame:
#                       Brand    Code  \
# 3232               ERGODYNE  52NN47
# 3233  CHILL-ITS BY ERGODYNE   2EMK5
# 3234              CLEVELAND  439M26
# 3235                WOOSTER  452D90
# 3236               WESTWARD   2UFU9
#
#                                                    Name  \
# 3232                   Tool Tethering Kit,3 Attachments
# 3233  CHILL-ITS BY ERGODYNE Cooling Hat: Orange, Uni...
# 3234  CLEVELAND Taper Length Drill Bit: 3/16 in Dril...
# 3235  Anti-Slip Tape: Very Coarse, 46 Grit Size, Sol...
# 3236  WESTWARD Mechanics Length Drill Bit: 1/8 in Dr...
#
#                                           PictureUrl600   Price  \
# 3232  https://static.grainger.com/rp/s/is/image/Grai...  $93.71
# 3233  https://static.grainger.com/rp/s/is/image/Grai...  $23.46
# 3234  https://static.grainger.com/rp/s/is/image/Grai...  $11.18
# 3235  https://static.grainger.com/rp/s/is/image/Grai...  $26.20
# 3236  https://static.grainger.com/rp/s/is/image/Grai...   $1.67
#
#                                             Description
# 3232                                               None
# 3233  <p>Baseball hats have a curved brim that shade...
# 3234  <p>These drill bits come in standard sizes exp...
# 3235  <p>This antislip tape has a coarse mineral-coa...
# 3236  <p>The black-and-gold-oxide finish on these dr...
#
# Size of DataFrame: 19422
#
# Values in DataFrame:
# [['TSUBAKI' '1A912' 'TSUBAKI Chain Detacher: 60 to 100'
#   'https://static.grainger.com/rp/s/is/image/Grainger/1A911_AS01?$lgmain$'
#   '$137.57'
#   '<p>Chain breakers, also called detachers, are devices that apply manual force to remove individual roller chain links from a chain. They drive out the pins on the link without damaging the link plates.</p>']
#  ['LION FIRE BOOTS BY THOROGOOD' '3XRG7'
#   'Insulated Firefighter Boots: Insulated, Steel, 10-1/2, M, Structural, 1 PR'
#   'https://static.grainger.com/rp/s/is/image/Grainger/3XRG3_AS05?$lgmain$'
#   '$197.55'
#   '<p>Thorogood® 807-6003 Insulated Boots are designed for use by firefighters in demanding applications. They feature vulcanized rubber construction, with double-reinforced pull loops, rubber T-toes for extra durability, oversized steel toe caps, reflective instep and heel patches, and removable polyurethane insoles.</p>']
#  ['GLOWEAR BY ERGODYNE' '1CXK5'
#   'GLOWEAR BY ERGODYNE Baseball Cap: Orange, Universal, Baseball Hat Hat, Polyester, Gen Purpose'
#   'https://static.grainger.com/rp/s/is/image/Grainger/1CXK5_AS04?$lgmain$'
#   '$13.93'
#   '<p>Baseball hats have a curved brim that shades the eyes from sun to reduce eye strain and improve visibility.</p>']
#  ...
#  ['CLEVELAND' '439M26'
#   'CLEVELAND Taper Length Drill Bit: 3/16 in Drill Bit Size, 3 3/8 in Flute Lg, 3/16 in Shank Dia., 4xD'
#   'https://static.grainger.com/rp/s/is/image/Grainger/439D72_GC01?$lgmain$'
#   '$11.18'
#   "<p>These drill bits come in standard sizes expressed in fractional inches. The bits have a black-oxide finish that retains lubricants to improve the bits' wear resistance and chip flow. Black-oxide bits should only be used for drilling ferrous metals. High-speed steel drill bits provide more flexibility and absorb more shock and vibration than cobalt and carbide drill bits, making them suitable for use in manual drilling machines and handheld power tools. They may leave a rough finish on the hole. These bits have spiral flutes that evacuate chips as the bits drill into a workpiece.</p>"]
#  ['WOOSTER' '452D90'
#   'Anti-Slip Tape: Very Coarse, 46 Grit Size, Solid, Black, 2 in x 60 ft, 42 mil Tape Thick, Acrylic'
#   'https://static.grainger.com/rp/s/is/image/Grainger/452D90_AS01?$lgmain$'
#   '$26.20'
#   '<p>This antislip tape has a coarse mineral-coated abrasive for high slip resistance in areas with heavy foot and equipment traffic. This durable, high-friction tape is used in muddy, greasy, and oily conditions, such as on construction and farm equipment.</p>']
#  ['WESTWARD' '2UFU9'
#   'WESTWARD Mechanics Length Drill Bit: 1/8 in Drill Bit Size, 1 7/16 in Flute Lg, 1/8 in Shank Dia.'
#   'https://static.grainger.com/rp/s/is/image/Grainger/2UFU5_GC01?$lgmain$'
#   '$1.67'
#   '<p>The black-and-gold-oxide finish on these drill bits lubricates the drill bit and provides some resistance to wear and rust. The bits are made from high-speed steel, which provides some flexibility and absorbs some shock and vibration.</p>']]

# %%
# FETCH DATA ON PRODUCT CODES FROM URL AND SAVE AS DATA FRAME
# UPDATE THE JSON FILE WITH VALID PRODUCT CODES
import os
import requests
import pandas as pd
import json

# Base URL and headers for the API
base_url = "https://mobile-rest-qa.nonprod.graingercloud.com/v1/product/detail"
headers = {
    "Content-Type": "application/json"
}

# Function to fetch and process data
def fetch_product_details(skus):
    params = {
        "partNumbers": skus,
        "extraInfo": "false"
    }
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code == 200:
        try:
            data = response.json()
            results = []
            for item in data:
                brand = item.get("brand", {}).get("name", "N/A")
                code = item.get("code", "N/A")
                name = item.get("name", "N/A")
                picture_url = item.get("pictureUrl600", "N/A")
                price = item.get("priceData", {}).get("formattedPrice", "N/A")
                description = item.get("productDetailsDescription", "N/A")

                results.append({
                    "Brand": brand,
                    "Code": code,
                    "Name": name,
                    "PictureUrl600": picture_url,
                    "Price": price,
                    "Description": description
                })

            return pd.DataFrame(results) if results else None
        except Exception as e:
            print(f"Error parsing response for {skus}: {e}")
            return None
    else:
        print(f"Failed to fetch details for {skus}: Status code {response.status_code}")
        return None

# Load the product codes from the JSON file
with open('all_product_codes.json', 'r') as f:
    product_codes = json.load(f)

# Product codes in chunks of 100
chunk_size = 1
chunks = [product_codes[i:i + chunk_size] for i in range(0, len(product_codes), chunk_size)]

# Iterate over each chunk for API requests
df = pd.DataFrame(columns=["Brand", "Code", "Name", "PictureUrl600", "Price", "Description"])
failed_chunks = []
for chunk in chunks:
    try:
        details = fetch_product_details(chunk)
        if details is not None:
            df = pd.concat([df, details], ignore_index=True)
        else:
            print(f"No details fetched for chunk: {chunk}. Removing from source.")
            failed_chunks.extend(chunk)
    except Exception as e:
        print(f"Failed to fetch details for chunk: {chunk}, Error: {e}")
        failed_chunks.extend(chunk)

# Remove failed product codes from the source list
product_codes = [code for code in product_codes if code not in failed_chunks]

# Save the updated product codes to the JSON file
with open('all_product_codes.json', 'w') as f:
    json.dump(product_codes, f, indent=4)

# Remove rows where all columns are NaN
df = df.dropna(how='all')

# Ensure all column names are strings
df.columns = df.columns.astype(str)

# Save to Parquet
os.makedirs('processed', exist_ok=True)
df.to_parquet('processed/grainger_products.parquet', index=False)
print("Product details have been saved to 'processed/grainger_products.parquet'")
print("\nHead of DataFrame:")
print(df.head(), "\n")
print("Tail of DataFrame:")
print(df.tail(), "\n")
print("Size of DataFrame:", df.size, "\n")
print("Values in DataFrame:")
print(df.values)
# Out:
# Failed to fetch details for ['182UFW9']: Status code 400
# No details fetched for chunk: ['182UFW9']. Removing from source.
# Failed to fetch details for ['04103']: Status code 400
# No details fetched for chunk: ['04103']. Removing from source.
# Failed to fetch details for ['97429T7']: Status code 400
# No details fetched for chunk: ['97429T7']. Removing from source.
# Failed to fetch details for ['ZEREXH']: Status code 400
# No details fetched for chunk: ['ZEREXH']. Removing from source.
# Failed to fetch details for ['ICHELIN']: Status code 400
# No details fetched for chunk: ['ICHELIN']. Removing from source.
# Failed to fetch details for ['6391H']: Status code 400
# No details fetched for chunk: ['6391H']. Removing from source.
# Failed to fetch details for ['00818HC']: Status code 400
# No details fetched for chunk: ['00818HC']. Removing from source.
# Failed to fetch details for ['40R19']: Status code 400
# No details fetched for chunk: ['40R19']. Removing from source.
# Failed to fetch details for ['ALTERNA']: Status code 400
# No details fetched for chunk: ['ALTERNA']. Removing from source.
# Failed to fetch details for ['FOOTWEA']: Status code 400
# No details fetched for chunk: ['FOOTWEA']. Removing from source.
# Failed to fetch details for ['0846C11']: Status code 400
# No details fetched for chunk: ['0846C11']. Removing from source.
# Failed to fetch details for ['MERET']: Status code 400
# No details fetched for chunk: ['MERET']. Removing from source.
# Failed to fetch details for ['2L18018']: Status code 400
# No details fetched for chunk: ['2L18018']. Removing from source.
# Failed to fetch details for ['2813X77']: Status code 400
# No details fetched for chunk: ['2813X77']. Removing from source.
# Failed to fetch details for ['10031DL']: Status code 400
# No details fetched for chunk: ['10031DL']. Removing from source.
# Failed to fetch details for ['341UKH6']: Status code 400
# No details fetched for chunk: ['341UKH6']. Removing from source.
# Failed to fetch details for ['4C13794']: Status code 400
# No details fetched for chunk: ['4C13794']. Removing from source.
# Failed to fetch details for ['504YPD1']: Status code 400
# No details fetched for chunk: ['504YPD1']. Removing from source.
# Failed to fetch details for ['EM7252E']: Status code 400
# No details fetched for chunk: ['EM7252E']. Removing from source.
# Failed to fetch details for ['40KJ09C']: Status code 400
# No details fetched for chunk: ['40KJ09C']. Removing from source.
# Failed to fetch details for ['9WX7043']: Status code 400
# No details fetched for chunk: ['9WX7043']. Removing from source.
# Failed to fetch details for ['90670']: Status code 400
# No details fetched for chunk: ['90670']. Removing from source.
# Failed to fetch details for ['0515F21']: Status code 400
# No details fetched for chunk: ['0515F21']. Removing from source.
# Failed to fetch details for ['65R17']: Status code 400
# No details fetched for chunk: ['65R17']. Removing from source.
# Failed to fetch details for ['274GB90']: Status code 400
# No details fetched for chunk: ['274GB90']. Removing from source.
# Failed to fetch details for ['OVERINE']: Status code 400
# No details fetched for chunk: ['OVERINE']. Removing from source.
# Failed to fetch details for ['TC02C']: Status code 400
# No details fetched for chunk: ['TC02C']. Removing from source.
# Failed to fetch details for ['173MUE5']: Status code 400
# No details fetched for chunk: ['173MUE5']. Removing from source.
# Failed to fetch details for ['8553WN5']: Status code 400
# No details fetched for chunk: ['8553WN5']. Removing from source.
# Failed to fetch details for ['2REEBOK']: Status code 400
# No details fetched for chunk: ['2REEBOK']. Removing from source.
# Failed to fetch details for ['992TGC7']: Status code 400
# No details fetched for chunk: ['992TGC7']. Removing from source.
# Failed to fetch details for ['8G843']: Status code 500
# No details fetched for chunk: ['8G843']. Removing from source.
# Failed to fetch details for ['116765']: Status code 400
# No details fetched for chunk: ['116765']. Removing from source.
# Failed to fetch details for ['817F52']: Status code 400
# No details fetched for chunk: ['817F52']. Removing from source.
# Failed to fetch details for ['116207']: Status code 400
# No details fetched for chunk: ['116207']. Removing from source.
# Failed to fetch details for ['39R839L']: Status code 400
# No details fetched for chunk: ['39R839L']. Removing from source.
# Failed to fetch details for ['P89135W']: Status code 400
# No details fetched for chunk: ['P89135W']. Removing from source.
# Failed to fetch details for ['WOOSTER']: Status code 400
# No details fetched for chunk: ['WOOSTER']. Removing from source.
# Failed to fetch details for ['P90439D']: Status code 400
# No details fetched for chunk: ['P90439D']. Removing from source.
# Failed to fetch details for ['846KEC3']: Status code 400
# No details fetched for chunk: ['846KEC3']. Removing from source.
# Failed to fetch details for ['FS2650C']: Status code 400
# No details fetched for chunk: ['FS2650C']. Removing from source.
# Failed to fetch details for ['1029XM5']: Status code 400
# No details fetched for chunk: ['1029XM5']. Removing from source.
# Failed to fetch details for ['VA225']: Status code 400
# No details fetched for chunk: ['VA225']. Removing from source.
# Failed to fetch details for ['86515TI']: Status code 400
# No details fetched for chunk: ['86515TI']. Removing from source.
# Failed to fetch details for ['3A1F297']: Status code 400
# No details fetched for chunk: ['3A1F297']. Removing from source.
# Failed to fetch details for ['ASSISTA']: Status code 400
# No details fetched for chunk: ['ASSISTA']. Removing from source.
# Failed to fetch details for ['RB4310K']: Status code 400
# No details fetched for chunk: ['RB4310K']. Removing from source.
# Failed to fetch details for ['92641KE']: Status code 400
# No details fetched for chunk: ['92641KE']. Removing from source.
# Failed to fetch details for ['53531AR']: Status code 400
# No details fetched for chunk: ['53531AR']. Removing from source.
# Failed to fetch details for ['43A5954']: Status code 400
# No details fetched for chunk: ['43A5954']. Removing from source.
# Failed to fetch details for ['543A706']: Status code 400
# No details fetched for chunk: ['543A706']. Removing from source.
# Failed to fetch details for ['246KEA0']: Status code 400
# No details fetched for chunk: ['246KEA0']. Removing from source.
# Failed to fetch details for ['1652WH3']: Status code 400
# No details fetched for chunk: ['1652WH3']. Removing from source.
# Failed to fetch details for ['46256']: Status code 400
# No details fetched for chunk: ['46256']. Removing from source.
# Failed to fetch details for ['404K74M']: Status code 400
# No details fetched for chunk: ['404K74M']. Removing from source.
# Failed to fetch details for ['FUNCTIO']: Status code 400
# No details fetched for chunk: ['FUNCTIO']. Removing from source.
# Failed to fetch details for ['49430']: Status code 400
# No details fetched for chunk: ['49430']. Removing from source.
# Failed to fetch details for ['955EC12']: Status code 400
# No details fetched for chunk: ['955EC12']. Removing from source.
# Failed to fetch details for ['355JK37']: Status code 400
# No details fetched for chunk: ['355JK37']. Removing from source.
# Failed to fetch details for ['985RXG3']: Status code 400
# No details fetched for chunk: ['985RXG3']. Removing from source.
# Failed to fetch details for ['43C0314']: Status code 400
# No details fetched for chunk: ['43C0314']. Removing from source.
# Failed to fetch details for ['6804AZ5']: Status code 400
# No details fetched for chunk: ['6804AZ5']. Removing from source.
# Failed to fetch details for ['IP54I']: Status code 400
# No details fetched for chunk: ['IP54I']. Removing from source.
# Failed to fetch details for ['8044208']: Status code 400
# No details fetched for chunk: ['8044208']. Removing from source.
# Failed to fetch details for ['30R20']: Status code 400
# No details fetched for chunk: ['30R20']. Removing from source.
# Failed to fetch details for ['6638M50']: Status code 400
# No details fetched for chunk: ['6638M50']. Removing from source.
# Failed to fetch details for ['91712M']: Status code 400
# No details fetched for chunk: ['91712M']. Removing from source.
# Failed to fetch details for ['1505BB5']: Status code 400
# No details fetched for chunk: ['1505BB5']. Removing from source.
# Failed to fetch details for ['43A6034']: Status code 400
# No details fetched for chunk: ['43A6034']. Removing from source.
# Failed to fetch details for ['77055W']: Status code 400
# No details fetched for chunk: ['77055W']. Removing from source.
# Failed to fetch details for ['EHSLP']: Status code 400
# No details fetched for chunk: ['EHSLP']. Removing from source.
# Failed to fetch details for ['83JY32S']: Status code 400
# No details fetched for chunk: ['83JY32S']. Removing from source.
# Failed to fetch details for ['SQWINCH']: Status code 400
# No details fetched for chunk: ['SQWINCH']. Removing from source.
# Failed to fetch details for ['U53490U']: Status code 400
# No details fetched for chunk: ['U53490U']. Removing from source.
# Failed to fetch details for ['LOCKOUT']: Status code 400
# No details fetched for chunk: ['LOCKOUT']. Removing from source.
# Failed to fetch details for ['JOHNSON']: Status code 400
# No details fetched for chunk: ['JOHNSON']. Removing from source.
# Failed to fetch details for ['1849ZY4']: Status code 400
# No details fetched for chunk: ['1849ZY4']. Removing from source.
# Failed to fetch details for ['FALCON']: Status code 400
# No details fetched for chunk: ['FALCON']. Removing from source.
# Failed to fetch details for ['2515X10']: Status code 400
# No details fetched for chunk: ['2515X10']. Removing from source.
# Failed to fetch details for ['OTHERWI']: Status code 400
# No details fetched for chunk: ['OTHERWI']. Removing from source.
# Failed to fetch details for ['W10765R']: Status code 400
# No details fetched for chunk: ['W10765R']. Removing from source.
# Failed to fetch details for ['32814']: Status code 400
# No details fetched for chunk: ['32814']. Removing from source.
# Failed to fetch details for ['CA7521A']: Status code 400
# No details fetched for chunk: ['CA7521A']. Removing from source.
# Failed to fetch details for ['5004KN3']: Status code 400
# No details fetched for chunk: ['5004KN3']. Removing from source.
# Failed to fetch details for ['152EM59']: Status code 400
# No details fetched for chunk: ['152EM59']. Removing from source.
# Failed to fetch details for ['A60543A']: Status code 400
# No details fetched for chunk: ['A60543A']. Removing from source.
# Failed to fetch details for ['23L220M']: Status code 400
# No details fetched for chunk: ['23L220M']. Removing from source.
# Failed to fetch details for ['A7751DE']: Status code 400
# No details fetched for chunk: ['A7751DE']. Removing from source.
# Failed to fetch details for ['2Z61012']: Status code 400
# No details fetched for chunk: ['2Z61012']. Removing from source.
# Failed to fetch details for ['EXTENT']: Status code 400
# No details fetched for chunk: ['EXTENT']. Removing from source.
# Failed to fetch details for ['5149YN1']: Status code 400
# No details fetched for chunk: ['5149YN1']. Removing from source.
# Failed to fetch details for ['56JH14M']: Status code 400
# No details fetched for chunk: ['56JH14M']. Removing from source.
# Failed to fetch details for ['9PAE1']: Status code 500
# No details fetched for chunk: ['9PAE1']. Removing from source.
# Failed to fetch details for ['2561UU3']: Status code 400
# No details fetched for chunk: ['2561UU3']. Removing from source.
# Failed to fetch details for ['240VI']: Status code 400
# No details fetched for chunk: ['240VI']. Removing from source.
# Failed to fetch details for ['V18111C']: Status code 400
# No details fetched for chunk: ['V18111C']. Removing from source.
# Failed to fetch details for ['4660YG4']: Status code 400
# No details fetched for chunk: ['4660YG4']. Removing from source.
# Failed to fetch details for ['3800W60']: Status code 400
# No details fetched for chunk: ['3800W60']. Removing from source.
# Failed to fetch details for ['3360NN2']: Status code 400
# No details fetched for chunk: ['3360NN2']. Removing from source.
# Failed to fetch details for ['STANLEY']: Status code 400
# No details fetched for chunk: ['STANLEY']. Removing from source.
# Failed to fetch details for ['3A1LSI0']: Status code 400
# No details fetched for chunk: ['3A1LSI0']. Removing from source.
# Failed to fetch details for ['68491V6']: Status code 400
# No details fetched for chunk: ['68491V6']. Removing from source.
# Failed to fetch details for ['512TGE4']: Status code 400
# No details fetched for chunk: ['512TGE4']. Removing from source.
# Failed to fetch details for ['43A6104']: Status code 400
# No details fetched for chunk: ['43A6104']. Removing from source.
# Failed to fetch details for ['1PKC7M']: Status code 400
# No details fetched for chunk: ['1PKC7M']. Removing from source.
# Failed to fetch details for ['749ZY38']: Status code 400
# No details fetched for chunk: ['749ZY38']. Removing from source.
# Failed to fetch details for ['99404K0']: Status code 400
# No details fetched for chunk: ['99404K0']. Removing from source.
# Failed to fetch details for ['EMAIL']: Status code 400
# No details fetched for chunk: ['EMAIL']. Removing from source.
# Failed to fetch details for ['84643P9']: Status code 400
# No details fetched for chunk: ['84643P9']. Removing from source.
# Failed to fetch details for ['21687']: Status code 400
# No details fetched for chunk: ['21687']. Removing from source.
# Failed to fetch details for ['0JV4800']: Status code 400
# No details fetched for chunk: ['0JV4800']. Removing from source.
# Failed to fetch details for ['F2100']: Status code 400
# No details fetched for chunk: ['F2100']. Removing from source.
# Failed to fetch details for ['213BB62']: Status code 400
# No details fetched for chunk: ['213BB62']. Removing from source.
# Failed to fetch details for ['35WX79C']: Status code 400
# No details fetched for chunk: ['35WX79C']. Removing from source.
# Failed to fetch details for ['13860RE']: Status code 400
# No details fetched for chunk: ['13860RE']. Removing from source.
# Failed to fetch details for ['1027109']: Status code 400
# No details fetched for chunk: ['1027109']. Removing from source.
# Failed to fetch details for ['MISUSE']: Status code 400
# No details fetched for chunk: ['MISUSE']. Removing from source.
# Failed to fetch details for ['0724EM4']: Status code 400
# No details fetched for chunk: ['0724EM4']. Removing from source.
# Failed to fetch details for ['15631']: Status code 400
# No details fetched for chunk: ['15631']. Removing from source.
# Failed to fetch details for ['44491K3']: Status code 400
# No details fetched for chunk: ['44491K3']. Removing from source.
# Failed to fetch details for ['71109']: Status code 400
# No details fetched for chunk: ['71109']. Removing from source.
# Failed to fetch details for ['53797T8']: Status code 400
# No details fetched for chunk: ['53797T8']. Removing from source.
# Failed to fetch details for ['RD7860R']: Status code 400
# No details fetched for chunk: ['RD7860R']. Removing from source.
# Failed to fetch details for ['T498B15']: Status code 400
# No details fetched for chunk: ['T498B15']. Removing from source.
# Failed to fetch details for ['48089']: Status code 400
# No details fetched for chunk: ['48089']. Removing from source.
# Failed to fetch details for ['35797T9']: Status code 400
# No details fetched for chunk: ['35797T9']. Removing from source.
# Failed to fetch details for ['15PEERL']: Status code 400
# No details fetched for chunk: ['15PEERL']. Removing from source.
# Failed to fetch details for ['802LK0']: Status code 400
# No details fetched for chunk: ['802LK0']. Removing from source.
# Failed to fetch details for ['00717']: Status code 400
# No details fetched for chunk: ['00717']. Removing from source.
# Failed to fetch details for ['8806XU8']: Status code 400
# No details fetched for chunk: ['8806XU8']. Removing from source.
# Failed to fetch details for ['16813X4']: Status code 400
# No details fetched for chunk: ['16813X4']. Removing from source.
# Failed to fetch details for ['818HC2']: Status code 400
# No details fetched for chunk: ['818HC2']. Removing from source.
# Failed to fetch details for ['BABCOCK']: Status code 400
# No details fetched for chunk: ['BABCOCK']. Removing from source.
# Failed to fetch details for ['2L090']: Status code 500
# No details fetched for chunk: ['2L090']. Removing from source.
# Failed to fetch details for ['35WX78C']: Status code 400
# No details fetched for chunk: ['35WX78C']. Removing from source.
# Failed to fetch details for ['94800HY']: Status code 400
# No details fetched for chunk: ['94800HY']. Removing from source.
# Failed to fetch details for ['Y001THO']: Status code 400
# No details fetched for chunk: ['Y001THO']. Removing from source.
# Failed to fetch details for ['113628C']: Status code 400
# No details fetched for chunk: ['113628C']. Removing from source.
# Failed to fetch details for ['55EC30']: Status code 500
# No details fetched for chunk: ['55EC30']. Removing from source.
# Failed to fetch details for ['464XT29']: Status code 400
# No details fetched for chunk: ['464XT29']. Removing from source.
# Failed to fetch details for ['312KVP1']: Status code 400
# No details fetched for chunk: ['312KVP1']. Removing from source.
# Failed to fetch details for ['1011242']: Status code 400
# No details fetched for chunk: ['1011242']. Removing from source.
# Failed to fetch details for ['TB0A42F']: Status code 400
# No details fetched for chunk: ['TB0A42F']. Removing from source.
# Failed to fetch details for ['5153WN5']: Status code 400
# No details fetched for chunk: ['5153WN5']. Removing from source.
# Failed to fetch details for ['P0121AP']: Status code 400
# No details fetched for chunk: ['P0121AP']. Removing from source.
# Failed to fetch details for ['20115TH']: Status code 400
# No details fetched for chunk: ['20115TH']. Removing from source.
# Failed to fetch details for ['22452D7']: Status code 400
# No details fetched for chunk: ['22452D7']. Removing from source.
# Failed to fetch details for ['89628']: Status code 400
# No details fetched for chunk: ['89628']. Removing from source.
# Failed to fetch details for ['DB019IR']: Status code 400
# No details fetched for chunk: ['DB019IR']. Removing from source.
# Failed to fetch details for ['2491V83']: Status code 400
# No details fetched for chunk: ['2491V83']. Removing from source.
# Failed to fetch details for ['GRAINGE']: Status code 400
# No details fetched for chunk: ['GRAINGE']. Removing from source.
# Failed to fetch details for ['2005C']: Status code 400
# No details fetched for chunk: ['2005C']. Removing from source.
# Failed to fetch details for ['SEARCH']: Status code 400
# No details fetched for chunk: ['SEARCH']. Removing from source.
# Failed to fetch details for ['794D127']: Status code 400
# No details fetched for chunk: ['794D127']. Removing from source.
# Failed to fetch details for ['TURES']: Status code 400
# No details fetched for chunk: ['TURES']. Removing from source.
# Failed to fetch details for ['CUX08CZ']: Status code 400
# No details fetched for chunk: ['CUX08CZ']. Removing from source.
# Failed to fetch details for ['NONINFR']: Status code 400
# No details fetched for chunk: ['NONINFR']. Removing from source.
# Failed to fetch details for ['1401R']: Status code 400
# No details fetched for chunk: ['1401R']. Removing from source.
# Failed to fetch details for ['3813X54']: Status code 400
# No details fetched for chunk: ['3813X54']. Removing from source.
# Failed to fetch details for ['999ZF9']: Status code 500
# No details fetched for chunk: ['999ZF9']. Removing from source.
# Failed to fetch details for ['2EM4952']: Status code 400
# No details fetched for chunk: ['2EM4952']. Removing from source.
# Failed to fetch details for ['ETHANOL']: Status code 400
# No details fetched for chunk: ['ETHANOL']. Removing from source.
# Failed to fetch details for ['1V66491']: Status code 400
# No details fetched for chunk: ['1V66491']. Removing from source.
# Failed to fetch details for ['C62814C']: Status code 400
# No details fetched for chunk: ['C62814C']. Removing from source.
# Failed to fetch details for ['95797T8']: Status code 400
# No details fetched for chunk: ['95797T8']. Removing from source.
# Failed to fetch details for ['TRENDS']: Status code 400
# No details fetched for chunk: ['TRENDS']. Removing from source.
# Failed to fetch details for ['9113V77']: Status code 400
# No details fetched for chunk: ['9113V77']. Removing from source.
# Failed to fetch details for ['146DWL3']: Status code 400
# No details fetched for chunk: ['146DWL3']. Removing from source.
# Failed to fetch details for ['4568KA0']: Status code 400
# No details fetched for chunk: ['4568KA0']. Removing from source.
# Failed to fetch details for ['30PL5']: Status code 400
# No details fetched for chunk: ['30PL5']. Removing from source.
# Failed to fetch details for ['115962']: Status code 400
# No details fetched for chunk: ['115962']. Removing from source.
# Failed to fetch details for ['WTEMPCO']: Status code 400
# No details fetched for chunk: ['WTEMPCO']. Removing from source.
# Failed to fetch details for ['2843A76']: Status code 400
# No details fetched for chunk: ['2843A76']. Removing from source.
# Failed to fetch details for ['A1KBWTI']: Status code 400
# No details fetched for chunk: ['A1KBWTI']. Removing from source.
# Failed to fetch details for ['BENEFIT']: Status code 400
# No details fetched for chunk: ['BENEFIT']. Removing from source.
# Failed to fetch details for ['SPSC261']: Status code 400
# No details fetched for chunk: ['SPSC261']. Removing from source.
# Failed to fetch details for ['4HPU1']: Status code 500
# No details fetched for chunk: ['4HPU1']. Removing from source.
# Failed to fetch details for ['13552CG']: Status code 400
# No details fetched for chunk: ['13552CG']. Removing from source.
# Failed to fetch details for ['116378']: Status code 400
# No details fetched for chunk: ['116378']. Removing from source.
# Failed to fetch details for ['JK5655J']: Status code 400
# No details fetched for chunk: ['JK5655J']. Removing from source.
# Failed to fetch details for ['HOMELAN']: Status code 400
# No details fetched for chunk: ['HOMELAN']. Removing from source.
# Failed to fetch details for ['43A8474']: Status code 400
# No details fetched for chunk: ['43A8474']. Removing from source.
# Failed to fetch details for ['843C019']: Status code 400
# No details fetched for chunk: ['843C019']. Removing from source.
# Failed to fetch details for ['093VRZ8']: Status code 400
# No details fetched for chunk: ['093VRZ8']. Removing from source.
# Failed to fetch details for ['35XF763']: Status code 400
# No details fetched for chunk: ['35XF763']. Removing from source.
# Failed to fetch details for ['RB417RE']: Status code 400
# No details fetched for chunk: ['RB417RE']. Removing from source.
# Failed to fetch details for ['CORTECH']: Status code 400
# No details fetched for chunk: ['CORTECH']. Removing from source.
# Failed to fetch details for ['DNESS']: Status code 400
# No details fetched for chunk: ['DNESS']. Removing from source.
# Failed to fetch details for ['02458T2']: Status code 400
# No details fetched for chunk: ['02458T2']. Removing from source.
# Failed to fetch details for ['4241HG9']: Status code 400
# No details fetched for chunk: ['4241HG9']. Removing from source.
# Failed to fetch details for ['5LE23C']: Status code 400
# No details fetched for chunk: ['5LE23C']. Removing from source.
# Failed to fetch details for ['3955EE6']: Status code 400
# No details fetched for chunk: ['3955EE6']. Removing from source.
# Failed to fetch details for ['48799H7']: Status code 400
# No details fetched for chunk: ['48799H7']. Removing from source.
# Failed to fetch details for ['6VTG8']: Status code 404
# No details fetched for chunk: ['6VTG8']. Removing from source.
# Failed to fetch details for ['014GB73']: Status code 400
# No details fetched for chunk: ['014GB73']. Removing from source.
# Failed to fetch details for ['XRP53XR']: Status code 400
# No details fetched for chunk: ['XRP53XR']. Removing from source.
# Failed to fetch details for ['SLOAN']: Status code 400
# No details fetched for chunk: ['SLOAN']. Removing from source.
# Failed to fetch details for ['ASMEIND']: Status code 400
# No details fetched for chunk: ['ASMEIND']. Removing from source.
# Failed to fetch details for ['DRAEGER']: Status code 400
# No details fetched for chunk: ['DRAEGER']. Removing from source.
# Failed to fetch details for ['CLEAN']: Status code 400
# No details fetched for chunk: ['CLEAN']. Removing from source.
# Failed to fetch details for ['W10633T']: Status code 400
# No details fetched for chunk: ['W10633T']. Removing from source.
# Failed to fetch details for ['SIMPLEH']: Status code 400
# No details fetched for chunk: ['SIMPLEH']. Removing from source.
# Failed to fetch details for ['5043Y97']: Status code 400
# No details fetched for chunk: ['5043Y97']. Removing from source.
# Failed to fetch details for ['63103']: Status code 400
# No details fetched for chunk: ['63103']. Removing from source.
# Failed to fetch details for ['6849VU2']: Status code 400
# No details fetched for chunk: ['6849VU2']. Removing from source.
# Failed to fetch details for ['QMARKO']: Status code 400
# No details fetched for chunk: ['QMARKO']. Removing from source.
# Failed to fetch details for ['8RWK7']: Status code 500
# No details fetched for chunk: ['8RWK7']. Removing from source.
# Failed to fetch details for ['1003577']: Status code 400
# No details fetched for chunk: ['1003577']. Removing from source.
# Failed to fetch details for ['TB0A1Z4']: Status code 400
# No details fetched for chunk: ['TB0A1Z4']. Removing from source.
# Failed to fetch details for ['RB4555R']: Status code 400
# No details fetched for chunk: ['RB4555R']. Removing from source.
# Failed to fetch details for ['XLKLEEN']: Status code 400
# No details fetched for chunk: ['XLKLEEN']. Removing from source.
# Failed to fetch details for ['4255EE4']: Status code 400
# No details fetched for chunk: ['4255EE4']. Removing from source.
# Failed to fetch details for ['G8374NE']: Status code 400
# No details fetched for chunk: ['G8374NE']. Removing from source.
# Failed to fetch details for ['REARR12']: Status code 400
# No details fetched for chunk: ['REARR12']. Removing from source.
# Failed to fetch details for ['91459H3']: Status code 400
# No details fetched for chunk: ['91459H3']. Removing from source.
# Failed to fetch details for ['T4J171']: Status code 400
# No details fetched for chunk: ['T4J171']. Removing from source.
# Failed to fetch details for ['42796FY']: Status code 400
# No details fetched for chunk: ['42796FY']. Removing from source.
# Failed to fetch details for ['14817GV']: Status code 400
# No details fetched for chunk: ['14817GV']. Removing from source.
# Failed to fetch details for ['M474WR9']: Status code 400
# No details fetched for chunk: ['M474WR9']. Removing from source.
# Failed to fetch details for ['9LGA88R']: Status code 400
# No details fetched for chunk: ['9LGA88R']. Removing from source.
# Failed to fetch details for ['55420']: Status code 400
# No details fetched for chunk: ['55420']. Removing from source.
# Failed to fetch details for ['35R19']: Status code 400
# No details fetched for chunk: ['35R19']. Removing from source.
# Failed to fetch details for ['25002']: Status code 400
# No details fetched for chunk: ['25002']. Removing from source.
# Failed to fetch details for ['813X81']: Status code 400
# No details fetched for chunk: ['813X81']. Removing from source.
# Failed to fetch details for ['392UFW5']: Status code 400
# No details fetched for chunk: ['392UFW5']. Removing from source.
# Failed to fetch details for ['84343A8']: Status code 400
# No details fetched for chunk: ['84343A8']. Removing from source.
# Failed to fetch details for ['01353']: Status code 400
# No details fetched for chunk: ['01353']. Removing from source.
# Failed to fetch details for ['2112V']: Status code 400
# No details fetched for chunk: ['2112V']. Removing from source.
# Failed to fetch details for ['9054DF2']: Status code 400
# No details fetched for chunk: ['9054DF2']. Removing from source.
# Failed to fetch details for ['799Z41']: Status code 500
# No details fetched for chunk: ['799Z41']. Removing from source.
# Failed to fetch details for ['6AGK7M']: Status code 400
# No details fetched for chunk: ['6AGK7M']. Removing from source.
# Failed to fetch details for ['103WUP6']: Status code 400
# No details fetched for chunk: ['103WUP6']. Removing from source.
# Failed to fetch details for ['26078AR']: Status code 400
# No details fetched for chunk: ['26078AR']. Removing from source.
# Failed to fetch details for ['BLNEW']: Status code 400
# No details fetched for chunk: ['BLNEW']. Removing from source.
# Failed to fetch details for ['16501']: Status code 400
# No details fetched for chunk: ['16501']. Removing from source.
# Failed to fetch details for ['AMETEK']: Status code 400
# No details fetched for chunk: ['AMETEK']. Removing from source.
# Failed to fetch details for ['FQ00062']: Status code 400
# No details fetched for chunk: ['FQ00062']. Removing from source.
# Failed to fetch details for ['TB1A1XJ']: Status code 400
# No details fetched for chunk: ['TB1A1XJ']. Removing from source.
# Failed to fetch details for ['6512N63']: Status code 400
# No details fetched for chunk: ['6512N63']. Removing from source.
# Failed to fetch details for ['MEDICF']: Status code 400
# No details fetched for chunk: ['MEDICF']. Removing from source.
# Failed to fetch details for ['91U4149']: Status code 400
# No details fetched for chunk: ['91U4149']. Removing from source.
# Failed to fetch details for ['23443']: Status code 400
# No details fetched for chunk: ['23443']. Removing from source.
# Failed to fetch details for ['36794DV']: Status code 400
# No details fetched for chunk: ['36794DV']. Removing from source.
# Failed to fetch details for ['87813X6']: Status code 400
# No details fetched for chunk: ['87813X6']. Removing from source.
# Failed to fetch details for ['59101']: Status code 400
# No details fetched for chunk: ['59101']. Removing from source.
# Failed to fetch details for ['117TH']: Status code 400
# No details fetched for chunk: ['117TH']. Removing from source.
# Failed to fetch details for ['1002949']: Status code 400
# No details fetched for chunk: ['1002949']. Removing from source.
# Failed to fetch details for ['VITAL']: Status code 400
# No details fetched for chunk: ['VITAL']. Removing from source.
# Failed to fetch details for ['ARIES']: Status code 400
# No details fetched for chunk: ['ARIES']. Removing from source.
# Failed to fetch details for ['7552WX8']: Status code 400
# No details fetched for chunk: ['7552WX8']. Removing from source.
# Failed to fetch details for ['PL78RMF']: Status code 400
# No details fetched for chunk: ['PL78RMF']. Removing from source.
# Failed to fetch details for ['3491U94']: Status code 400
# No details fetched for chunk: ['3491U94']. Removing from source.
# Failed to fetch details for ['41CR16M']: Status code 400
# No details fetched for chunk: ['41CR16M']. Removing from source.
# Failed to fetch details for ['PARTITI']: Status code 400
# No details fetched for chunk: ['PARTITI']. Removing from source.
# Failed to fetch details for ['CROSS']: Status code 400
# No details fetched for chunk: ['CROSS']. Removing from source.
# Failed to fetch details for ['1023228']: Status code 400
# No details fetched for chunk: ['1023228']. Removing from source.
# Failed to fetch details for ['BUYERS']: Status code 400
# No details fetched for chunk: ['BUYERS']. Removing from source.
# Failed to fetch details for ['LOG9200']: Status code 400
# No details fetched for chunk: ['LOG9200']. Removing from source.
# Failed to fetch details for ['PREMIUM']: Status code 400
# No details fetched for chunk: ['PREMIUM']. Removing from source.
# Failed to fetch details for ['920025C']: Status code 400
# No details fetched for chunk: ['920025C']. Removing from source.
# Failed to fetch details for ['3001TIM']: Status code 400
# No details fetched for chunk: ['3001TIM']. Removing from source.
# Failed to fetch details for ['714GB71']: Status code 400
# No details fetched for chunk: ['714GB71']. Removing from source.
# Failed to fetch details for ['CANCELL']: Status code 400
# No details fetched for chunk: ['CANCELL']. Removing from source.
# Failed to fetch details for ['584DJW3']: Status code 400
# No details fetched for chunk: ['584DJW3']. Removing from source.
# Failed to fetch details for ['CUSTOME']: Status code 400
# No details fetched for chunk: ['CUSTOME']. Removing from source.
# Failed to fetch details for ['974GB68']: Status code 400
# No details fetched for chunk: ['974GB68']. Removing from source.
# Failed to fetch details for ['3ANBE98']: Status code 400
# No details fetched for chunk: ['3ANBE98']. Removing from source.
# Failed to fetch details for ['433DRN1']: Status code 400
# No details fetched for chunk: ['433DRN1']. Removing from source.
# Failed to fetch details for ['4C62414']: Status code 400
# No details fetched for chunk: ['4C62414']. Removing from source.
# Failed to fetch details for ['745VK78']: Status code 400
# No details fetched for chunk: ['745VK78']. Removing from source.
# Failed to fetch details for ['L59FAX2']: Status code 400
# No details fetched for chunk: ['L59FAX2']. Removing from source.
# Failed to fetch details for ['878ADP8']: Status code 400
# No details fetched for chunk: ['878ADP8']. Removing from source.
# Failed to fetch details for ['132RB16']: Status code 400
# No details fetched for chunk: ['132RB16']. Removing from source.
# Failed to fetch details for ['DIVERSE']: Status code 400
# No details fetched for chunk: ['DIVERSE']. Removing from source.
# Failed to fetch details for ['01243C0']: Status code 400
# No details fetched for chunk: ['01243C0']. Removing from source.
# Failed to fetch details for ['2XN3732']: Status code 400
# No details fetched for chunk: ['2XN3732']. Removing from source.
# Failed to fetch details for ['VP32KVP']: Status code 400
# No details fetched for chunk: ['VP32KVP']. Removing from source.
# Failed to fetch details for ['18197JM']: Status code 400
# No details fetched for chunk: ['18197JM']. Removing from source.
# Failed to fetch details for ['NSPSC41']: Status code 400
# No details fetched for chunk: ['NSPSC41']. Removing from source.
# Failed to fetch details for ['INTELLE']: Status code 400
# No details fetched for chunk: ['INTELLE']. Removing from source.
# Failed to fetch details for ['1492U32']: Status code 400
# No details fetched for chunk: ['1492U32']. Removing from source.
# Failed to fetch details for ['CME8355']: Status code 400
# No details fetched for chunk: ['CME8355']. Removing from source.
# Failed to fetch details for ['TECHNOL']: Status code 400
# No details fetched for chunk: ['TECHNOL']. Removing from source.
# Failed to fetch details for ['RB874GR']: Status code 400
# No details fetched for chunk: ['RB874GR']. Removing from source.
# Failed to fetch details for ['A7402']: Status code 400
# No details fetched for chunk: ['A7402']. Removing from source.
# Failed to fetch details for ['78408']: Status code 400
# No details fetched for chunk: ['78408']. Removing from source.
# Failed to fetch details for ['6660JD2']: Status code 400
# No details fetched for chunk: ['6660JD2']. Removing from source.
# Failed to fetch details for ['70498X6']: Status code 400
# No details fetched for chunk: ['70498X6']. Removing from source.
# Failed to fetch details for ['75247']: Status code 400
# No details fetched for chunk: ['75247']. Removing from source.
# Failed to fetch details for ['6529RW0']: Status code 400
# No details fetched for chunk: ['6529RW0']. Removing from source.
# Failed to fetch details for ['HTRAM']: Status code 400
# No details fetched for chunk: ['HTRAM']. Removing from source.
# Failed to fetch details for ['00J1780']: Status code 400
# No details fetched for chunk: ['00J1780']. Removing from source.
# Failed to fetch details for ['8038101']: Status code 400
# No details fetched for chunk: ['8038101']. Removing from source.
# Failed to fetch details for ['976UTD1']: Status code 400
# No details fetched for chunk: ['976UTD1']. Removing from source.
# Failed to fetch details for ['8242TIM']: Status code 400
# No details fetched for chunk: ['8242TIM']. Removing from source.
# Failed to fetch details for ['1YNG3']: Status code 500
# No details fetched for chunk: ['1YNG3']. Removing from source.
# Failed to fetch details for ['92507']: Status code 400
# No details fetched for chunk: ['92507']. Removing from source.
# Failed to fetch details for ['M7752EM']: Status code 400
# No details fetched for chunk: ['M7752EM']. Removing from source.
# Failed to fetch details for ['6860NT6']: Status code 400
# No details fetched for chunk: ['6860NT6']. Removing from source.
# Failed to fetch details for ['SECTION']: Status code 400
# No details fetched for chunk: ['SECTION']. Removing from source.
# Failed to fetch details for ['90U5449']: Status code 400
# No details fetched for chunk: ['90U5449']. Removing from source.
# Failed to fetch details for ['91447Y5']: Status code 400
# No details fetched for chunk: ['91447Y5']. Removing from source.
# Failed to fetch details for ['3345EU4']: Status code 400
# No details fetched for chunk: ['3345EU4']. Removing from source.
# Failed to fetch details for ['521U996']: Status code 400
# No details fetched for chunk: ['521U996']. Removing from source.
# Failed to fetch details for ['JL88VPG']: Status code 400
# No details fetched for chunk: ['JL88VPG']. Removing from source.
# Failed to fetch details for ['108AAM3']: Status code 400
# No details fetched for chunk: ['108AAM3']. Removing from source.
# Failed to fetch details for ['V71420V']: Status code 400
# No details fetched for chunk: ['V71420V']. Removing from source.
# Failed to fetch details for ['1UHG8']: Status code 500
# No details fetched for chunk: ['1UHG8']. Removing from source.
# Failed to fetch details for ['RB4251S']: Status code 400
# No details fetched for chunk: ['RB4251S']. Removing from source.
# Failed to fetch details for ['71043A7']: Status code 400
# No details fetched for chunk: ['71043A7']. Removing from source.
# Failed to fetch details for ['8543A78']: Status code 400
# No details fetched for chunk: ['8543A78']. Removing from source.
# Failed to fetch details for ['512JDF3']: Status code 400
# No details fetched for chunk: ['512JDF3']. Removing from source.
# Failed to fetch details for ['45EF934']: Status code 400
# No details fetched for chunk: ['45EF934']. Removing from source.
# Failed to fetch details for ['CA7921C']: Status code 400
# No details fetched for chunk: ['CA7921C']. Removing from source.
# Failed to fetch details for ['1020086']: Status code 400
# No details fetched for chunk: ['1020086']. Removing from source.
# Failed to fetch details for ['0439C30']: Status code 400
# No details fetched for chunk: ['0439C30']. Removing from source.
# Failed to fetch details for ['TORNADO']: Status code 400
# No details fetched for chunk: ['TORNADO']. Removing from source.
# Failed to fetch details for ['W240V']: Status code 400
# No details fetched for chunk: ['W240V']. Removing from source.
# Failed to fetch details for ['HOTHAND']: Status code 400
# No details fetched for chunk: ['HOTHAND']. Removing from source.
# Failed to fetch details for ['116111']: Status code 400
# No details fetched for chunk: ['116111']. Removing from source.
# Failed to fetch details for ['403XHT5']: Status code 400
# No details fetched for chunk: ['403XHT5']. Removing from source.
# Failed to fetch details for ['DXWP100']: Status code 400
# No details fetched for chunk: ['DXWP100']. Removing from source.
# Failed to fetch details for ['GRNEW']: Status code 400
# No details fetched for chunk: ['GRNEW']. Removing from source.
# Failed to fetch details for ['75796JC']: Status code 400
# No details fetched for chunk: ['75796JC']. Removing from source.
# Failed to fetch details for ['W10181']: Status code 400
# No details fetched for chunk: ['W10181']. Removing from source.
# Failed to fetch details for ['481C08']: Status code 404
# No details fetched for chunk: ['481C08']. Removing from source.
# Failed to fetch details for ['17010']: Status code 400
# No details fetched for chunk: ['17010']. Removing from source.
# Failed to fetch details for ['5142020']: Status code 400
# No details fetched for chunk: ['5142020']. Removing from source.
# Failed to fetch details for ['TB1A2QV']: Status code 400
# No details fetched for chunk: ['TB1A2QV']. Removing from source.
# Failed to fetch details for ['3T843C']: Status code 400
# No details fetched for chunk: ['3T843C']. Removing from source.
# Failed to fetch details for ['SOLEAIR']: Status code 400
# No details fetched for chunk: ['SOLEAIR']. Removing from source.
# Failed to fetch details for ['06P9180']: Status code 400
# No details fetched for chunk: ['06P9180']. Removing from source.
# Failed to fetch details for ['A7450']: Status code 400
# No details fetched for chunk: ['A7450']. Removing from source.
# Failed to fetch details for ['X719KDJ']: Status code 400
# No details fetched for chunk: ['X719KDJ']. Removing from source.
# Failed to fetch details for ['NFC15']: Status code 400
# No details fetched for chunk: ['NFC15']. Removing from source.
# Failed to fetch details for ['RB4177C']: Status code 400
# No details fetched for chunk: ['RB4177C']. Removing from source.
# Failed to fetch details for ['11232']: Status code 400
# No details fetched for chunk: ['11232']. Removing from source.
# Failed to fetch details for ['85R17']: Status code 400
# No details fetched for chunk: ['85R17']. Removing from source.
# Failed to fetch details for ['DH5143K']: Status code 400
# No details fetched for chunk: ['DH5143K']. Removing from source.
# Failed to fetch details for ['LT295']: Status code 400
# No details fetched for chunk: ['LT295']. Removing from source.
# Failed to fetch details for ['0818HC1']: Status code 400
# No details fetched for chunk: ['0818HC1']. Removing from source.
# Failed to fetch details for ['XLARGE']: Status code 400
# No details fetched for chunk: ['XLARGE']. Removing from source.
# Failed to fetch details for ['AABILIT']: Status code 400
# No details fetched for chunk: ['AABILIT']. Removing from source.
# Failed to fetch details for ['66439M6']: Status code 400
# No details fetched for chunk: ['66439M6']. Removing from source.
# Failed to fetch details for ['MASTER']: Status code 400
# No details fetched for chunk: ['MASTER']. Removing from source.
# Failed to fetch details for ['34471']: Status code 400
# No details fetched for chunk: ['34471']. Removing from source.
# Failed to fetch details for ['809WX8']: Status code 400
# No details fetched for chunk: ['809WX8']. Removing from source.
# Failed to fetch details for ['4643A64']: Status code 400
# No details fetched for chunk: ['4643A64']. Removing from source.
# Failed to fetch details for ['813X93']: Status code 400
# No details fetched for chunk: ['813X93']. Removing from source.
# Failed to fetch details for ['813X67']: Status code 400
# No details fetched for chunk: ['813X67']. Removing from source.
# Failed to fetch details for ['9CS21']: Status code 400
# No details fetched for chunk: ['9CS21']. Removing from source.
# Failed to fetch details for ['6516W53']: Status code 400
# No details fetched for chunk: ['6516W53']. Removing from source.
# Failed to fetch details for ['22UV778']: Status code 400
# No details fetched for chunk: ['22UV778']. Removing from source.
# Failed to fetch details for ['RB8807D']: Status code 400
# No details fetched for chunk: ['RB8807D']. Removing from source.
# Failed to fetch details for ['2421EK3']: Status code 400
# No details fetched for chunk: ['2421EK3']. Removing from source.
# Failed to fetch details for ['GMM9900']: Status code 400
# No details fetched for chunk: ['GMM9900']. Removing from source.
# Failed to fetch details for ['91CSPST']: Status code 400
# No details fetched for chunk: ['91CSPST']. Removing from source.
# Failed to fetch details for ['70R16']: Status code 400
# No details fetched for chunk: ['70R16']. Removing from source.
# Failed to fetch details for ['43A6394']: Status code 400
# No details fetched for chunk: ['43A6394']. Removing from source.
# Failed to fetch details for ['MILWAUK']: Status code 400
# No details fetched for chunk: ['MILWAUK']. Removing from source.
# Failed to fetch details for ['TB0A5RS']: Status code 400
# No details fetched for chunk: ['TB0A5RS']. Removing from source.
# Failed to fetch details for ['865E874']: Status code 400
# No details fetched for chunk: ['865E874']. Removing from source.
# Failed to fetch details for ['92841']: Status code 400
# No details fetched for chunk: ['92841']. Removing from source.
# Failed to fetch details for ['84439M5']: Status code 400
# No details fetched for chunk: ['84439M5']. Removing from source.
# Failed to fetch details for ['COVID']: Status code 400
# No details fetched for chunk: ['COVID']. Removing from source.
# Failed to fetch details for ['UNSPSC4']: Status code 400
# No details fetched for chunk: ['UNSPSC4']. Removing from source.
# Failed to fetch details for ['023XGC7']: Status code 400
# No details fetched for chunk: ['023XGC7']. Removing from source.
# Failed to fetch details for ['TB1A1I5']: Status code 400
# No details fetched for chunk: ['TB1A1I5']. Removing from source.
# Failed to fetch details for ['19GEK19']: Status code 400
# No details fetched for chunk: ['19GEK19']. Removing from source.
# Failed to fetch details for ['32439F2']: Status code 400
# No details fetched for chunk: ['32439F2']. Removing from source.
# Failed to fetch details for ['PC1300C']: Status code 400
# No details fetched for chunk: ['PC1300C']. Removing from source.
# Failed to fetch details for ['575PB37']: Status code 400
# No details fetched for chunk: ['575PB37']. Removing from source.
# Failed to fetch details for ['3731AC6']: Status code 400
# No details fetched for chunk: ['3731AC6']. Removing from source.
# Failed to fetch details for ['NOAAL']: Status code 400
# No details fetched for chunk: ['NOAAL']. Removing from source.
# Failed to fetch details for ['3352ZX9']: Status code 400
# No details fetched for chunk: ['3352ZX9']. Removing from source.
# Failed to fetch details for ['5145MP7']: Status code 400
# No details fetched for chunk: ['5145MP7']. Removing from source.
# Failed to fetch details for ['HOROGOO']: Status code 400
# No details fetched for chunk: ['HOROGOO']. Removing from source.
# Failed to fetch details for ['CA4525W']: Status code 400
# No details fetched for chunk: ['CA4525W']. Removing from source.
# Failed to fetch details for ['491V844']: Status code 400
# No details fetched for chunk: ['491V844']. Removing from source.
# Failed to fetch details for ['74438X2']: Status code 400
# No details fetched for chunk: ['74438X2']. Removing from source.
# Failed to fetch details for ['GB00562']: Status code 400
# No details fetched for chunk: ['GB00562']. Removing from source.
# Failed to fetch details for ['843A609']: Status code 400
# No details fetched for chunk: ['843A609']. Removing from source.
# Failed to fetch details for ['02472']: Status code 400
# No details fetched for chunk: ['02472']. Removing from source.
# Failed to fetch details for ['W10717R']: Status code 400
# No details fetched for chunk: ['W10717R']. Removing from source.
# Failed to fetch details for ['2441HG9']: Status code 400
# No details fetched for chunk: ['2441HG9']. Removing from source.
# Failed to fetch details for ['07012']: Status code 400
# No details fetched for chunk: ['07012']. Removing from source.
# Failed to fetch details for ['CA1435W']: Status code 400
# No details fetched for chunk: ['CA1435W']. Removing from source.
# Failed to fetch details for ['1TC63C']: Status code 400
# No details fetched for chunk: ['1TC63C']. Removing from source.
# Failed to fetch details for ['LT265']: Status code 400
# No details fetched for chunk: ['LT265']. Removing from source.
# Failed to fetch details for ['402109M']: Status code 400
# No details fetched for chunk: ['402109M']. Removing from source.
# Failed to fetch details for ['4418D82']: Status code 400
# No details fetched for chunk: ['4418D82']. Removing from source.
# Failed to fetch details for ['91V4249']: Status code 400
# No details fetched for chunk: ['91V4249']. Removing from source.
# Failed to fetch details for ['00443C0']: Status code 400
# No details fetched for chunk: ['00443C0']. Removing from source.
# Failed to fetch details for ['SKILCRA']: Status code 400
# No details fetched for chunk: ['SKILCRA']. Removing from source.
# Failed to fetch details for ['HANDLER']: Status code 400
# No details fetched for chunk: ['HANDLER']. Removing from source.
# Failed to fetch details for ['6490DAN']: Status code 400
# No details fetched for chunk: ['6490DAN']. Removing from source.
# Failed to fetch details for ['FW09LH9']: Status code 400
# ...
# Failed to fetch details for ['MOBILD']: Status code 400
# No details fetched for chunk: ['MOBILD']. Removing from source.
# Failed to fetch details for ['PRESTON']: Status code 400
# No details fetched for chunk: ['PRESTON']. Removing from source.
# Failed to fetch details for ['76553']: Status code 400
# No details fetched for chunk: ['76553']. Removing from source.
# Failed to fetch details for ['CHECKER']: Status code 400
# No details fetched for chunk: ['CHECKER']. Removing from source.
# Failed to fetch details for ['243A653']: Status code 400
# No details fetched for chunk: ['243A653']. Removing from source.
# Failed to fetch details for ['35439M5']: Status code 400
# No details fetched for chunk: ['35439M5']. Removing from source.
# Failed to fetch details for ['40511']: Status code 400
# No details fetched for chunk: ['40511']. Removing from source.
# Failed to fetch details for ['A83543A']: Status code 400
# No details fetched for chunk: ['A83543A']. Removing from source.
# Failed to fetch details for ['BAYCO']: Status code 400
# No details fetched for chunk: ['BAYCO']. Removing from source.
# Failed to fetch details for ['SPEND']: Status code 400
# No details fetched for chunk: ['SPEND']. Removing from source.
# Failed to fetch details for ['A7124AV']: Status code 400
# No details fetched for chunk: ['A7124AV']. Removing from source.
# Failed to fetch details for ['30R21']: Status code 400
# No details fetched for chunk: ['30R21']. Removing from source.
# Failed to fetch details for ['4653DD4']: Status code 400
# No details fetched for chunk: ['4653DD4']. Removing from source.
# Failed to fetch details for ['00JV380']: Status code 400
# No details fetched for chunk: ['00JV380']. Removing from source.
# Failed to fetch details for ['48024']: Status code 400
# No details fetched for chunk: ['48024']. Removing from source.
# Failed to fetch details for ['W211042']: Status code 400
# No details fetched for chunk: ['W211042']. Removing from source.
# Failed to fetch details for ['91V2349']: Status code 400
# No details fetched for chunk: ['91V2349']. Removing from source.
# Failed to fetch details for ['U001ARI']: Status code 400
# No details fetched for chunk: ['U001ARI']. Removing from source.
# Failed to fetch details for ['20E892C']: Status code 400
# No details fetched for chunk: ['20E892C']. Removing from source.
# Failed to fetch details for ['43C0404']: Status code 400
# No details fetched for chunk: ['43C0404']. Removing from source.
# Failed to fetch details for ['07812']: Status code 400
# No details fetched for chunk: ['07812']. Removing from source.
# Failed to fetch details for ['492T86M']: Status code 400
# No details fetched for chunk: ['492T86M']. Removing from source.
# Failed to fetch details for ['764FKR2']: Status code 400
# No details fetched for chunk: ['764FKR2']. Removing from source.
# Failed to fetch details for ['3032TL9']: Status code 400
# No details fetched for chunk: ['3032TL9']. Removing from source.
# Failed to fetch details for ['56LN43C']: Status code 400
# No details fetched for chunk: ['56LN43C']. Removing from source.
# Failed to fetch details for ['BROWSE']: Status code 400
# No details fetched for chunk: ['BROWSE']. Removing from source.
# Failed to fetch details for ['8214TIM']: Status code 400
# No details fetched for chunk: ['8214TIM']. Removing from source.
# Failed to fetch details for ['IMAGEWE']: Status code 400
# No details fetched for chunk: ['IMAGEWE']. Removing from source.
# Failed to fetch details for ['34382']: Status code 400
# No details fetched for chunk: ['34382']. Removing from source.
# Failed to fetch details for ['55EC19']: Status code 500
# No details fetched for chunk: ['55EC19']. Removing from source.
# Failed to fetch details for ['6360XN2']: Status code 400
# No details fetched for chunk: ['6360XN2']. Removing from source.
# Failed to fetch details for ['47809MZ']: Status code 400
# No details fetched for chunk: ['47809MZ']. Removing from source.
# Failed to fetch details for ['786UZ6']: Status code 500
# No details fetched for chunk: ['786UZ6']. Removing from source.
# Failed to fetch details for ['38E571M']: Status code 400
# No details fetched for chunk: ['38E571M']. Removing from source.
# Failed to fetch details for ['39F190S']: Status code 400
# No details fetched for chunk: ['39F190S']. Removing from source.
# Failed to fetch details for ['006KDZ8']: Status code 400
# No details fetched for chunk: ['006KDZ8']. Removing from source.
# Failed to fetch details for ['W05680S']: Status code 400
# No details fetched for chunk: ['W05680S']. Removing from source.
# Failed to fetch details for ['ALLOW']: Status code 400
# No details fetched for chunk: ['ALLOW']. Removing from source.
# Failed to fetch details for ['9938ZD4']: Status code 400
# No details fetched for chunk: ['9938ZD4']. Removing from source.
# Failed to fetch details for ['94438X1']: Status code 400
# No details fetched for chunk: ['94438X1']. Removing from source.
# Failed to fetch details for ['5492U26']: Status code 400
# No details fetched for chunk: ['5492U26']. Removing from source.
# Failed to fetch details for ['12579']: Status code 400
# No details fetched for chunk: ['12579']. Removing from source.
# Failed to fetch details for ['3C04243']: Status code 400
# No details fetched for chunk: ['3C04243']. Removing from source.
# Failed to fetch details for ['11353']: Status code 400
# No details fetched for chunk: ['11353']. Removing from source.
# Failed to fetch details for ['4NE56M']: Status code 400
# No details fetched for chunk: ['4NE56M']. Removing from source.
# Failed to fetch details for ['116309']: Status code 400
# No details fetched for chunk: ['116309']. Removing from source.
# Failed to fetch details for ['B1L57']: Status code 400
# No details fetched for chunk: ['B1L57']. Removing from source.
# Failed to fetch details for ['708AAM2']: Status code 400
# No details fetched for chunk: ['708AAM2']. Removing from source.
# Failed to fetch details for ['3JUSTIN']: Status code 400
# No details fetched for chunk: ['3JUSTIN']. Removing from source.
# Failed to fetch details for ['60TRITA']: Status code 400
# No details fetched for chunk: ['60TRITA']. Removing from source.
# Failed to fetch details for ['6613M54']: Status code 400
# No details fetched for chunk: ['6613M54']. Removing from source.
# Failed to fetch details for ['PROCESS']: Status code 400
# No details fetched for chunk: ['PROCESS']. Removing from source.
# Failed to fetch details for ['29PG42M']: Status code 400
# No details fetched for chunk: ['29PG42M']. Removing from source.
# Failed to fetch details for ['A7125RE']: Status code 400
# No details fetched for chunk: ['A7125RE']. Removing from source.
# Failed to fetch details for ['491V644']: Status code 400
# No details fetched for chunk: ['491V644']. Removing from source.
# Failed to fetch details for ['6455JK6']: Status code 400
# No details fetched for chunk: ['6455JK6']. Removing from source.
# Failed to fetch details for ['3Z16793']: Status code 400
# No details fetched for chunk: ['3Z16793']. Removing from source.
# Failed to fetch details for ['7643P20']: Status code 400
# No details fetched for chunk: ['7643P20']. Removing from source.
# Failed to fetch details for ['1039FK8']: Status code 400
# No details fetched for chunk: ['1039FK8']. Removing from source.
# Failed to fetch details for ['6JP9956']: Status code 400
# No details fetched for chunk: ['6JP9956']. Removing from source.
# Failed to fetch details for ['61VG686']: Status code 400
# No details fetched for chunk: ['61VG686']. Removing from source.
# Failed to fetch details for ['55EC32']: Status code 500
# No details fetched for chunk: ['55EC32']. Removing from source.
# Failed to fetch details for ['TRIMCO']: Status code 400
# No details fetched for chunk: ['TRIMCO']. Removing from source.
# Failed to fetch details for ['XG96E']: Status code 400
# No details fetched for chunk: ['XG96E']. Removing from source.
# Failed to fetch details for ['4311C66']: Status code 400
# No details fetched for chunk: ['4311C66']. Removing from source.
# Failed to fetch details for ['50507TI']: Status code 400
# No details fetched for chunk: ['50507TI']. Removing from source.
# Failed to fetch details for ['INSTALL']: Status code 400
# No details fetched for chunk: ['INSTALL']. Removing from source.
# Failed to fetch details for ['86515AV']: Status code 400
# No details fetched for chunk: ['86515AV']. Removing from source.
# Failed to fetch details for ['TB1A1I4']: Status code 400
# No details fetched for chunk: ['TB1A1I4']. Removing from source.
# Failed to fetch details for ['7800NEX']: Status code 400
# No details fetched for chunk: ['7800NEX']. Removing from source.
# Failed to fetch details for ['53530WO']: Status code 400
# No details fetched for chunk: ['53530WO']. Removing from source.
# Failed to fetch details for ['DZ2BBQ']: Status code 400
# No details fetched for chunk: ['DZ2BBQ']. Removing from source.
# Failed to fetch details for ['U53491U']: Status code 400
# No details fetched for chunk: ['U53491U']. Removing from source.
# Failed to fetch details for ['075C734']: Status code 400
# No details fetched for chunk: ['075C734']. Removing from source.
# Failed to fetch details for ['303UP44']: Status code 400
# No details fetched for chunk: ['303UP44']. Removing from source.
# Failed to fetch details for ['VENDORB']: Status code 400
# No details fetched for chunk: ['VENDORB']. Removing from source.
# Failed to fetch details for ['56VTG6']: Status code 400
# No details fetched for chunk: ['56VTG6']. Removing from source.
# Failed to fetch details for ['RK6640']: Status code 400
# No details fetched for chunk: ['RK6640']. Removing from source.
# Failed to fetch details for ['2655EA9']: Status code 400
# No details fetched for chunk: ['2655EA9']. Removing from source.
# Failed to fetch details for ['421V004']: Status code 400
# No details fetched for chunk: ['421V004']. Removing from source.
# Failed to fetch details for ['7793Z08']: Status code 400
# No details fetched for chunk: ['7793Z08']. Removing from source.
# Failed to fetch details for ['55PK985']: Status code 400
# No details fetched for chunk: ['55PK985']. Removing from source.
# Failed to fetch details for ['6379T']: Status code 400
# No details fetched for chunk: ['6379T']. Removing from source.
# Failed to fetch details for ['W04714R']: Status code 400
# No details fetched for chunk: ['W04714R']. Removing from source.
# Product details have been saved to 'processed/grainger_products.parquet'
#
# Head of DataFrame:
#                           Brand    Code  \
# 0                       TSUBAKI   1A912
# 1  LION FIRE BOOTS BY THOROGOOD   3XRG7
# 2           GLOWEAR BY ERGODYNE   1CXK5
# 3                      PEERLESS  39R838
# 4                     TOUGH GUY   4KN42
#
#                                                 Name  \
# 0                  TSUBAKI Chain Detacher: 60 to 100
# 1  Insulated Firefighter Boots: Insulated, Steel,...
# 2  GLOWEAR BY ERGODYNE Baseball Cap: Orange, Univ...
# 3                          Tire Chain: Passenger, Pr
# 4  TOUGH GUY Trash Bags: 56 gal Capacity, 43 in W...
#
#                                        PictureUrl600    Price  \
# 0  https://static.grainger.com/rp/s/is/image/Grai...  $137.57
# 1  https://static.grainger.com/rp/s/is/image/Grai...  $197.55
# 2  https://static.grainger.com/rp/s/is/image/Grai...   $13.93
# 3  https://static.grainger.com/rp/s/is/image/Grai...  $102.33
# 4  https://static.grainger.com/rp/s/is/image/Grai...   $75.73
#
#                                          Description
# 0  <p>Chain breakers, also called detachers, are ...
# 1  <p>Thorogood® 807-6003 Insulated Boots are des...
# 2  <p>Baseball hats have a curved brim that shade...
# 3
# 4  <p>Trash bags for soft refuse are made of HDPE...
#
# Tail of DataFrame:
#                       Brand    Code  \
# 3232               ERGODYNE  52NN47
# 3233  CHILL-ITS BY ERGODYNE   2EMK5
# 3234              CLEVELAND  439M26
# 3235                WOOSTER  452D90
# 3236               WESTWARD   2UFU9
#
#                                                    Name  \
# 3232                   Tool Tethering Kit,3 Attachments
# 3233  CHILL-ITS BY ERGODYNE Cooling Hat: Orange, Uni...
# 3234  CLEVELAND Taper Length Drill Bit: 3/16 in Dril...
# 3235  Anti-Slip Tape: Very Coarse, 46 Grit Size, Sol...
# 3236  WESTWARD Mechanics Length Drill Bit: 1/8 in Dr...
#
#                                           PictureUrl600   Price  \
# 3232  https://static.grainger.com/rp/s/is/image/Grai...  $93.71
# 3233  https://static.grainger.com/rp/s/is/image/Grai...  $23.46
# 3234  https://static.grainger.com/rp/s/is/image/Grai...  $11.18
# 3235  https://static.grainger.com/rp/s/is/image/Grai...  $26.20
# 3236  https://static.grainger.com/rp/s/is/image/Grai...   $1.67
#
#                                             Description
# 3232                                               None
# 3233  <p>Baseball hats have a curved brim that shade...
# 3234  <p>These drill bits come in standard sizes exp...
# 3235  <p>This antislip tape has a coarse mineral-coa...
# 3236  <p>The black-and-gold-oxide finish on these dr...
#
# Size of DataFrame: 19422
#
# Values in DataFrame:
# [['TSUBAKI' '1A912' 'TSUBAKI Chain Detacher: 60 to 100'
#   'https://static.grainger.com/rp/s/is/image/Grainger/1A911_AS01?$lgmain$'
#   '$137.57'
#   '<p>Chain breakers, also called detachers, are devices that apply manual force to remove individual roller chain links from a chain. They drive out the pins on the link without damaging the link plates.</p>']
#  ['LION FIRE BOOTS BY THOROGOOD' '3XRG7'
#   'Insulated Firefighter Boots: Insulated, Steel, 10-1/2, M, Structural, 1 PR'
#   'https://static.grainger.com/rp/s/is/image/Grainger/3XRG3_AS05?$lgmain$'
#   '$197.55'
#   '<p>Thorogood® 807-6003 Insulated Boots are designed for use by firefighters in demanding applications. They feature vulcanized rubber construction, with double-reinforced pull loops, rubber T-toes for extra durability, oversized steel toe caps, reflective instep and heel patches, and removable polyurethane insoles.</p>']
#  ['GLOWEAR BY ERGODYNE' '1CXK5'
#   'GLOWEAR BY ERGODYNE Baseball Cap: Orange, Universal, Baseball Hat Hat, Polyester, Gen Purpose'
#   'https://static.grainger.com/rp/s/is/image/Grainger/1CXK5_AS04?$lgmain$'
#   '$13.93'
#   '<p>Baseball hats have a curved brim that shades the eyes from sun to reduce eye strain and improve visibility.</p>']
#  ...
#  ['CLEVELAND' '439M26'
#   'CLEVELAND Taper Length Drill Bit: 3/16 in Drill Bit Size, 3 3/8 in Flute Lg, 3/16 in Shank Dia., 4xD'
#   'https://static.grainger.com/rp/s/is/image/Grainger/439D72_GC01?$lgmain$'
#   '$11.18'
#   "<p>These drill bits come in standard sizes expressed in fractional inches. The bits have a black-oxide finish that retains lubricants to improve the bits' wear resistance and chip flow. Black-oxide bits should only be used for drilling ferrous metals. High-speed steel drill bits provide more flexibility and absorb more shock and vibration than cobalt and carbide drill bits, making them suitable for use in manual drilling machines and handheld power tools. They may leave a rough finish on the hole. These bits have spiral flutes that evacuate chips as the bits drill into a workpiece.</p>"]
#  ['WOOSTER' '452D90'
#   'Anti-Slip Tape: Very Coarse, 46 Grit Size, Solid, Black, 2 in x 60 ft, 42 mil Tape Thick, Acrylic'
#   'https://static.grainger.com/rp/s/is/image/Grainger/452D90_AS01?$lgmain$'
#   '$26.20'
#   '<p>This antislip tape has a coarse mineral-coated abrasive for high slip resistance in areas with heavy foot and equipment traffic. This durable, high-friction tape is used in muddy, greasy, and oily conditions, such as on construction and farm equipment.</p>']
#  ['WESTWARD' '2UFU9'
#   'WESTWARD Mechanics Length Drill Bit: 1/8 in Drill Bit Size, 1 7/16 in Flute Lg, 1/8 in Shank Dia.'
#   'https://static.grainger.com/rp/s/is/image/Grainger/2UFU5_GC01?$lgmain$'
#   '$1.67'
#   '<p>The black-and-gold-oxide finish on these drill bits lubricates the drill bit and provides some resistance to wear and rust. The bits are made from high-speed steel, which provides some flexibility and absorbs some shock and vibration.</p>']]
