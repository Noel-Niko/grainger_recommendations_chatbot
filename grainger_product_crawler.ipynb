# %%
domain = "https://www.grainger.com"
start_url = "https://www.grainger.com/category"

# %%
# #BREATH-FIRST CRAWLER 
# import time
# import os
# from urllib.parse import urlparse, urljoin
# from collections import deque
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from webdriver_manager.chrome import ChromeDriverManager
# from bs4 import BeautifulSoup
# import re
# 
# # Selenium setup
# options = Options()
# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
# service = Service(ChromeDriverManager().install())
# driver = webdriver.Chrome(service=service, options=options)
# 
# # Function to get the hyperlinks from a URL using Selenium
# def get_hyperlinks(url):
#     print(f"Getting hyperlinks for URL: {url}")
#     try:
#         driver.get(url)
#         time.sleep(1)  # Adjust wait time as needed based on page load speed
#         html = driver.page_source
#         soup = BeautifulSoup(html, 'html.parser')
#         hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
#         return hyperlinks
#     except Exception as e:
#         print(f"Error getting hyperlinks: {e}")
#         return []
# 
# # Function to crawl the website
# def crawl(url):
#     local_domain = urlparse(domain).netloc
#     queue = deque([url])
#     seen = {url}
#     clean_links = []
# 
#     # Create necessary directories if they don't exist
#     if not os.path.exists("text/"):
#         os.mkdir("text/")
#     if not os.path.exists(f"text/{local_domain}/"):
#         os.mkdir(f"text/{local_domain}/")
#     if not os.path.exists("processed"):
#         os.mkdir("processed")
# 
#     while queue and len(clean_links) < 100000:
#         url = queue.popleft()  # Use popleft to ensure we process URLs in a breadth-first manner
#         print(f"Crawling URL: {url}")
#         try:
#             # Construct file path for saving content
#             file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
#             with open(file_path, "w") as f:
#                 driver.get(url)
#                 time.sleep(3)  # Adjust wait time as needed based on page load speed
#                 soup = BeautifulSoup(driver.page_source, "html.parser")
#                 text = soup.get_text()
#                 if "You need to enable JavaScript to run this app." in text:
#                     print(f"Unable to parse page {url} due to JavaScript being required")
#                 f.write(text)
#                 # print(f"Writing: {text}")
#         except Exception as e:
#             print(f"Error crawling URL: {e}")
# 
#         try:
#             new_links = get_domain_hyperlinks(local_domain, url, clean_links)
#             for link in new_links:
#                 if link not in seen:
#                     queue.append(link)
#                     seen.add(link)
#         except Exception as e:
#             print(f"Error processing links: {e}")
# 
#     print(f"Collected {len(clean_links)} clean links")
# 
# # Function to get the hyperlinks from a URL that are within the same domain and base URL
# def get_domain_hyperlinks(local_domain, url, clean_links):
#     # regex_pattern = re.compile(r'-[a-zA-Z0-9]+\?.*')
#     # regex_pattern = re.compile(r'-((?=.*\d.*\d.*\d)[A-Z0-9]{5,7})\?.*')
#     # regex_pattern = re.compile(r'-((?=.*\d.*\d.*\d)[A-Z0-9]{5,7})\?.*(?<!\.txt|\.pdf)$')
# #    regex_pattern = re.compile(r'-[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')
# regex_pattern = re.compile(r'/product/[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')

# 
# 
#     hyperlinks = get_hyperlinks(url)
#     print(f"Found {len(hyperlinks)} hyperlinks on {url}")
#     for link in set(hyperlinks):
#         clean_link = None
#         print(f"Checking link: {link}")
# 
#         # Handle absolute URLs
#         if link.startswith("http"):
#             url_obj = urlparse(link)
#             if url_obj.netloc == local_domain and link.startswith(domain):
#                 clean_link = link
#         else:
#             # Handle relative URLs
#             clean_link = urljoin(url, link)
# 
#         if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
#             if clean_link.endswith("/"):
#                 clean_link = clean_link[:-1]
#             if clean_link not in clean_links:
#                 print(f"Adding clean link: {clean_link}")
#                 clean_links.append(clean_link)
# 
#         # Stop collecting if we reach n links
#         if len(clean_links) >= 100000:
#             break
# 
#     print(f"Clean links: {clean_links}")
#     return list(set(hyperlinks))
# 
# crawl(start_url)
# 
# driver.quit()

# #BREATH-FIRST CRAWLER

# %%
#DEPTH-FIRST CRAWLER
import time
import os
from urllib.parse import urlparse, urljoin
from collections import deque
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re

# Selenium setup
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to get the hyperlinks from a URL using Selenium
def get_hyperlinks(url):
    print(f"Getting hyperlinks for URL: {url}")
    try:
        driver.get(url)
        time.sleep(1)  # Adjust wait time as needed based on page load speed
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
        return hyperlinks
    except Exception as e:
        print(f"Error getting hyperlinks: {e}")
        return []

# Function to crawl the website using depth-first strategy
def crawl(url):
    local_domain = urlparse(domain).netloc
    stack = [url]  # Use a stack instead of a queue for depth-first
    seen = {url}
    clean_links = []

    # Create necessary directories if they don't exist
    if not os.path.exists("text/"):
        os.mkdir("text/")
    if not os.path.exists(f"text/{local_domain}/"):
        os.mkdir(f"text/{local_domain}/")
    if not os.path.exists("processed"):
        os.mkdir("processed")

    while stack and len(clean_links) < 100000:
        url = stack.pop()  # Use pop() to ensure we process URLs in a depth-first manner
        print(f"Crawling URL: {url}")
        try:
            # Construct file path for saving content
            file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
            with open(file_path, "w") as f:
                driver.get(url)
                time.sleep(3)  # Adjust wait time as needed based on page load speed
                soup = BeautifulSoup(driver.page_source, "html.parser")
                text = soup.get_text()
                if "You need to enable JavaScript to run this app." in text:
                    print(f"Unable to parse page {url} due to JavaScript being required")
                f.write(text)
        except Exception as e:
            print(f"Error crawling URL: {e}")

        try:
            new_links = get_domain_hyperlinks(local_domain, url, clean_links)
            for link in new_links:
                if link not in seen:
                    stack.append(link)
                    seen.add(link)
        except Exception as e:
            print(f"Error processing links: {e}")

    print(f"Collected {len(clean_links)} clean links")

# Function to get the hyperlinks from a URL that are within the same domain and base URL
def get_domain_hyperlinks(local_domain, url, clean_links):
    regex_pattern = re.compile(r'/product/[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')

    hyperlinks = get_hyperlinks(url)
    print(f"Found {len(hyperlinks)} hyperlinks on {url}")
    for link in set(hyperlinks):
        clean_link = None
        print(f"Checking link: {link}")

        # Handle absolute URLs
        if link.startswith("http"):
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain and link.startswith(domain):
                clean_link = link
        else:
            # Handle relative URLs
            clean_link = urljoin(url, link)

        if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            if clean_link not in clean_links:
                print(f"Adding clean link: {clean_link}")
                clean_links.append(clean_link)

        # Stop collecting if we reach n links
        if len(clean_links) >= 100000:
            break

    print(f"Clean links: {clean_links}")
    return list(set(hyperlinks))

crawl(start_url)

driver.quit()
#DEPTH-FIRST
# Out:
# Crawling URL: https://www.grainger.com/category
# Getting hyperlinks for URL: https://www.grainger.com/category
# Found 142 hyperlinks on https://www.grainger.com/category
# Checking link: /category/reference-and-learning-supplies
# Checking link: /apps/keepstock/
# Checking link: /content/mc/services-and-solutions
# Checking link: /category/fasteners
# Checking link: /category/office-supplies
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: /category/lighting?analytics=nav
# Checking link: /category/plumbing
# Checking link: /category/hardware?analytics=nav
# Checking link: /category/machining
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /content/custom-product-center
# Checking link: /content/bulk-order-pad
# Checking link: /category/hvac-and-refrigeration
# Checking link: /category/welding?analytics=nav
# Checking link: /category/outdoor-equipment
# Checking link: /category/fasteners?analytics=nav
# Checking link: /content/mc/product-collections
# Checking link: /category/test-instruments?analytics=nav
# Checking link: /orders/lookup
# Checking link: /category/lubrication
# Checking link: https://instagram.com/grainger
# Checking link: /category/raw-materials
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /content/mc/product-collections/industries
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: /category/electronics-batteries
# Checking link: /category/pneumatics?analytics=nav
# Checking link: /category/security
# Checking link: /invoicing
# Checking link: /category/adhesives-sealants-and-tape
# Checking link: /content/sitemap
# Checking link: /content/mc/policies/delivery
# Checking link: https://apps.apple.com/us/app/w-w-grainger-inc/id526722540?ls=1
# Checking link: /category/material-handling
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Checking link: /content/mc/supplier-overview
# Checking link: /category/outdoor-equipment?analytics=nav
# Checking link: /content/mc/policies/return-instructions
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: /category/pneumatics
# Checking link: /
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /category/lubrication?analytics=nav
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: /category/tools
# Checking link: /category/material-handling?analytics=nav
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: https://www.google.com/chrome
# Checking link: /category/electrical?analytics=nav
# Checking link: /content/general-catalog
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: https://jobs.grainger.com/
# Checking link: /category/motors?analytics=nav
# Checking link: /content/mc/serving-customers/extended-protection-plan
# Checking link: /category/lab-supplies
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: /category/fleet-vehicle-maintenance
# Checking link: /category/pumps?analytics=nav
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: /category/tools?analytics=nav
# Checking link: /category/furnishings-appliances-hospitality
# Checking link: /cart
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /category/safety
# Checking link: /myaccount/signin
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: /category/pipe-hose-tube-fittings
# Checking link: /content/find-branch-location
# Checking link: /content/user_registration
# Checking link: https://www.youtube.com/grainger
# Checking link: https://www.facebook.com/grainger
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /category/electrical
# Checking link: tel:1-800-472-4643
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /category/fleet-vehicle-maintenance?analytics=nav
# Checking link: /category/motors
# Checking link: /content/help
# Checking link: /category/hardware
# Checking link: /category/power-transmission
# Checking link: https://www.graingeresg.com/
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: /category/paints-equipment-and-supplies
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: /myaccount
# Checking link: /content/mc/policies/supported-browsers
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: /content/mc/serving-customers
# Checking link: /content/mc/policies/terms-of-access
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /category?analytics=nav
# Checking link: /category/plumbing?analytics=nav
# Checking link: /category/security?analytics=nav
# Checking link: /know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: /content/repair_parts_center
# Checking link: /category/welding
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /category/test-instruments
# Checking link: /category/machining?analytics=nav
# Checking link: https://www.twitter.com/grainger
# Checking link: /category/pumps
# Checking link: /category/abrasives
# Checking link: /category/packaging-shipping
# Checking link: /category/abrasives?analytics=nav
# Checking link: /category/safety?analytics=nav
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: /category/raw-materials?analytics=nav
# Checking link: /category/hydraulics
# Checking link: /category/cleaning-and-janitorial
# Checking link: /category/lighting
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /content/mc/policies/accessibility-statement
# Clean links: []
# Crawling URL: /content/mc/policies/accessibility-statement
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/mc/policies/accessibility-statement
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /content/mc/policies/accessibility-statement
# Clean links: []
# Crawling URL: /category/hydraulics?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/hydraulics?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/hydraulics?analytics=nav
# Clean links: []
# Crawling URL: /category/lighting
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/lighting
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/lighting
# Clean links: []
# Crawling URL: /category/cleaning-and-janitorial
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/cleaning-and-janitorial
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/cleaning-and-janitorial
# Clean links: []
# Crawling URL: /category/hydraulics
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/hydraulics
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/hydraulics
# Clean links: []
# Crawling URL: /category/raw-materials?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/raw-materials?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/raw-materials?analytics=nav
# Clean links: []
# Crawling URL: /rservices/datadisclosure/privacyPortal
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /rservices/datadisclosure/privacyPortal
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /rservices/datadisclosure/privacyPortal
# Clean links: []
# Crawling URL: /category/safety?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/safety?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/safety?analytics=nav
# Clean links: []
# Crawling URL: /category/abrasives?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/abrasives?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/abrasives?analytics=nav
# Clean links: []
# Crawling URL: /category/packaging-shipping
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/packaging-shipping
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/packaging-shipping
# Clean links: []
# Crawling URL: /category/abrasives
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/abrasives
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000100976a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010096f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010058c970 chromedriver + 280944
# 3   chromedriver                        0x0000000100576a38 chromedriver + 191032
# 4   chromedriver                        0x00000001005751d4 chromedriver + 184788
# 5   chromedriver                        0x0000000100575b18 chromedriver + 187160
# 6   chromedriver                        0x000000010058f0a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100608364 chromedriver + 787300
# 8   chromedriver                        0x0000000100607d24 chromedriver + 785700
# 9   chromedriver                        0x00000001005c3eec chromedriver + 507628
# 10  chromedriver                        0x00000001005c48c4 chromedriver + 510148
# 11  chromedriver                        0x000000010093e43c chromedriver + 4154428
# 12  chromedriver                        0x0000000100942ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100923ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010094378c chromedriver + 4175756
# 15  chromedriver                        0x0000000100916fb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010096121c chromedriver + 4297244
# 17  chromedriver                        0x0000000100961398 chromedriver + 4297624
# 18  chromedriver                        0x000000010096ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/abrasives
# Clean links: []
# Crawling URL: /category/pumps
# ...
# Checking link: /content/business-twitter/ar.html
# Checking link: https://help.x.com/en/managing-your-account
# Checking link: https://business.x.com/en/advertising/ads-best-practices.html
# Checking link: https://developer.x.com/en/more/developer-terms
# Checking link: https://marketing.x.com/en/success-stories
# Checking link: https://business.x.com/en/products/amplify-pre-roll.html
# Checking link: https://publish.x.com
# Checking link: https://business.x.com/
# Checking link: https://business.x.com/en/advertising/analytics.html
# Checking link: https://business.x.com/en/help/account-setup.html
# Checking link: https://preferencecenter.x.com/
# Checking link: https://business.x.com/en/basics.html
# Checking link: https://business.x.com/en/basics/quick-promote.html
# Checking link: https://business.x.com/en/success-stories/how-dior-brought-the-runway-to-x-with-collection-ads.html
# Checking link: https://business.x.com/en/help.html
# Checking link: https://ads.x.com/login
# Checking link: https://business.x.com/en/advertising/formats.html
# Checking link: https://business.x.com/en/products/media-studio.html
# Checking link: /content/business-twitter/it.html
# Checking link: https://business.x.com/en/success-stories/on-running-wco-campaign-strategy-on-twitter.html
# Checking link: https://business.x.com/en/products.html
# Checking link: https://marketing.x.com/en/insights
# Checking link: https://business.x.com/en/success-stories/how-sky-tapped-into-nostalgia-to-promote-sky-glass.html
# Checking link: /content/business-twitter/ko.html
# Checking link: https://status.twitterstat.us/
# Checking link: https://business.x.com/en/success-stories.html
# Checking link: https://ads.x.com
# Checking link: https://help.x.com/en/forms.html
# Checking link: https://about.x.com/en/who-we-are/our-company.html
# Checking link: #twtr-main
# Checking link: https://help.x.com/
# Checking link: https://business.x.com/en/products/trend-takeovers.html
# Checking link: /content/business-twitter/fr.html
# Checking link: https://business.twitter.com/en/basics/get-your-business-started-with-X.html
# Checking link: https://privacy.x.com/
# Checking link: https://business.x.com/en/campaign/x-ad-credit-terms.html
# Checking link: https://business.x.com/en/resources/x-marketing-calendar.html
# Checking link: https://help.x.com/using-x/download-the-x-app
# Checking link: https://help.twitter.com/rules-and-policies/twitter-cookies
# Checking link: https://business.x.com/en/help/ads-policies.html
# Checking link: https://ads.x.com/
# Checking link: https://business.x.com/en/advertising/targeting.html
# Checking link: https://business.x.com/en/resources.html
# Checking link: https://business.twitter.com/en/success-stories.html
# Checking link: https://blog.x.com/
# Checking link: https://create.x.com/
# Checking link: https://business.x.com/en/basics/get-your-business-started-with-x.html
# Clean links: []
# Crawling URL: https://business.x.com/en/basics/get-your-business-started-with-x.html
# Getting hyperlinks for URL: https://business.x.com/en/basics/get-your-business-started-with-x.html
# Found 111 hyperlinks on https://business.x.com/en/basics/get-your-business-started-with-x.html
# Checking link: https://business.x.com/en/help/campaign-measurement-and-analytics.html
# Checking link: /content/business-twitter/id.html
# Checking link: https://business.x.com/en/advertising.html
# Checking link: #3
# Checking link: https://help.x.com/rules-and-policies/twitter-cookies
# Checking link: https://business.x.com/en/resources/video.html
# Checking link: https://business.x.com/en/advertising/measurement.html
# Checking link: /content/business-twitter/zh-cn.html
# Checking link: https://developer.x.com/en/docs
# Checking link: https://marketing.x.com/
# Checking link: https://business.x.com/en/resources/small-business.html
# Checking link: https://www.xadsacademy.com/sl/2b01d55a
# Checking link: https://investor.twitterinc.com/
# Checking link: https://business.x.com/en/help/ads-policies/brand-safety.html
# Checking link: https://x.com/login?redirect_after_login=https%3A%2F%2Ftwitter.com%2Fsignup
# Checking link: https://business.x.com/en/help/shopping-policies.html
# Checking link: /content/business-twitter/nl.html
# Checking link: https://twitter.com/signup
# Checking link: https://help.x.com/resources/accessibility
# Checking link: https://business.x.com/en/basics/intro-x-for-business.html
# Checking link: https://business.x.com/en/help/campaign-setup.html
# Checking link: https://business.x.com/en/products/vertical-video-ads.html
# Checking link: https://developer.x.com/en
# Checking link: https://business.x.com/en/basics/community-management.html
# Checking link: https://x.com/
# Checking link: /content/business-twitter/es.html
# Checking link: https://www.xadsacademy.com/sl/5c3e29ed
# Checking link: https://business.x.com/en/resources/guides-and-webinars.html
# Checking link: https://about.x.com/en/who-we-are/brand-toolkit.html
# Checking link: https://blog.x.com/developer/
# Checking link: https://business.x.com/en/products/amplify-sponsorships.html
# Checking link: https://business.x.com/en/help/overview.html
# Checking link: /
# Checking link: https://careers.x.com/
# Checking link: https://blog.x.com/engineering/en_us.html
# Checking link: https://help.x.com/en/rules-and-policies
# Checking link: https://business.x.com/en/blog.html
# Checking link: https://business.x.com/en/basics/organic-best-practices.html
# Checking link: /content/business-twitter/ja.html
# Checking link: https://help.x.com/en/using-twitter
# Checking link: https://business.x.com/en/advertising/partners.html
# Checking link: https://business.x.com/en/resources/performance-advertising-hub.html
# Checking link: /en/basics/get-your-business-started-with-x.html
# Checking link: https://business.x.com/en/advertising/campaign-types.html
# Checking link: https://business.x.com/en/help/campaign-editing-and-optimization.html
# Checking link: #email-subscribe-modal
# Checking link: https://x.com/privacy
# Checking link: /content/business-twitter/de.html
# Checking link: /content/business-twitter/pt.html
# Checking link: https://developer.x.com/en/community
# Checking link: https://transparency.x.com/
# Checking link: https://business.twitter.com/en/advertising.html
# Checking link: https://business.x.com/en/products/timeline-takeovers.html
# Checking link: https://twittercommunity.com/
# Checking link: https://business.x.com/en/help/troubleshooting.html
# Checking link: https://x.com/tos
# Checking link: /content/business-twitter/ar.html
# Checking link: https://help.x.com/en/managing-your-account
# Checking link: https://business.x.com/en/advertising/ads-best-practices.html
# Checking link: #1
# Checking link: https://developer.x.com/en/more/developer-terms
# Checking link: https://marketing.x.com/en/success-stories
# Checking link: https://business.x.com/en/products/amplify-pre-roll.html
# Checking link: https://publish.x.com
# Checking link: https://business.x.com/
# Checking link: https://business.x.com/en/advertising/analytics.html
# Checking link: https://business.x.com/en/help/account-setup.html
# Checking link: https://preferencecenter.x.com/
# Checking link: https://business.x.com/en/basics.html
# Checking link: https://business.x.com/en/basics/quick-promote.html
# Checking link: https://business.x.com/en/help.html
# Checking link: ##4
# Checking link: https://business.x.com/en/advertising/formats.html
# Checking link: https://business.x.com/en/products/media-studio.html
# Checking link: /content/business-twitter/it.html
# Checking link: https://business.x.com/en/products.html
# Checking link: https://marketing.x.com/en/insights
# Checking link: /content/business-twitter/ko.html
# Checking link: https://status.twitterstat.us/
# Checking link: https://business.x.com/en/success-stories.html
# Checking link: https://ads.x.com
# Checking link: https://help.x.com/en/forms.html
# Checking link: https://about.x.com/en/who-we-are/our-company.html
# Checking link: https://twitter.com/XBusiness
# Checking link: #twtr-main
# Checking link: https://help.x.com/
# Checking link: https://business.x.com/en/products/trend-takeovers.html
# Checking link: /content/business-twitter/fr.html
# Checking link: https://privacy.x.com/
# Checking link: #2
# Checking link: https://business.x.com/en/resources/small-business-faqs.html
# Checking link: https://business.x.com/en/resources/x-marketing-calendar.html
# Checking link: https://help.x.com/using-x/download-the-x-app
# Checking link: https://help.twitter.com/rules-and-policies/twitter-cookies
# Checking link: https://business.x.com/en/help/ads-policies.html
# Checking link: https://business.x.com/en/advertising/targeting.html
# Checking link: https://business.x.com/en/resources.html
# Checking link: https://blog.x.com/
# Checking link: https://create.x.com/
# Checking link: https://business.x.com/en/basics/get-your-business-started-with-x.html
# Clean links: []
# Crawling URL: https://business.x.com/en/resources/small-business-faqs.html
# Getting hyperlinks for URL: https://business.x.com/en/resources/small-business-faqs.html
# Found 9 hyperlinks on https://business.x.com/en/resources/small-business-faqs.html
# Checking link: https://status.twitterstat.us/
# Checking link: https://legal.twitter.com/imprint
# Checking link: /
# Checking link: https://support.twitter.com/articles/20170514
# Checking link: https://twitter.com/privacy
# Checking link: https://twitter.com/
# Checking link: https://twitter.com
# Checking link: https://business.twitter.com/en/help/troubleshooting/how-twitter-ads-work.html
# Checking link: https://twitter.com/tos
# Clean links: []
# Crawling URL: https://business.twitter.com/en/help/troubleshooting/how-twitter-ads-work.html
# Getting hyperlinks for URL: https://business.twitter.com/en/help/troubleshooting/how-twitter-ads-work.html
# Found 114 hyperlinks on https://business.twitter.com/en/help/troubleshooting/how-twitter-ads-work.html
# Checking link: https://business.x.com/en/help/campaign-measurement-and-analytics.html
# Checking link: /content/business-twitter/id.html
# Checking link: /en/help/overview/what-are-promoted-ads.html
# Checking link: https://business.x.com/en/advertising.html
# Checking link: http://www.google.com/settings/ads
# Checking link: https://help.x.com/rules-and-policies/twitter-cookies
# Checking link: https://business.x.com/en/resources/video.html
# Checking link: https://business.x.com/en/advertising/measurement.html
# Checking link: /content/business-twitter/zh-cn.html
# Checking link: https://developer.x.com/en/docs
# Checking link: https://support.twitter.com/articles/20170405-your-privacy-controls-for-tailored-ads
# Checking link: https://marketing.x.com/
# Checking link: https://business.x.com/en/resources/small-business.html
# Checking link: https://www.xadsacademy.com/sl/2b01d55a
# Checking link: https://investor.twitterinc.com/
# Checking link: http://ads.twitter.com/?ref=en-btc-how-twitter-ads-work
# Checking link: /en/help/overview/what-are-promoted-trends.html
# Checking link: https://help.twitter.com/en/personalization-data-settings
# Checking link: https://business.x.com/en/help/ads-policies/brand-safety.html
# Checking link: https://business.x.com/en/help/shopping-policies.html
# Checking link: /content/business-twitter/nl.html
# Checking link: https://help.x.com/resources/accessibility
# Checking link: https://business.x.com/en/basics/intro-x-for-business.html
# Checking link: https://business.x.com/en/help/campaign-setup.html
# Checking link: https://business.x.com/en/products/vertical-video-ads.html
# Checking link: https://developer.x.com/en
# Checking link: https://business.x.com/en/basics/community-management.html
# Checking link: https://x.com/
# Checking link: /content/business-twitter/es.html
# Checking link: https://www.xadsacademy.com/sl/5c3e29ed
# Checking link: /en/advertising/campaign-types.html
# Checking link: https://business.x.com/en/resources/guides-and-webinars.html
# Checking link: /en/help/troubleshooting/how-x-ads-work.html
# Checking link: https://about.x.com/en/who-we-are/brand-toolkit.html
# Checking link: https://blog.x.com/developer/
# Checking link: https://business.x.com/en/products/amplify-sponsorships.html
# Checking link: https://business.x.com/en/help/overview.html
# Checking link: /
# Checking link: https://careers.x.com/
# Checking link: https://blog.x.com/engineering/en_us.html
# Checking link: https://help.x.com/en/rules-and-policies
# Checking link: https://business.x.com/en/blog.html
# Checking link: https://business.x.com/en/basics/organic-best-practices.html
# Checking link: https://ads.twitter.com?ref=BTC
# Checking link: /content/business-twitter/ja.html
# Checking link: https://help.x.com/en/using-twitter
# Checking link: https://business.x.com/en/advertising/partners.html
# Checking link: https://business.x.com/en/resources/performance-advertising-hub.html
# Checking link: https://business.x.com/en/advertising/campaign-types.html
# Checking link: https://business.x.com/en/help/campaign-editing-and-optimization.html
# Checking link: https://x.com/privacy
# Checking link: http://www.networkadvertising.org/choices/
# Checking link: /content/business-twitter/de.html
# Checking link: /content/business-twitter/pt.html
# Checking link: https://developer.x.com/en/community
# Checking link: https://transparency.x.com/
# Checking link: https://business.twitter.com/en/advertising.html
# Checking link: http://optout.aboutads.info
# Checking link: https://business.x.com/en/products/timeline-takeovers.html
# Checking link: https://twittercommunity.com/
# Checking link: https://business.x.com/en/help/troubleshooting.html
# Checking link: https://x.com/tos
# Checking link: /content/business-twitter/ar.html
# Checking link: https://help.x.com/en/managing-your-account
# Checking link: https://business.x.com/en/advertising/ads-best-practices.html
# Checking link: http://optout.aboutads.info/
# Checking link: https://tools.google.com/dlpage/gaoptout
# Checking link: https://developer.x.com/en/more/developer-terms
# Checking link: https://business.x.com/en/products/amplify-pre-roll.html
# Checking link: https://publish.x.com
# Checking link: https://marketing.x.com/en/success-stories
# Checking link: https://business.x.com/
# Checking link: https://business.x.com/en/advertising.html?ref=en-btc-help-troubleshooting-how-it-works-footer
# Checking link: https://business.x.com/en/advertising/analytics.html
# Checking link: https://business.x.com/en/help/account-setup.html
# Checking link: https://preferencecenter.x.com/
# Checking link: https://business.x.com/en/basics.html
# Checking link: https://business.x.com/en/basics/quick-promote.html
# Checking link: https://business.x.com/en/help.html
# Checking link: https://business.x.com/en/advertising/formats.html
# Checking link: https://business.x.com/en/products/media-studio.html
# Checking link: /content/business-twitter/it.html
# Checking link: https://business.x.com/en/products.html
# Checking link: https://marketing.x.com/en/insights
# Checking link: /en/help/overview/what-are-follower-ads.html
# Checking link: /content/business-twitter/ko.html
# Checking link: https://status.twitterstat.us/
# Checking link: https://business.x.com/en/success-stories.html
# Checking link: https://help.x.com/en/forms.html
# Checking link: https://about.x.com/en/who-we-are/our-company.html
# Checking link: #twtr-main
# Checking link: https://help.x.com/
# Checking link: https://business.x.com/en/products/trend-takeovers.html
# Checking link: /content/business-twitter/fr.html
# Checking link: https://privacy.x.com/
# Checking link: https://support.twitter.com/articles/118492-how-to-use-the-location-feature-on-mobile-devices#
# Checking link: https://business.x.com/en/resources/x-marketing-calendar.html
# Checking link: https://help.x.com/using-x/download-the-x-app
# Checking link: https://help.twitter.com/rules-and-policies/twitter-cookies
# Checking link: https://business.x.com/en/help/ads-policies.html
# Checking link: https://business.x.com/en/advertising/targeting.html
# Checking link: https://business.x.com/en/resources.html
# Checking link: https://blog.x.com/
# Checking link: https://create.x.com/
# Checking link: https://business.x.com/en/basics/get-your-business-started-with-x.html
# Clean links: []
# Crawling URL: https://support.twitter.com/articles/118492-how-to-use-the-location-feature-on-mobile-devices#

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd
import os

# Create a list to store the text files
texts=[]

domain_dir = os.path.join("text", domain)
abs_domain_dir = os.path.abspath(domain_dir)

if os.path.exists(abs_domain_dir):
    # Get all the text files in the text directory
    for file in os.listdir("text/" + domain + "/"):
        
        try:
            # Open the file and read the text
            with open("text/" + domain + "/" + file, "r") as f:
                text = f.read()
        
                # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
                texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))
        except Exception as e:
            print(f"Exception occurred during reading file '{text}': {e}")       
else:
    print(f"Directory '{abs_domain_dir}' does not exist.")
# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from transformers import GPT2Tokenizer

# Assuming your dataframe 'df' is already created and contains a 'text' column
df = pd.DataFrame({
    'text': ["This is a sample text.", "Another example text.", "Yet another text sample."]
})

# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Calculate the number of tokens for each text
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
plt.xlabel('Number of Tokens')
plt.ylabel('Frequency')
plt.title('Distribution of Tokens per Text')
plt.show()
