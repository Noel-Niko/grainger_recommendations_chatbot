# %%
domain = "https://www.grainger.com"
start_url = "https://www.grainger.com"

# %%
import time
import os
from urllib.parse import urlparse, urljoin
from collections import deque
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re

# Selenium setup
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to get the hyperlinks from a URL using Selenium
def get_hyperlinks(url):
    print(f"Getting hyperlinks for URL: {url}")
    try:
        driver.get(url)
        time.sleep(1)  # Adjust wait time as needed based on page load speed
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
        return hyperlinks
    except Exception as e:
        print(f"Error getting hyperlinks: {e}")
        return []

# Function to crawl the website
def crawl(url):
    local_domain = urlparse(domain).netloc
    queue = deque([url])
    seen = {url}
    clean_links = []

    # Create necessary directories if they don't exist
    if not os.path.exists("text/"):
        os.mkdir("text/")
    if not os.path.exists(f"text/{local_domain}/"):
        os.mkdir(f"text/{local_domain}/")
    if not os.path.exists("processed"):
        os.mkdir("processed")

    while queue and len(clean_links) < 1000:
        url = queue.popleft()  # Use popleft to ensure we process URLs in a breadth-first manner
        print(f"Crawling URL: {url}")
        try:
            # Construct file path for saving content
            file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
            with open(file_path, "w") as f:
                driver.get(url)
                time.sleep(3)  # Adjust wait time as needed based on page load speed
                soup = BeautifulSoup(driver.page_source, "html.parser")
                text = soup.get_text()
                if "You need to enable JavaScript to run this app." in text:
                    print(f"Unable to parse page {url} due to JavaScript being required")
                f.write(text)
                # print(f"Writing: {text}")
        except Exception as e:
            print(f"Error crawling URL: {e}")

        try:
            new_links = get_domain_hyperlinks(local_domain, url, clean_links)
            for link in new_links:
                if link not in seen:
                    queue.append(link)
                    seen.add(link)
        except Exception as e:
            print(f"Error processing links: {e}")

    print(f"Collected {len(clean_links)} clean links")

# Function to get the hyperlinks from a URL that are within the same domain and base URL
def get_domain_hyperlinks(local_domain, url, clean_links):
    # regex_pattern = re.compile(r'-[a-zA-Z0-9]+\?.*')
    # regex_pattern = re.compile(r'-((?=.*\d.*\d.*\d)[A-Z0-9]{5,7})\?.*')
    # regex_pattern = re.compile(r'-((?=.*\d.*\d.*\d)[A-Z0-9]{5,7})\?.*(?<!\.txt|\.pdf)$')
    regex_pattern = re.compile(r'-[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')


    hyperlinks = get_hyperlinks(url)
    print(f"Found {len(hyperlinks)} hyperlinks on {url}")
    for link in set(hyperlinks):
        clean_link = None
        print(f"Checking link: {link}")

        # Handle absolute URLs
        if link.startswith("http"):
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain and link.startswith(domain):
                clean_link = link
        else:
            # Handle relative URLs
            clean_link = urljoin(url, link)

        if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            if clean_link not in clean_links:
                print(f"Adding clean link: {clean_link}")
                clean_links.append(clean_link)

        # Stop collecting if we reach 1000 links
        if len(clean_links) >= 1000:
            break

    print(f"Clean links: {clean_links}")
    return list(set(hyperlinks))

crawl(start_url)

driver.quit()
# Out:
# Crawling URL: https://www.grainger.com
# Getting hyperlinks for URL: https://www.grainger.com
# Found 196 hyperlinks on https://www.grainger.com
# Checking link: https://www.youtube.com/grainger
# Checking link: https://www.grainger.com/know-how/business-operations.html?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_Operations
# Checking link: https://www.grainger.com/content/mc/services-and-solutions/benefit-management?cm_sp=HomePage-_-GraingerGotYourBack-_-Benefit_Management-Services
# Checking link: /category/material-handling?analytics=nav
# Checking link: /category/test-instruments?analytics=nav
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: /content/user_registration
# Checking link: /category/group/tapes-adhesives-lubricants
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Emergency-Services
# Checking link: /category/pumps?analytics=nav
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /content/mc/services-and-solutions
# Checking link: /cart
# Checking link: https://www.grainger.com/content/mc/product-collections/industries?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Industries
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /category/group/fasteners-hardware-raw-materials
# Checking link: https://www.grainger.com/content/mc/services-and-solutions/keepstock?cm_sp=HomePage-_-GraingerGotYourBack-_-Services_KeepStock
# Checking link: /category?analytics=nav
# Checking link: https://www.grainger.com/content/mc/services-and-solutions/facility-services?cm_sp=HomePage-_-GraingerGotYourBack-_-Services_Facility-Services
# Checking link: /content/repair_parts_center
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: /myaccount/signin
# Checking link: https://www.grainger.com/content/mc/ehs?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Safety-Solutions
# Checking link: https://www.grainger.com/content/mc/services-and-solutions/energy-services?cm_sp=HomePage-_-GraingerGotYourBack-_-Services_Energy-Services
# Checking link: /content/mc/policies/return-instructions
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: https://www.grainger.com/know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /content/mc/policies/supported-browsers
# Checking link: /category/group/cleaning-janitorial
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /myaccount
# Checking link: /category/group/building-grounds-maintenance
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: /content/mc/serving-customers
# Checking link: /apps/keepstock/
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/heatstress?gicid=WFXC3K:APZ_1
# Checking link: /category/group/packaging-shipping
# Checking link: /category/electrical?analytics=nav
# Checking link: https://www.twitter.com/grainger
# Checking link: /content/mc/policies/terms-of-access
# Checking link: /category/lighting?analytics=nav
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: /category/motors?analytics=nav
# Checking link: /category/plumbing?analytics=nav
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /category/group/material-handling
# Checking link: /content/custom-product-center
# Checking link: https://www.grainger.com/know-how/?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_Header
# Checking link: /category/group/lab-office-hospitality-supplies
# Checking link: https://jobs.grainger.com/
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: /category/group/pipes-hose-tube-fittings
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: /category/group/pneumatics-hydraulics
# Checking link: /category/group/tools-test-instruments
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: /category/fasteners?analytics=nav
# Checking link: /category/safety?analytics=nav
# Checking link: #
# Checking link: /category/outdoor-equipment?analytics=nav
# Checking link: https://apps.apple.com/us/app/w-w-grainger-inc/id526722540?ls=1
# Checking link: https://www.grainger.com/content/mc/services-and-solutions?cm_sp=HomePage-_-GraingerGotYourBack-_-Services_Header
# Checking link: https://www.grainger.com/know-how/safety-health.html?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_Safety-and-Health
# Checking link: tel:1-800-472-4643
# Checking link: https://www.grainger.com/content/metalworking?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Metalworking
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: /category/group/hvac
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: /category/group/motors-power-transmission
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: https://www.facebook.com/grainger
# Checking link: /orders/lookup
# Checking link: https://www.grainger.com/content/mc/product-collections?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Header
# Checking link: /content/mc/serving-customers/extended-protection-plan
# Checking link: /category/raw-materials?analytics=nav
# Checking link: https://instagram.com/grainger
# Checking link: /category/security?analytics=nav
# Checking link: /content/sitemap
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: /content/mc/product-collections/industries
# Checking link: /category/hardware?analytics=nav
# Checking link: /category/pneumatics?analytics=nav
# Checking link: https://www.google.com/chrome
# Checking link: /category/tools?analytics=nav
# Checking link: /content/mc/policies/delivery
# Checking link: https://www.grainger.com/content/mc/services-and-solutions/safety-services?cm_sp=HomePage-_-GraingerGotYourBack-_-Services_EHS-Services
# Checking link: https://www.grainger.com/category/tools/power-tools/impact-wrenches-power-torque-wrenches-power-ratchets?brandName=MILWAUKEE&filters=brandName&gicid=DBBYJ0:APZ_1
# Checking link: /category/fleet-vehicle-maintenance?analytics=nav
# Checking link: /content/bulk-order-pad
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /content/find-branch-location
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /category/lubrication?analytics=nav
# Checking link: https://www.grainger.com/know-how/operations/preparedness/kh-prepare-working-heat?gicid=JIP20W:APZ_1
# Checking link: /content/mc/product-collections
# Checking link: /category/group/safety-security
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /
# Checking link: /category/welding?analytics=nav
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: /category/group/plumbing-pumps
# Checking link: /content/general-catalog
# Checking link: /category/machining?analytics=nav
# Checking link: https://www.grainger.com/know-how/inspiration.html?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_People
# Checking link: /category/abrasives?analytics=nav
# Checking link: /category/group/fleet-vehicle-maintenance
# Checking link: https://www.graingeresg.com/
# Checking link: /category
# Checking link: /category/group/metalworking-fabrication
# Checking link: /invoicing
# Checking link: /content/mc/supplier-overview
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: /content/help
# Checking link: /category/group/lighting-electrical
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Clean links: []
# Crawling URL: https://www.youtube.com/grainger
# Getting hyperlinks for URL: https://www.youtube.com/grainger
# Found 256 hyperlinks on https://www.youtube.com/grainger
# Checking link:
# Checking link: /playlist?list=PLzGQz6MjmcZKZH78WEtIy50JUvQsS_CNe
# Checking link: /watch?v=u9cPbdO-_Jg
# Checking link: /watch?v=w0JSSGUoIAs
# Checking link: https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbTU0MmVFMnlwMUtfSy1TVHZYV1RCdkM4bURqZ3xBQ3Jtc0trRGtKU2RLVlBLNUlOTWkyUTJ5YjFqQUlOWktXRjFyV1FrLUgtVjU1V2pHNWdmd0JUZTQ3cFQzS1JPVUFMNjNwZllmSXJHSFhucEhmWmpoN01yaERmeWgwSElKbmdhWE5lRFU3ZTkxUTYwVmNTUEJpcw&q=https%3A%2F%2Fwww.instagram.com%2Fgrainger
# Checking link: /watch?v=FZ0a0XY4ILc
# Checking link: /watch?v=Ttjq8l-aO4o
# Checking link: https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqa3BoZE5Fb3N1R3J1YnozNjBQN0RxZktXTnhSQXxBQ3Jtc0tuNjJSOUpxZmV5a1RFb2tfaUc5ejgyLVJzMDU1c2tvSmN1Sm5XeXV4bDFubzF0UDRyRENSVWJyRHdZWXRGUmpXNUplc2h5Y1FoYjFHTHIzbk5xQ09lUk9ObC1rWHRJMVpZa0hTZ24xbVdFNWY4RzRJZw&q=https%3A%2F%2Fwww.twitter.com%2Fgrainger
# Checking link: /watch?v=IRTVw13UNHU
# Checking link: /watch?v=pYKNNiwsEGE
# Checking link: /watch?v=rb38lH7yqn4
# Checking link: /watch?v=m0M6PGI4t_U
# Checking link: /watch?v=Gx8RYrwHVGQ
# Checking link: /watch?v=P40L5BdQPbU
# Checking link: /watch?v=M0pu5NXTYUU&list=PLzGQz6MjmcZJ6eNafrbhrHmnOp-1sD1Ij
# Checking link: /watch?v=vCb7i3KQHLc
# Checking link: /watch?v=cY7MTA_-Dzw
# Checking link: /watch?v=DEzlATpn7Dw
# Checking link: /watch?v=HtE1WfzzV4A
# Checking link: /watch?v=FkFGjCE9_jg
# Checking link: /playlist?list=PLzGQz6MjmcZIdRezdxk3hcaEVv8lIdBvq
# Checking link: https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbUNZR0hMZFZWZ0lFY21XQWRQWXRpR0VGcmZtd3xBQ3Jtc0traWpwbS1oLWtZVDR1eFRwaEVUN201MjJrM0NnV2NBVmduNUxtN3gtZmQwakctUUF1RjFqNmxScHVSdVlLRDhWdDRsMHdJejZ6MGI4S0hPd1FBS2lBTm5BOG1LYVhFM3B1eEMxa0tFNkVieXFYTmdVUQ&q=https%3A%2F%2Fwww.facebook.com%2Fgrainger
# Checking link: /watch?v=tKZQZvwdeK8
# Checking link: /watch?v=NfnK4518I5M
# Checking link: /shorts/MXaX74aadg4
# Checking link: /watch?v=YAS3-86siPc
# Checking link: /watch?v=daHz2xBAs8I
# Checking link: /watch?v=ky5HgR_R28g
# Checking link: /watch?v=VgJaczcVxtU
# Checking link: /watch?v=IsqgvfzpAR4
# Checking link: https://www.youtube.com/channel/UC1EXGMfoklkkEgPzyqRWw4A
# Checking link: /watch?v=Mlx6XnYfyxc
# Checking link: /watch?v=yixt9F0h-WY
# Checking link: /shorts/M0pu5NXTYUU
# Checking link: /shorts/dEJhFl6oBoU
# Checking link: /feed/history
# Checking link: /playlist?list=PLzGQz6MjmcZI8Bltm6AH0LXsXPaO4DQuY
# Checking link: /feed/subscriptions
# Checking link: /watch?v=RT8q7Tw5CzI
# Checking link: /watch?v=FZ0a0XY4ILc&list=PLzGQz6MjmcZIdRezdxk3hcaEVv8lIdBvq
# Checking link: /watch?v=ldYCU4jl6eA
# Checking link: /watch?v=Ttjq8l-aO4o&list=PLzGQz6MjmcZJvxa8x8zL1NBC4XrklTH64
# Checking link: /watch?v=Ry8jdEjVLag
# Checking link: /@grainger
# Checking link: https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbDd4Z1hreDNRaGNvd19xQTgydENDaC1sZE43QXxBQ3Jtc0tsc3JJQjRONGNHd0Q1VXVDVDJrM1pLYjJWdWstUUtMY3JKWTdkY2tueG10TXZ0RmtqNUM5TjhBQWFDRV9IUVAtSFZxRU14Sm9sN0duNklMT0Q2OFl5WDg2Z2JBWnpOei1RdnNLXy1HcUpTekhVMDZTbw&q=https%3A%2F%2Flandmaster.com%2F
# Checking link: /playlist?list=PLzGQz6MjmcZKW8sfu0KXYdGStnSgrByxQ
# Checking link: /playlist?list=PLzGQz6MjmcZJ6eNafrbhrHmnOp-1sD1Ij
# Checking link: /playlist?list=PLzGQz6MjmcZKqOOmWpvKrML8yT_bEMirt
# Checking link: /watch?v=GQoBhlTdcbM
# Checking link: /watch?v=3yLOC2SIB74
# Checking link: /watch?v=eVn1VgoOZwc
# Checking link: /watch?v=_zkIiux1o0E
# Checking link: /watch?v=KD7TpNHkd-o
# Checking link: /watch?v=r6L-noEZ7ao
# Checking link: /watch?v=MXaX74aadg4
# Checking link: /shorts/3yLOC2SIB74
# Checking link: /watch?v=xHUliOIjDJU
# Checking link: /watch?v=GZCeFP8jx8o
# Checking link: /watch?v=9npk9WRHHGY
# Checking link: /watch?v=i5dyq3mNqg8
# Checking link: /watch?v=ZJAu9BBjh5Y
# Checking link: /watch?v=Bl_Eup_JLXc
# Checking link: /watch?v=DEzlATpn7Dw&list=PLzGQz6MjmcZI8Bltm6AH0LXsXPaO4DQuY
# Checking link: /watch?v=bRbU2XCQcrY
# Checking link: /watch?v=7StNdltfRW4&list=PLzGQz6MjmcZJEJbgdt2yN-YXLiRf6MRCS
# Checking link: /watch?v=ZJAu9BBjh5Y&list=PLzGQz6MjmcZKZH78WEtIy50JUvQsS_CNe
# Checking link: /watch?v=SeZXykjYWXM&list=PLzGQz6MjmcZLklWcWf8MkQHcUGHrXUxFe
# Checking link: /watch?v=iZAWOiE27aY
# Checking link: /shorts/m0M6PGI4t_U
# Checking link: /watch?v=yO0QDoeXFfQ
# Checking link: /watch?v=dEJhFl6oBoU
# Checking link: /watch?v=OhL7gPWB0CU
# Checking link: /watch?v=mvsHq51TorU
# Checking link: /playlist?list=PLzGQz6MjmcZKm3FPIDBw6viCAE8b1sl9q
# Checking link: /
# Checking link: javascript:void(0);
# Checking link: /watch?v=OdzMWOr1Vj4
# Checking link: /watch?v=nXq1ODRx4IQ&list=PLzGQz6MjmcZKm3FPIDBw6viCAE8b1sl9q
# Checking link: /watch?v=WiAbW9o7UrA&list=PLzGQz6MjmcZKW8sfu0KXYdGStnSgrByxQ
# Checking link: /watch?v=1_9qENVyQcE
# Checking link: /watch?v=kniLVnn6AC0
# Checking link: /watch?v=6lNG7d1BMf4
# Checking link: https://www.youtube.com/redirect?event=endscreen&redir_token=QUFFLUhqa3dNLWVaQm1IT3R5TVVlb3lNZURQNW1xNWNQZ3xBQ3Jtc0tuSk9qcXFGUjNFWWVaVHlKMGZrNl8yNDBRWDVhYXZFZHNHbnVRWmVFUkJON1JOTzBkZUdDOU8wZzNseHBFNVVia0lpSmFfeThLLURLU1RBUTZsQVk3aVhGMzhPUXBveW10Tk50OW5mMzZoZ0lRdkJoQQ&q=http%3A%2F%2Fwww.grainger.com%2Fknow-how
# Checking link: /shorts/w0JSSGUoIAs
# Checking link: /watch?v=7StNdltfRW4
# Checking link: /watch?v=8n7mnc_wk1I
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/business-operations.html?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_Operations
# Getting hyperlinks for URL: https://www.grainger.com/know-how/business-operations.html?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_Operations
# Found 72 hyperlinks on https://www.grainger.com/know-how/business-operations.html?cm_sp=HomePage-_-GraingerGotYourBack-_-KnowHow_Operations
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.grainger.com/know-how/operations/facility/kh-workspace-organization-guide
# Checking link: /content/grainger/know-how/us/en/operations/warehouse
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: https://www.grainger.com/know-how/operations/people/kh-video-the-job-you-want-wind-turbine-tech
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: #
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://www.grainger.com/know-how/operations/preparedness/kh-prepare-working-heat
# Checking link: /content/grainger/know-how/us/en/operations/inventory
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.grainger.com/know-how/operations/people/kh-the-job-you-want-heavy-equipment-tech
# Checking link: https://www.grainger.com/know-how/operations/facility/kh-get-ready-for-spring
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.grainger.com/know-how/operations/facility/kh-preventive-maintenance-checklist
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://www.grainger.com/know-how/operations/preparedness/kh-business-continuity-planning-quiz
# Checking link: https://www.grainger.com/know-how
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.grainger.com/know-how/operations/inventory/kh-tips-streamlining-jobsite-storage-organization
# Checking link: https://www.grainger.com/know-how/operations/warehouse/kh-5-ways-automation-solves-common-warehouse-issues
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://twitter.com/grainger
# Checking link: /content/grainger/know-how/us/en/operations/preparedness
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/know-how/operations/people/kh-safety-training-institutional-knowledge
# Checking link: https://www.grainger.com/know-how/operations/preparedness/kh-the-many-ways-to-move-snow
# Checking link: https://www.grainger.com/know-how/operations/inventory/kh-creative-organization-small-workspace
# Checking link: /content/grainger/know-how/us/en/operations/facility
# Checking link: https://www.grainger.com/know-how/operations/warehouse/kh-12-tips-maximize-warehouse-space
# Checking link: /content/grainger/know-how/us/en/operations/people
# Checking link: https://www.grainger.com/know-how/operations/inventory/kh-5-benefits-using-5s-system-tools-equipment
# Checking link: https://www.grainger.com/know-how/operations/warehouse/kh-5-tips-to-prepare-warehouse-peak-season
# Clean links: []
# Crawling URL: https://www.grainger.com/content/mc/services-and-solutions/benefit-management?cm_sp=HomePage-_-GraingerGotYourBack-_-Benefit_Management-Services
# Getting hyperlinks for URL: https://www.grainger.com/content/mc/services-and-solutions/benefit-management?cm_sp=HomePage-_-GraingerGotYourBack-_-Benefit_Management-Services
# Found 167 hyperlinks on https://www.grainger.com/content/mc/services-and-solutions/benefit-management?cm_sp=HomePage-_-GraingerGotYourBack-_-Benefit_Management-Services
# Checking link: https://www.youtube.com/grainger
# Checking link: /category/material-handling?analytics=nav
# Checking link: /category/test-instruments?analytics=nav
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: /content/user_registration
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Checking link: /category/pumps?analytics=nav
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /content/mc/services-and-solutions
# Checking link: /cart
# Checking link: /category/office-supplies?analytics=nav
# Checking link: https://www.grainger.com/category/safety/footwear-footwear-accessories/safety-toe-work-boots-shoes?categoryIndex=7
# Checking link: /category?analytics=nav
# Checking link: https://www.grainger.com/content/catalog_safetyfootwear
# Checking link: /content/repair_parts_center
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: https://www.grainger.com/content/HOYA-Safety-Prescription-Eyewear?cm_sp=CS_Banner-_-SA-_-Portal_HoyaSRx
# Checking link: /myaccount/signin
# Checking link: https://www.grainger.com/content/mc/services-and-solutions
# Checking link: https://www.grainger.com/know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: /content/mc/policies/return-instructions
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /content/mc/policies/supported-browsers
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /myaccount
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: /apps/keepstock/
# Checking link: https://www.grainger.com/content/mc/services/services-request-form?id=Managed-Safety-Programs
# Checking link: /category/electrical?analytics=nav
# Checking link: https://www.twitter.com/grainger
# Checking link: /content/mc/policies/terms-of-access
# Checking link: /category/lighting?analytics=nav
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: /category/motors?analytics=nav
# Checking link: /category/plumbing?analytics=nav
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /content/custom-product-center
# Checking link: https://www.grainger.com/category/safety/footwear-footwear-accessories/safety-toe-work-boots-shoes?attrs=Gender|Women's&filters=attrs
# Checking link: https://jobs.grainger.com/
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: /category/fasteners?analytics=nav
# Checking link: /category/safety?analytics=nav
# Checking link: /category/outdoor-equipment?analytics=nav
# Checking link: https://apps.apple.com/us/app/w-w-grainger-inc/id526722540?ls=1
# Checking link: tel:1-800-472-4643
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: https://www.facebook.com/grainger
# Checking link: /orders/lookup
# Checking link: /content/mc/serving-customers/extended-protection-plan
# Checking link: /category/raw-materials?analytics=nav
# Checking link: https://instagram.com/grainger
# Checking link: /category/security?analytics=nav
# Checking link: /content/sitemap
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: /content/mc/product-collections/industries
# Checking link: /category/hardware?analytics=nav
# Checking link: /category/pneumatics?analytics=nav
# Checking link: https://www.google.com/chrome
# Checking link: /category/tools?analytics=nav
# Checking link: https://www.grainger.com/category/safety/footwear-footwear-accessories/insoles?categoryIndex=2
# Checking link: /content/mc/policies/delivery
# Checking link: /category/fleet-vehicle-maintenance?analytics=nav
# Checking link: /content/bulk-order-pad
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /content/find-branch-location
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /category/lubrication?analytics=nav
# Checking link: /content/mc/product-collections
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /
# Checking link: /category/welding?analytics=nav
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: https://www.grainger.com/category/safety/eye-protection-and-accessories/safety-glasses?categoryIndex=7
# Checking link: /content/general-catalog
# Checking link: https://www.grainger.com/category/safety/eye-protection-and-accessories/eye-protection-accessories?categoryIndex=1
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: /category/machining?analytics=nav
# Checking link: /category/abrasives?analytics=nav
# Checking link: https://www.grainger.com
# Checking link: https://www.graingeresg.com/
# Checking link: /invoicing
# Checking link: /content/mc/supplier-overview
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: /content/help
# Checking link: /content/mc/serving-customers
# Clean links: []
# Crawling URL: /category/material-handling?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x00000001032fea80 chromedriver + 4385408
# 1   chromedriver                        0x00000001032f738c chromedriver + 4354956
# 2   chromedriver                        0x0000000102f14970 chromedriver + 280944
# 3   chromedriver                        0x0000000102efea38 chromedriver + 191032
# 4   chromedriver                        0x0000000102efd1d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102efdb18 chromedriver + 187160
# 6   chromedriver                        0x0000000102f170a0 chromedriver + 290976
# 7   chromedriver                        0x0000000102f90364 chromedriver + 787300
# 8   chromedriver                        0x0000000102f8fd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102f4beec chromedriver + 507628
# 10  chromedriver                        0x0000000102f4c8c4 chromedriver + 510148
# 11  chromedriver                        0x00000001032c643c chromedriver + 4154428
# 12  chromedriver                        0x00000001032caea0 chromedriver + 4173472
# 13  chromedriver                        0x00000001032abff8 chromedriver + 4046840
# 14  chromedriver                        0x00000001032cb78c chromedriver + 4175756
# 15  chromedriver                        0x000000010329efb8 chromedriver + 3993528
# 16  chromedriver                        0x00000001032e921c chromedriver + 4297244
# 17  chromedriver                        0x00000001032e9398 chromedriver + 4297624
# 18  chromedriver                        0x00000001032f6f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/material-handling?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x00000001032fea80 chromedriver + 4385408
# 1   chromedriver                        0x00000001032f738c chromedriver + 4354956
# 2   chromedriver                        0x0000000102f14970 chromedriver + 280944
# 3   chromedriver                        0x0000000102efea38 chromedriver + 191032
# 4   chromedriver                        0x0000000102efd1d4 chromedriver + 184788
# 5   chromedriver                        0x0000000
4 chromedriver + 184788
# 5   chromedriver                        0x0000000102efdb18 chromedriver + 187160
# 6   chromedriver                        0x0000000102f170a0 chromedriver + 290976
# 7   chromedriver                        0x0000000102f90364 chromedriver + 787300
# 8   chromedriver                        0x0000000102f8fd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102f4beec chromedriver + 507628
# 10  chromedriver                        0x0000000102f4c8c4 chromedriver + 510148
# 11  chromedriver                        0x00000001032c643c chromedriver + 4154428
# 12  chromedriver                        0x00000001032caea0 chromedriver + 4173472
# 13  chromedriver                        0x00000001032abff8 chromedriver + 4046840
# 14  chromedriver                        0x00000001032cb78c chromedriver + 4175756
# 15  chromedriver                        0x000000010329efb8 chromedriver + 3993528
# 16  chromedriver                        0x00000001032e921c chromedriver + 4297244
# 17  chromedriver                        0x00000001032e9398 chromedriver + 4297624
# 18  chromedriver                        0x00000001032f6f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /category/group/tapes-adhesives-lubricants
# Clean links: []
# Crawling URL: https://www.grainger.com/content/mc/product-collections/emergency-preparedness?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Emergency-Services
# Getting hyperlinks for URL: https://www.grainger.com/content/mc/product-collections/emergency-preparedness?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Emergency-Services
# Found 179 hyperlinks on https://www.grainger.com/content/mc/product-collections/emergency-preparedness?cm_sp=HomePage-_-GraingerGotYourBack-_-ProductCollections_Emergency-Services
# Checking link: https://www.youtube.com/grainger
# Checking link: /category/material-handling?analytics=nav
# Checking link: /category/test-instruments?analytics=nav
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/power-outages
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: /content/user_registration
# Checking link: /category/pumps?analytics=nav
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /content/mc/services-and-solutions
# Checking link: /cart
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /category?analytics=nav
# Checking link: /content/repair_parts_center
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: /myaccount/signin
# Checking link: /content/mc/policies/return-instructions
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: https://www.grainger.com/know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /content/mc/policies/supported-browsers
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/wildfires
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /myaccount
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: /content/mc/serving-customers
# Checking link: /apps/keepstock/
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/fire-protection
# Checking link: https://www.osha.gov/
# Checking link: /category/electrical?analytics=nav
# Checking link: https://www.twitter.com/grainger
# Checking link: http://www.redcross.org/
# Checking link: /content/mc/policies/terms-of-access
# Checking link: /category/lighting?analytics=nav
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: /category/motors?analytics=nav
# Checking link: /category/plumbing?analytics=nav
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /content/custom-product-center
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/floods
# Checking link: https://jobs.grainger.com/
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: https://www.grainger.com/content/catalog_emergency_prep
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/communicable-diseases
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/heatstress
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: https://www.grainger.com/content/mc/product-collections/emergency-preparedness/earthquakes
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.onetrust.com/products/cookie-consent/
# ...
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://hbr.org/2018/11/retirement-proof-your-company
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: #
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www2.deloitte.com/us/en/insights/industry/manufacturing/manufacturing-industry-outlook.html
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-driving-sustainability-mro-purchasing
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.cpwr.com/research/management-resources-from-research/aging-workers/supportive-programs/
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: mailto:?Subject=&Body=
# Checking link: https://www.grainger.com/know-how
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.grainger.com/know-how/equipment/kh-10-factors-to-consider-when-choosing-fasteners
# Checking link: https://twitter.com/grainger
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/know-how/safety-health/ppe/ppe-safety-quiz
# Checking link: https://www.census.gov/library/stories/2020/11/manufacturing-faces-labor-shortage-as-workforce-ages.html
# Checking link: https://www.grainger.com/know-how/operations/people
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/operations/preparedness/kh-the-many-ways-to-move-snow
# Getting hyperlinks for URL: https://www.grainger.com/know-how/operations/preparedness/kh-the-many-ways-to-move-snow
# Found 69 hyperlinks on https://www.grainger.com/know-how/operations/preparedness/kh-the-many-ways-to-move-snow
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/category/outdoor-equipment/snow-and-ice-removal/snow-shovels-and-snow-pushers?filters=webParentSkuKey&webParentSkuKey=WP54583
# Checking link: https://www.grainger.com/category/outdoor-equipment/snow-and-ice-removal/snow-shovels-and-snow-pushers
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.grainger.com/category/outdoor-equipment/snow-and-ice-removal/ice-melting-compounds
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/category/outdoor-equipment/electrical-generators/portable-and-inverter-generators?gicid=TBAPZL:APZ_1
# Checking link: https://www.grainger.com/category/outdoor-equipment/snow-and-ice-removal/snow-blowers?categoryIndex=6
# Checking link: https://www.grainger.com/search/outdoor-equipment/shovels-tampers-and-digging-tools/scoop-shovels
# Checking link: https://www.grainger.com/category/outdoor-equipment/snow-and-ice-removal/snow-blowers
# Checking link: https://www.grainger.com/category/outdoor-equipment/shovels-tampers-and-digging-tools/scoop-shovels
# Checking link: https://www.grainger.com/category/outdoor-equipment/power-brushes-yard-vacuums-and-leaf-blowers/leaf-blowers?filters=webParentSkuKey&webParentSkuKey=WP54349|WP54350|WP54352|WP6645707|WP8118454|WP8427390
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/operations/inventory/kh-creative-organization-small-workspace
# Getting hyperlinks for URL: https://www.grainger.com/know-how/operations/inventory/kh-creative-organization-small-workspace
# Found 69 hyperlinks on https://www.grainger.com/know-how/operations/inventory/kh-creative-organization-small-workspace
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-abrasive-safety-understanding-hazards
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-panels-panel-racks/pegboard-panels-racks-accessories/stationary-pegboard-panels-racks
# Checking link: https://www.grainger.com/category/tools/hand-tools?analytics=FM:3EU87C:APZ_1&gicid=3EU87C:APZ_1
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-cabinets/small-parts-cabinets/small-parts-drawer-cabinets
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: https://www.grainger.com/category/tools/sockets-bits?analytics=FM:1DHYNU:APZ_1&gicid=1DHYNU:APZ_1
# Checking link: #
# Checking link: https://www.grainger.com/category/tools/tool-storage?analytics=FM:YBC8D5:APZ_1&gicid=YBC8D5:APZ_1
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-panels-panel-racks/pegboard-panels-racks-accessories/pegboard-shelves
# Checking link: https://www.grainger.com/category/tools/tool-storage/tool-cabinets-chests/rolling-tool-cabinets
# Checking link: https://www.grainger.com/category?searchQuery=chalkboard paint&searchBar=true
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-driving-sustainability-mro-purchasing
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-containers/small-parts-compartmented-boxes-systems-frames
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-panels-panel-racks/pegboard-panels-racks-accessories/pegboard-hooks-bins-toolholders/round-hole-pegboard-hooks-bins-toolholders?attrs=Accessory Type|Bin&filters=attrs
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-containers/totes-storage-boxes-trunks/standard-divider-boxes-accessories
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: mailto:?Subject=&Body=
# Checking link: https://www.grainger.com/know-how
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/category/tools/power-tools?analytics=FM:NK5BV9:APZ_1&gicid=NK5BV9:APZ_1
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/workbenches-shop-furniture/worktables/mobile-worktables
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.grainger.com/know-how/equipment/kh-10-factors-to-consider-when-choosing-fasteners
# Checking link: https://twitter.com/grainger
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.grainger.com/category/hardware/garage-door-openers/hanging-door-hardware
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/workbenches-shop-furniture/sawhorses-portable-workbenches
# Checking link: https://www.grainger.com/know-how/equipment/kh-types-casters-and-wheel-guide
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/category/tools/measuring-layout-tools?analytics=FM:UT19JF:APZ_1&gicid=UT19JF:APZ_1
# Checking link: https://www.grainger.com/know-how/operations/inventory
# Checking link: https://www.grainger.com/category/material-handling/storage-workspace/storage-panels-panel-racks/pegboard-panels-racks-accessories/pegboard-hooks-bins-toolholders
# Checking link: https://www.grainger.com/category/material-handling/transporting/casters-wheels/casters
# Checking link: https://www.grainger.com/search/material-handling/storage-workspace/storage-cabinets/small-parts-cabinets/small-parts-compartmented-box-cabinets-boxes
# Checking link: https://www.grainger.com/category/safety/signs-facility-identification-products/label-printers/label-printers-supplies/desktop-portable-label-printers/handheld-portable-label-printers
# Checking link: https://www.grainger.com/know-how/safety-health/ppe/ppe-safety-quiz
# Clean links: []
# Crawling URL: /content/grainger/know-how/us/en/operations/facility
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x00000001032fea80 chromedriver + 4385408
# 1   chromedriver                        0x00000001032f738c chromedriver + 4354956
# 2   chromedriver                        0x0000000102f14970 chromedriver + 280944
# 3   chromedriver                        0x0000000102efea38 chromedriver + 191032
# 4   chromedriver                        0x0000000102efd1d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102efdb18 chromedriver + 187160
# 6   chromedriver                        0x0000000102f170a0 chromedriver + 290976
# 7   chromedriver                        0x0000000102f90364 chromedriver + 787300
# 8   chromedriver                        0x0000000102f8fd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102f4beec chromedriver + 507628
# 10  chromedriver                        0x0000000102f4c8c4 chromedriver + 510148
# 11  chromedriver                        0x00000001032c643c chromedriver + 4154428
# 12  chromedriver                        0x00000001032caea0 chromedriver + 4173472
# 13  chromedriver                        0x00000001032abff8 chromedriver + 4046840
# 14  chromedriver                        0x00000001032cb78c chromedriver + 4175756
# 15  chromedriver                        0x000000010329efb8 chromedriver + 3993528
# 16  chromedriver                        0x00000001032e921c chromedriver + 4297244
# 17  chromedriver                        0x00000001032e9398 chromedriver + 4297624
# 18  chromedriver                        0x00000001032f6f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/grainger/know-how/us/en/operations/facility
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x00000001032fea80 chromedriver + 4385408
# 1   chromedriver                        0x00000001032f738c chromedriver + 4354956
# 2   chromedriver                        0x0000000102f14970 chromedriver + 280944
# 3   chromedriver                        0x0000000102efea38 chromedriver + 191032
# 4   chromedriver                        0x0000000102efd1d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102efdb18 chromedriver + 187160
# 6   chromedriver                        0x0000000102f170a0 chromedriver + 290976
# 7   chromedriver                        0x0000000102f90364 chromedriver + 787300
# 8   chromedriver                        0x0000000102f8fd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102f4beec chromedriver + 507628
# 10  chromedriver                        0x0000000102f4c8c4 chromedriver + 510148
# 11  chromedriver                        0x00000001032c643c chromedriver + 4154428
# 12  chromedriver                        0x00000001032caea0 chromedriver + 4173472
# 13  chromedriver                        0x00000001032abff8 chromedriver + 4046840
# 14  chromedriver                        0x00000001032cb78c chromedriver + 4175756
# 15  chromedriver                        0x000000010329efb8 chromedriver + 3993528
# 16  chromedriver                        0x00000001032e921c chromedriver + 4297244
# 17  chromedriver                        0x00000001032e9398 chromedriver + 4297624
# 18  chromedriver                        0x00000001032f6f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x000000018c82af94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x000000018c825d34 thread_start + 8
#
# Found 0 hyperlinks on /content/grainger/know-how/us/en/operations/facility
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/operations/warehouse/kh-12-tips-maximize-warehouse-space

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd
import os

# Create a list to store the text files
texts=[]

domain_dir = os.path.join("text", domain)
abs_domain_dir = os.path.abspath(domain_dir)

if os.path.exists(abs_domain_dir):
    # Get all the text files in the text directory
    for file in os.listdir("text/" + domain + "/"):
        
        try:
            # Open the file and read the text
            with open("text/" + domain + "/" + file, "r") as f:
                text = f.read()
        
                # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
                texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))
        except Exception as e:
            print(f"Exception occurred during reading file '{text}': {e}")       
else:
    print(f"Directory '{abs_domain_dir}' does not exist.")
# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from transformers import GPT2Tokenizer

# Assuming your dataframe 'df' is already created and contains a 'text' column
df = pd.DataFrame({
    'text': ["This is a sample text.", "Another example text.", "Yet another text sample."]
})

# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Calculate the number of tokens for each text
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
plt.xlabel('Number of Tokens')
plt.ylabel('Frequency')
plt.title('Distribution of Tokens per Text')
plt.show()
