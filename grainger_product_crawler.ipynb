# %%
domain = "https://www.grainger.com"
start_url = "https://www.grainger.com/category/tools/power-tools/cordless-tool-combination-kits?categoryIndex=4"

# %%
# #BREATHFIRST CRAWLER 
# import time
# import os
# from urllib.parse import urlparse, urljoin
# from collections import deque
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from webdriver_manager.chrome import ChromeDriverManager
# from bs4 import BeautifulSoup
# import re
# 
# # Selenium setup
# options = Options()
# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
# service = Service(ChromeDriverManager().install())
# driver = webdriver.Chrome(service=service, options=options)
# 
# # Function to get the hyperlinks from a URL using Selenium
# def get_hyperlinks(url):
#     print(f"Getting hyperlinks for URL: {url}")
#     try:
#         driver.get(url)
#         time.sleep(1)  # Adjust wait time 
#         html = driver.page_source
#         soup = BeautifulSoup(html, 'html.parser')
#         hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
#         return hyperlinks
#     except Exception as e:
#         print(f"Error getting hyperlinks: {e}")
#         return []
# 
# # Function to crawl the website
# def crawl(url):
#     local_domain = urlparse(domain).netloc
#     queue = deque([url])
#     seen = {url}
#     clean_links = []
# 
#     # Create necessary directories if they don't exist
#     if not os.path.exists("text/"):
#         os.mkdir("text/")
#     if not os.path.exists(f"text/{local_domain}/"):
#         os.mkdir(f"text/{local_domain}/")
#     if not os.path.exists("processed"):
#         os.mkdir("processed")
# 
# 
#     while queue and len(clean_links) < 100000:
#         url = queue.popleft()  # Use popleft to ensure we process URLs in a breadth-first manner
#         print(f"Crawling URL: {url}")
#         try:
#             # Handle absolute URLs
#             if url.startswith("http://") or url.startswith("https://"):
#                 url_domain = urlparse(url).netloc
#                 if url_domain != local_domain:
#                     print(f"Skipping URL: {url} (Not part of {domain})")
#                     continue
#             else:
#                 # Handle relative URLs
#                 url = urljoin(domain, url)
# 
#             # Construct file path for saving content
#             file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
#             with open(file_path, "w") as f:
#                 driver.get(url)
#                 time.sleep(3)  # Adjust wait time as needed based on page load speed
#                 soup = BeautifulSoup(driver.page_source, "html.parser")
#                 text = soup.get_text()
#                 if "You need to enable JavaScript to run this app." in text:
#                     print(f"Unable to parse page {url} due to JavaScript being required")
#                 f.write(text)
#         except Exception as e:
#             print(f"Error crawling URL: {e}")
# 
#         try:
#             new_links = get_domain_hyperlinks(local_domain, url, clean_links)
#             for link in new_links:
#                 if link not in seen:
#                     queue.append(link)
#                     seen.add(link)
#         except Exception as e:
#             print(f"Error processing links: {e}")
# 
#     print(f"Collected {len(clean_links)} clean links")
# 
# 
# # Function to get the hyperlinks from a URL that are within the same domain and base URL
# def get_domain_hyperlinks(local_domain, url, clean_links):
#     regex_pattern = re.compile(r'/product/[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')
# 
#     hyperlinks = get_hyperlinks(url)
#     print(f"Found {len(hyperlinks)} hyperlinks on {url}")
#     for link in set(hyperlinks):
#         clean_link = None
#         print(f"Checking link: {link}")
# 
#         # Handle absolute URLs
#         if link.startswith("http"):
#             url_obj = urlparse(link)
#             if url_obj.netloc == local_domain and link.startswith(domain):
#                 clean_link = link
#         else:
#             # Handle relative URLs
#             clean_link = urljoin(url, link)
# 
#         if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
#             if clean_link.endswith("/"):
#                 clean_link = clean_link[:-1]
#             if clean_link not in clean_links:
#                 print(f"Adding clean link: {clean_link}")
#                 clean_links.append(clean_link)
# 
#         # Stop collecting if we reach n links
#         if len(clean_links) >= 100000:
#             break
# 
#     print(f"Clean links: {clean_links}")
#     return list(set(hyperlinks))
# 
# crawl(start_url)
# 
# driver.quit()
# 
# # BREADTH-FIRST

# %%
#DEPTH-FIRST CRAWLER
import time
import os
from urllib.parse import urlparse, urljoin
from collections import deque
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re

# Selenium setup
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to get the hyperlinks from a URL using Selenium
def get_hyperlinks(url):
    print(f"Getting hyperlinks for URL: {url}")
    try:
        driver.get(url)
        time.sleep(1)  # Adjust wait time
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
        return hyperlinks
    except Exception as e:
        print(f"Error getting hyperlinks: {e}")
        return []

# Function to crawl the website using depth-first strategy
def crawl(url):
    local_domain = urlparse(domain).netloc
    stack = [url]  # Use a stack instead of a queue for depth-first
    seen = {url}
    clean_links = []

    # Create necessary directories if they don't exist
    if not os.path.exists("text/"):
        os.mkdir("text/")
    if not os.path.exists(f"text/{local_domain}/"):
        os.mkdir(f"text/{local_domain}/")
    if not os.path.exists("processed"):
        os.mkdir("processed")

    while stack and len(clean_links) < 100000:
        url = stack.pop()  # Use pop() to ensure we process URLs in a depth-first manner
        print(f"Crawling URL: {url}")
        try:     
               # Handle absolute URLs
            if url.startswith("http://") or url.startswith("https://"):
                url_domain = urlparse(url).netloc
                if url_domain != local_domain:
                    print(f"Skipping URL: {url} (Not part of {domain})")
                    continue
                
            # Construct file path for saving content
            file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
            with open(file_path, "w") as f:
                driver.get(url)
                time.sleep(1)  # Adjust wait time as needed based on page load speed
                soup = BeautifulSoup(driver.page_source, "html.parser")
                text = soup.get_text()
                if "You need to enable JavaScript to run this app." in text:
                    print(f"Unable to parse page {url} due to JavaScript being required")
                f.write(text)
        except Exception as e:
            print(f"Error crawling URL: {e}")

        try:
            new_links = get_domain_hyperlinks(local_domain, url, clean_links)
            for link in new_links:
                if link not in seen:
                    stack.append(link)
                    seen.add(link)
        except Exception as e:
            print(f"Error processing links: {e}")

    print(f"Collected {len(clean_links)} clean links")

# Function to get the hyperlinks from a URL that are within the same domain and base URL
def get_domain_hyperlinks(local_domain, url, clean_links):
    regex_pattern = re.compile(r'/product/[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')

    hyperlinks = get_hyperlinks(url)
    print(f"Found {len(hyperlinks)} hyperlinks on {url}")
    for link in set(hyperlinks):
        clean_link = None
        print(f"Checking link: {link}")

        # Handle absolute URLs
        if link.startswith("http"):
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain and link.startswith(domain):
                clean_link = link
        else:
            # Handle relative URLs
            clean_link = urljoin(url, link)

        if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            if clean_link not in clean_links:
                print(f"Adding clean link: {clean_link}")
                clean_links.append(clean_link)

        # Stop collecting if we reach n links
        if len(clean_links) >= 100000:
            break

    print(f"Clean links: {clean_links}")
    return list(set(hyperlinks))

crawl(start_url)

driver.quit()
#DEPTH-FIRST
# Out:
# Crawling URL: https://www.grainger.com/category/tools/power-tools/cordless-tool-combination-kits?categoryIndex=4
# Getting hyperlinks for URL: https://www.grainger.com/category/tools/power-tools/cordless-tool-combination-kits?categoryIndex=4
# Found 112 hyperlinks on https://www.grainger.com/category/tools/power-tools/cordless-tool-combination-kits?categoryIndex=4
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /category/safety?analytics=nav
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://instagram.com/grainger
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: /category?analytics=nav
# Checking link: /category/pumps?analytics=nav
# Checking link: /cart
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /content/help
# Checking link: https://www.facebook.com/grainger
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: /category/plumbing?analytics=nav
# Checking link: /category/fasteners?analytics=nav
# Checking link: https://www.youtube.com/grainger
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: /category/lubrication?analytics=nav
# Checking link: /content/custom-product-center
# Checking link: /category/abrasives?analytics=nav
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: /category/pneumatics?analytics=nav
# Checking link: /know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: https://www.google.com/chrome
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: /content/mc/product-collections
# Checking link: https://www.graingeresg.com/
# Checking link: /category
# Checking link: /myaccount/signin
# Checking link: /content/mc/policies/return-instructions
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: https://www.twitter.com/grainger
# Checking link: /category/electrical?analytics=nav
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: /content/mc/supplier-overview
# Checking link: tel:1-800-472-4643
# Checking link: /content/bulk-order-pad
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /invoicing
# Checking link: /category/tools?analytics=nav
# Checking link: /myaccount
# Checking link: /content/general-catalog
# Checking link: /category/tools
# Checking link: /content/sitemap
# Checking link: /category/test-instruments?analytics=nav
# Checking link: /content/mc/services-and-solutions
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /content/mc/policies/supported-browsers
# Checking link: /category/tools/power-tools
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: /category/welding?analytics=nav
# Checking link: /content/mc/policies/terms-of-access
# Checking link: /content/mc/serving-customers
# Checking link: /category/security?analytics=nav
# Checking link: https://jobs.grainger.com/
# Checking link: /category/raw-materials?analytics=nav
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: /orders/lookup
# Checking link: /content/user_registration
# Checking link: /category/fleet-vehicle-maintenance?analytics=nav
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: /content/mc/product-collections/industries
# Checking link: https://apps.apple.com/us/app/w-w-grainger-inc/id526722540?ls=1
# Checking link: /
# Checking link: /content/mc/policies/delivery
# Checking link: /content/find-branch-location
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /category/hardware?analytics=nav
# Checking link: /category/motors?analytics=nav
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /category/material-handling?analytics=nav
# Checking link: /content/mc/serving-customers/extended-protection-plan
# Checking link: /category/machining?analytics=nav
# Checking link: /category/lighting?analytics=nav
# Checking link: /category/outdoor-equipment?analytics=nav
# Checking link: /content/repair_parts_center
# Checking link: /apps/keepstock/
# Clean links: []
# Crawling URL: /apps/keepstock/
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /apps/keepstock/
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /apps/keepstock/
# Clean links: []
# Crawling URL: /content/repair_parts_center
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/repair_parts_center
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/repair_parts_center
# Clean links: []
# Crawling URL: /category/outdoor-equipment?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/outdoor-equipment?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/outdoor-equipment?analytics=nav
# Clean links: []
# Crawling URL: /category/lighting?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/lighting?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/lighting?analytics=nav
# Clean links: []
# Crawling URL: /category/machining?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/machining?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/machining?analytics=nav
# Clean links: []
# Crawling URL: /content/mc/serving-customers/extended-protection-plan
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/mc/serving-customers/extended-protection-plan
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/mc/serving-customers/extended-protection-plan
# Clean links: []
# Crawling URL: /category/material-handling?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/material-handling?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/material-handling?analytics=nav
# Clean links: []
# Crawling URL: /content/mc/policies/terms-of-sale
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/mc/policies/terms-of-sale
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/mc/policies/terms-of-sale
# Clean links: []
# Crawling URL: /category/motors?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/motors?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/motors?analytics=nav
# Clean links: []
# Crawling URL: /category/hardware?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/hardware?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/hardware?analytics=nav
# Clean links: []
# Crawling URL: https://www.grainger.com/content/mc/policies/privacy-policy
# Getting hyperlinks for URL: https://www.grainger.com/content/mc/policies/privacy-policy
# Found 212 hyperlinks on https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /category/safety?analytics=nav
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://adssettings.google.com/
# Checking link: https://instagram.com/grainger
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: #links
# Checking link: /category?analytics=nav
# Checking link: #change
# Checking link: /category/pumps?analytics=nav
# Checking link: #protect
# Checking link: /cart
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: https://www.linkedin.com/psettings/advertising
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /content/help
# Checking link: https://www.facebook.com/grainger
# Checking link: #privacy
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: https://www.grainger.com/content/mc/policies
# Checking link: /category/plumbing?analytics=nav
# Checking link: https://www.grainger.com/content/california-privacy-notice
# Checking link: mailto:Data.Privacy@grainger.com
# Checking link: /category/fasteners?analytics=nav
# Checking link: https://www.youtube.com/grainger
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: https://www.grainger.com/content/mc/policies/california-privacy-notice
# Checking link: #share
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: /category/lubrication?analytics=nav
# Checking link: /content/custom-product-center
# Checking link: /category/abrasives?analytics=nav
# Checking link: https://www.grainger.com/content/customer-service
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: https://help.twitter.com/en/safety-and-security/privacy-controls-for-tailored-ads
# Checking link: /category/pneumatics?analytics=nav
# Checking link: https://www.grainger.com
# Checking link: https://www.google.com/chrome
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: https://www.grainger.com/know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: /content/mc/product-collections
# Checking link: https://www.graingeresg.com/
# Checking link: https://tools.google.com/dlpage/gaoptout/
# Checking link: #choice
# Checking link: #disclosures
# Checking link: /myaccount/signin
# Checking link: /content/mc/policies/return-instructions
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: https://www.twitter.com/grainger
# Checking link: /category/electrical?analytics=nav
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: #
# Checking link: /content/mc/supplier-overview
# Checking link: tel:1-800-472-4643
# Checking link: /content/bulk-order-pad
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /invoicing
# Checking link: /category/tools?analytics=nav
# Checking link: #collect
# Checking link: /myaccount
# Checking link: /content/general-catalog
# Checking link: http://www.networkadvertising.org/choices
# Checking link: /content/sitemap
# Checking link: https://adssettings.google.com
# Checking link: /category/test-instruments?analytics=nav
# Checking link: /content/mc/services-and-solutions
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /content/mc/policies/supported-browsers
# Checking link: https://www.zoro.com/
# Checking link: http://youradchoices.com/appchoices
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: https://privacyportal-cdn.onetrust.com/dsarwebform/6a6816ee-1bb2-4697-934f-17c3f04d4461/823ed1b8-6b19-4f0b-8e05-702382e23eeb.html
# Checking link: #contact
# Checking link: https://policies.google.com/privacy
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: http://www.aboutads.info/choices
# Checking link: /category/welding?analytics=nav
# Checking link: /content/mc/policies/terms-of-access
# ...
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/guide?pagelabel=25
# Clean links: []
# Crawling URL: https://static.grainger.com/images/zemoga/Grainger_eProcurement_Infographic-8SP6136.pdf
# Skipping URL: https://static.grainger.com/images/zemoga/Grainger_eProcurement_Infographic-8SP6136.pdf (Not part of https://www.grainger.com)
# Crawling URL: /content/help-eprocurement-edit-solutions-epro-overview
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/help-eprocurement-edit-solutions-epro-overview
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/help-eprocurement-edit-solutions-epro-overview
# Clean links: []
# Crawling URL: /content/grainger-procurement-solutions
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/grainger-procurement-solutions
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.116)
# Stacktrace:
# 0   chromedriver                        0x0000000102c36a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102c2f38c chromedriver + 4354956
# 2   chromedriver                        0x000000010284c970 chromedriver + 280944
# 3   chromedriver                        0x0000000102836a38 chromedriver + 191032
# 4   chromedriver                        0x00000001028351d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102835b18 chromedriver + 187160
# 6   chromedriver                        0x000000010284f0a0 chromedriver + 290976
# 7   chromedriver                        0x00000001028c8364 chromedriver + 787300
# 8   chromedriver                        0x00000001028c7d24 chromedriver + 785700
# 9   chromedriver                        0x0000000102883eec chromedriver + 507628
# 10  chromedriver                        0x00000001028848c4 chromedriver + 510148
# 11  chromedriver                        0x0000000102bfe43c chromedriver + 4154428
# 12  chromedriver                        0x0000000102c02ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000102be3ff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000102c0378c chromedriver + 4175756
# 15  chromedriver                        0x0000000102bd6fb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000102c2121c chromedriver + 4297244
# 17  chromedriver                        0x0000000102c21398 chromedriver + 4297624
# 18  chromedriver                        0x0000000102c2ef84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/grainger-procurement-solutions
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/business-operations/sustainable-practices
# Getting hyperlinks for URL: https://www.grainger.com/know-how/business-operations/sustainable-practices
# Found 55 hyperlinks on https://www.grainger.com/know-how/business-operations/sustainable-practices
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-what-does-that-tshirt-really-cost
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://twitter.com/grainger
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-how-trash-liners-reduce-plastic-waste
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-improve-sustainability-stop-waste
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-retrofitting-historic-buildings-sustainability
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-sustainability-podcast
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-6-improvements-for-a-greener-warehouse
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-how-saving-energy-helps-environment
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-benefits-of-energy-management-infographic
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-what-recycling-symbols-mean
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-5-safety-measures-when-disposing-rechargeable-batteries
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-driving-sustainability-mro-purchasing
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/?gicid=H1Q0VB:APZ_1
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-6-steps-recycle-construction-materials
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-alternative-fuel-options
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-certified-green-buildings-leed
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-facility-sustainability-quick-wins-infographic
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-sustainable-building-design
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-develop-green-cleaning-program
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-how-facilities-earn-leed-credits-covid-prevention
# Checking link: #
# Checking link: https://www.grainger.com/know-how
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/safety-health/sustainability/kh-how-facilities-earn-leed-credits-covid-prevention
# Getting hyperlinks for URL: https://www.grainger.com/know-how/safety-health/sustainability/kh-how-facilities-earn-leed-credits-covid-prevention
# Found 58 hyperlinks on https://www.grainger.com/know-how/safety-health/sustainability/kh-how-facilities-earn-leed-credits-covid-prevention
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.usgbc.org/credits/safety-first-142-v4.1
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://twitter.com/grainger
# Checking link: https://www.usgbc.org/credits/safety-first-136-v4.1
# Checking link: https://www.aia.org/resources/6292441-re-occupancy-assessment-tool
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.usgbc.org/leed/why-leed
# Checking link: https://www.usgbc.org/credits/safety-first-138-v4.1
# Checking link: https://www.usgbc.org/credits/safety-first-156-v4.1
# Checking link: https://www.usgbc.org/credits/safety-first-141-v4.1
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: https://www.usgbc.org/credits/safety-first-140-v4.1
# Checking link: https://www.grainger.com/content/mc/services/services-request-form?id=EES
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.usgbc.org/credits/safety-first-137-v4.1
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.usgbc.org/help
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/content/mc/product-collections/green-resources
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.usgbc.org/credits/safety-first-155-v4.1
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability
# Checking link: mailto:?Subject=&Body=
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: https://www.usgbc.org/about/building-re-entry-resources
# Checking link: https://www.usgbc.org/credits/safety-first-139-v4.1
# Checking link: #
# Checking link: https://www.arcskoru.com/re-entry
# Checking link: https://www.grainger.com/know-how
# Clean links: []
# Crawling URL: https://www.arcskoru.com/re-entry
# Skipping URL: https://www.arcskoru.com/re-entry (Not part of https://www.grainger.com)
# Crawling URL: https://www.usgbc.org/credits/safety-first-139-v4.1
# Skipping URL: https://www.usgbc.org/credits/safety-first-139-v4.1 (Not part of https://www.grainger.com)
# Crawling URL: https://www.usgbc.org/about/building-re-entry-resources
# Skipping URL: https://www.usgbc.org/about/building-re-entry-resources (Not part of https://www.grainger.com)
# Crawling URL: https://www.usgbc.org/credits/safety-first-155-v4.1
# Skipping URL: https://www.usgbc.org/credits/safety-first-155-v4.1 (Not part of https://www.grainger.com)
# Crawling URL: https://www.grainger.com/content/mc/product-collections/green-resources

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
import pandas as pd
import os

# Create a list to store the text files
texts=[]

domain_dir = os.path.join("text", domain)
abs_domain_dir = os.path.abspath(domain_dir)

if os.path.exists(abs_domain_dir):
    # Get all the text files in the text directory
    for file in os.listdir("text/" + domain + "/"):
        
        try:
            # Open the file and read the text
            with open("text/" + domain + "/" + file, "r") as f:
                text = f.read()
        
                # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
                texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))
        except Exception as e:
            print(f"Exception occurred during reading file '{text}': {e}")       
else:
    print(f"Directory '{abs_domain_dir}' does not exist.")
# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
df.to_csv('processed/scraped.csv')
df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from transformers import GPT2Tokenizer

# Todo implement BedRock for Totan Tokenizer and Faiss Index
# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Calculate the number of tokens for each text
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
plt.xlabel('Number of Tokens')
plt.ylabel('Frequency')
plt.title('Distribution of Tokens per Text')
plt.show()
