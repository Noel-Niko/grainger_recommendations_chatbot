# %%
domain = "https://www.grainger.com"
start_url = "https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE8?cpnuser=undefined&searchBar=true&searchQuery=1VCE8&suggestConfigId=6"

# %%
import time
import os
from urllib.parse import urlparse, urljoin
from collections import deque
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re

# Selenium setup
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to get the hyperlinks from a URL using Selenium
def get_hyperlinks(url):
    print(f"Getting hyperlinks for URL: {url}")
    try:
        driver.get(url)
        time.sleep(1)  # Adjust wait time as needed based on page load speed
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
        return hyperlinks
    except Exception as e:
        print(f"Error getting hyperlinks: {e}")
        return []

# Function to crawl the website
def crawl(url):
    local_domain = urlparse(domain).netloc
    queue = deque([url])
    seen = {url}
    clean_links = []

    # Create necessary directories if they don't exist
    if not os.path.exists("text/"):
        os.mkdir("text/")
    if not os.path.exists(f"text/{local_domain}/"):
        os.mkdir(f"text/{local_domain}/")
    if not os.path.exists("processed"):
        os.mkdir("processed")

    while queue and len(clean_links) < 1000:
        url = queue.popleft()  # Use popleft to ensure we process URLs in a breadth-first manner
        print(f"Crawling URL: {url}")
        try:
            # Construct file path for saving content
            file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
            with open(file_path, "w") as f:
                driver.get(url)
                time.sleep(3)  # Adjust wait time as needed based on page load speed
                soup = BeautifulSoup(driver.page_source, "html.parser")
                text = soup.get_text()
                if "You need to enable JavaScript to run this app." in text:
                    print(f"Unable to parse page {url} due to JavaScript being required")
                f.write(text)
                # print(f"Writing: {text}")
        except Exception as e:
            print(f"Error crawling URL: {e}")

        try:
            new_links = get_domain_hyperlinks(local_domain, url, clean_links)
            for link in new_links:
                if link not in seen:
                    queue.append(link)
                    seen.add(link)
        except Exception as e:
            print(f"Error processing links: {e}")

    print(f"Collected {len(clean_links)} clean links")

# Function to get the hyperlinks from a URL that are within the same domain and base URL
def get_domain_hyperlinks(local_domain, url, clean_links):
    # regex_pattern = re.compile(r'-[a-zA-Z0-9]+\?.*')
    regex_pattern = re.compile(r'-((?=.*\d.*\d.*\d)[A-Z0-9]{5,7})\?.*')
    
    hyperlinks = get_hyperlinks(url)
    print(f"Found {len(hyperlinks)} hyperlinks on {url}")
    for link in set(hyperlinks):
        clean_link = None
        print(f"Checking link: {link}")

        # Handle absolute URLs
        if link.startswith("http"):
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain and link.startswith(domain):
                clean_link = link
        else:
            # Handle relative URLs
            clean_link = urljoin(url, link)

        if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            if clean_link not in clean_links:
                print(f"Adding clean link: {clean_link}")
                clean_links.append(clean_link)

        # Stop collecting if we reach 1000 links
        if len(clean_links) >= 1000:
            break

    print(f"Clean links: {clean_links}")
    return list(set(hyperlinks))

crawl(start_url)

driver.quit()
# Out:
# Crawling URL: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE8?cpnuser=undefined&searchBar=true&searchQuery=1VCE8&suggestConfigId=6
# Getting hyperlinks for URL: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE8?cpnuser=undefined&searchBar=true&searchQuery=1VCE8&suggestConfigId=6
# Found 146 hyperlinks on https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE8?cpnuser=undefined&searchBar=true&searchQuery=1VCE8&suggestConfigId=6
# Checking link: /content/mc/policies/terms-of-access
# Checking link: https://www.facebook.com/grainger
# Checking link: /product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2
# Adding clean link: https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2
# Checking link: /category/security?analytics=nav
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /category/test-instruments?analytics=nav
# Checking link: https://www.grainger.com/ec/pdf/Industrial-Assembled-Air-Circulator-Heads.pdf
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /content/general-catalog?pagelabel=2792&search=1VCE8
# Checking link: /apps/keepstock/
# Checking link: /category/safety?analytics=nav
# Checking link: /content/find-branch-location
# Checking link: https://www.twitter.com/grainger
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: /invoicing
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /category/lubrication?analytics=nav
# Checking link: /content/mc/policies/return-instructions
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /category/outdoor-equipment?analytics=nav
# Checking link: /content/sitemap
# Checking link: /category/welding?analytics=nav
# Checking link: /category/fasteners?analytics=nav
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /category
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: /product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2
# Adding clean link: https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2
# Checking link: /content/help
# Checking link: /product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3
# Adding clean link: https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3
# Checking link: /content/user_registration
# Checking link: /category/material-handling?analytics=nav
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /content/mc/serving-customers
# Checking link: /content/mc/supplier-overview
# Checking link: /cart
# Checking link: /orders/lookup
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Checking link: /myaccount/signin
# Checking link: https://www.youtube.com/grainger
# Checking link: /content/mc/policies/supported-browsers
# Checking link: /product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1
# Adding clean link: https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: /myaccount
# Checking link: /category/lighting?analytics=nav
# Checking link: /content/mc/policies/delivery
# Checking link: /content/mc/product-collections
# Checking link: /content/bulk-order-pad
# Checking link: /product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8
# Adding clean link: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8
# Checking link: /content/mc/product-collections/industries
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: /category/hvac-and-refrigeration/cooling-fans/industrial-cooling-fans
# Checking link: /content/mc/services-and-solutions
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: https://apps.apple.com/us/app/w-w-grainger-inc/id526722540?ls=1
# Checking link: /content/repair_parts_center
# Checking link: /product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8
# Adding clean link: https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: /content/general-catalog
# Checking link: https://jobs.grainger.com/
# Checking link: /product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1
# Adding clean link: https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1
# Checking link: /product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3
# Adding clean link: https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3
# Checking link: /category/motors?analytics=nav
# Checking link: /category/plumbing?analytics=nav
# Checking link: /product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8
# Adding clean link: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8
# Checking link: /content/mc/serving-customers/extended-protection-plan
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: tel:1-800-472-4643
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: /category/machining?analytics=nav
# Checking link: /category/hardware?analytics=nav
# Checking link: /category/pumps?analytics=nav
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: /category/electrical?analytics=nav
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: https://www.grainger.com/ec/pdf/Non-Oscillating-Air-Circulator-Parts-Diagram.pdf
# Checking link: https://instagram.com/grainger
# Checking link: /category?analytics=nav
# Checking link: /category/hvac-and-refrigeration
# Checking link: /category/raw-materials?analytics=nav
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: /category/hvac-and-refrigeration/cooling-fans
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: /category/fleet-vehicle-maintenance?analytics=nav
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: /product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1
# Adding clean link: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8
# Adding clean link: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8
# Checking link: https://www.P65Warnings.ca.gov
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: /category/tools?analytics=nav
# Checking link: /category/hvac-and-refrigeration/cooling-fans/industrial-cooling-fans/industrial-fan-heads
# Checking link: /content/custom-product-center
# Checking link: /product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2
# Adding clean link: https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: /category/pneumatics?analytics=nav
# Checking link: /
# Checking link: /product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8
# Adding clean link: https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8
# Checking link: https://www.graingeresg.com/
# Checking link: /category/abrasives?analytics=nav
# Checking link: /product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8
# Adding clean link: https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8
# Checking link: https://www.google.com/chrome
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: /content/mc/policies/terms-of-access
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/mc/policies/terms-of-access
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/mc/policies/terms-of-access
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: https://www.facebook.com/grainger
# Getting hyperlinks for URL: https://www.facebook.com/grainger
# Found 39 hyperlinks on https://www.facebook.com/grainger
# Checking link: https://www.facebook.com/grainger
# Checking link: /photo/?fbid=856997976465355&set=ecnf.100064654811342
# Checking link: ?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%2CO%2CP-R#?jkk
# Checking link: /policies?ref=pf
# Checking link: https://www.facebook.com/grainger/posts/pfbid02bHn7w6SdD971xntb4eMuD6K4YZCpcKFXZdQymFcMUMr8htnRUgZR8itBr486CyrJl?comment_id=465625176403641&__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=R]-R
# Checking link: /policies/cookies/
# Checking link: https://www.facebook.com/grainger/about
# Checking link: /privacy/policy/?entry_point=comet_dropdown
# Checking link: https://www.facebook.com/photo/?fbid=699665662198588&set=a.699665608865260&__tn__=%3C
# Checking link: /photo/?fbid=859658456199307&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/photo/?fbid=699665665531921&set=a.699665612198593
# Checking link: /help/568137493302217
# Checking link: https://www.facebook.com/grainger?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%3C%3C%2CP-R
# Checking link: https://www.facebook.com/grainger/videos
# Checking link: https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3Ep5CMz&h=AT0ww6rZBs38rMYX_CSUObEomR9pYRUSMBbILnNl4MxvNlbMx7ULYOaYwHoxD0twemhPf1FiTrOmiuoiN0dZzEpOqDL7H0qILsJWGiYV38wKrw25DcM1D_g_3X6SgUYXGpfr4rpbTrvcRda0lUZKAd1klc0
# Checking link: ?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=H-R#?gfa
# Checking link: /privacy/policies/health/
# Checking link: https://www.facebook.com/login/device-based/regular/login/?login_attempt=1&next=https%3A%2F%2Fwww.facebook.com%2Fgrainger
# Checking link: /grainger/
# Checking link: https://www.facebook.com/hashtag/graingerknowhow?__eep__=6&__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=*NK-R
# Checking link: /photo/?fbid=863657719132714&set=ecnf.100064654811342
# Checking link: /photo/?fbid=865441292287690&set=ecnf.100064654811342
# Checking link: ?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%2CmH-R#?bbe
# Checking link: /photo/?fbid=869313598567126&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger/followers/
# Checking link: https://www.facebook.com/recover/initiate?ars=royal_blue_bar
# Checking link: https://www.facebook.com/grainger?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%3C%2CP-R
# Checking link: /photo/?fbid=872814974883655&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger/photos
# Checking link: /photo/?fbid=873865028111983&set=ecnf.100064654811342
# Checking link: /
# Checking link: /business/
# Checking link: /photo/?fbid=862182135938551&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=-UC%2CP-R
# Checking link: /photo/?fbid=861396436025509&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger/friends_likes/
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: /product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Getting hyperlinks for URL: /product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Found 0 hyperlinks on /product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: /category/security?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/security?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/security?analytics=nav
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: /category/power-transmission?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/power-transmission?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/power-transmission?analytics=nav
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: /category/test-instruments?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/test-instruments?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x000000010339aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010339338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102fb0970 chromedriver + 280944
# 3   chromedriver                        0x0000000102f9aa38 chromedriver + 191032
# 4   chromedriver                        0x0000000102f991d4 chromedriver + 184788
# 5   chromedriver                        0x0000000102f99b18 chromedriver + 187160
# 6   chromedriver                        0x0000000102fb30a0 chromedriver + 290976
# 7   chromedriver                        0x000000010302c364 chromedriver + 787300
# 8   chromedriver                        0x000000010302bd24 chromedriver + 785700
# 9   chromedriver                        0x0000000102fe7eec chromedriver + 507628
# 10  chromedriver                        0x0000000102fe88c4 chromedriver + 510148
# 11  chromedriver                        0x000000010336243c chromedriver + 4154428
# 12  chromedriver                        0x0000000103366ea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000103347ff8 chromedriver + 4046840
# 14  chromedriver                        0x000000010336778c chromedriver + 4175756
# 15  chromedriver                        0x000000010333afb8 chromedriver + 3993528
# 16  chromedriver                        0x000000010338521c chromedriver + 4297244
# 17  chromedriver                        0x0000000103385398 chromedriver + 4297624
# 18  chromedriver                        0x0000000103392f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001888b6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001888b1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/test-instruments?analytics=nav
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: https://www.grainger.com/ec/pdf/Industrial-Assembled-Air-Circulator-Heads.pdf
# Getting hyperlinks for URL: https://www.grainger.com/ec/pdf/Industrial-Assembled-Air-Circulator-Heads.pdf
# Found 39 hyperlinks on https://www.grainger.com/ec/pdf/Industrial-Assembled-Air-Circulator-Heads.pdf
# Checking link: https://www.facebook.com/grainger
# Checking link: /photo/?fbid=856997976465355&set=ecnf.100064654811342
# Checking link: ?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%2CO%2CP-R#?jkk
# Checking link: /policies?ref=pf
# Checking link: https://www.facebook.com/grainger/posts/pfbid02bHn7w6SdD971xntb4eMuD6K4YZCpcKFXZdQymFcMUMr8htnRUgZR8itBr486CyrJl?comment_id=465625176403641&__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=R]-R
# Checking link: /policies/cookies/
# Checking link: https://www.facebook.com/grainger/about
# Checking link: /privacy/policy/?entry_point=comet_dropdown
# Checking link: https://www.facebook.com/photo/?fbid=699665662198588&set=a.699665608865260&__tn__=%3C
# Checking link: /photo/?fbid=859658456199307&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/photo/?fbid=699665665531921&set=a.699665612198593
# Checking link: /help/568137493302217
# Checking link: https://www.facebook.com/grainger?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%3C%3C%2CP-R
# Checking link: https://www.facebook.com/grainger/videos
# Checking link: https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3Ep5CMz&h=AT0ww6rZBs38rMYX_CSUObEomR9pYRUSMBbILnNl4MxvNlbMx7ULYOaYwHoxD0twemhPf1FiTrOmiuoiN0dZzEpOqDL7H0qILsJWGiYV38wKrw25DcM1D_g_3X6SgUYXGpfr4rpbTrvcRda0lUZKAd1klc0
# Checking link: ?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=H-R#?gfa
# Checking link: /privacy/policies/health/
# Checking link: https://www.facebook.com/login/device-based/regular/login/?login_attempt=1&next=https%3A%2F%2Fwww.facebook.com%2Fgrainger
# Checking link: /grainger/
# Checking link: https://www.facebook.com/hashtag/graingerknowhow?__eep__=6&__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=*NK-R
# Checking link: /photo/?fbid=863657719132714&set=ecnf.100064654811342
# Checking link: /photo/?fbid=865441292287690&set=ecnf.100064654811342
# Checking link: ?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%2CmH-R#?bbe
# Checking link: /photo/?fbid=869313598567126&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger/followers/
# Checking link: https://www.facebook.com/recover/initiate?ars=royal_blue_bar
# Checking link: https://www.facebook.com/grainger?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=%3C%2CP-R
# Checking link: /photo/?fbid=872814974883655&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger/photos
# Checking link: /photo/?fbid=873865028111983&set=ecnf.100064654811342
# Checking link: /
# Checking link: /business/
# Checking link: /photo/?fbid=862182135938551&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger?__cft__[0]=AZXeaKPIxbBaAXrqNv7ECjlpj4fQj2CQLDoBgLa3t5TiXqegiD25SvDMLDQYtr0Vtv5fv9J_FllxN39GqdBp9y94YtDskp7fMrZm7PlfbQyArAa1QfylgJMCFXil592Kik-jeamQZzAMKBU4JjEynFEeTHPv_AQh3OuiyW0mge0u8nojkJvZnbapIRaOBoLTG6Fzo48zJbmFU7dsW-uLQHFz&__tn__=-UC%2CP-R
# Checking link: /photo/?fbid=861396436025509&set=ecnf.100064654811342
# Checking link: https://www.facebook.com/grainger/friends_likes/
# Clean links: ['https://www.grainger.com/product/SCHAEFER-Standard-Duty-Industrial-Fan-6ALD6?opr=APPD&analytics=altItems_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Open-Pedestal-Base-38-in-Lg-1ZCP4?opr=RAPD&analytics=REQACC_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Mounting-Bracket-14-1-2-in-1ZCP6?opr=RAPD&analytics=REQACC_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Pedestal-Base-Dayton-Yoke-1ZCP2?opr=RAPD&analytics=REQACC_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCF3?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-1RWB5?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Kit-21DP75?opr=PDRP&analytics=repParts_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Replacement-Propeller-24-in-2ATW2?opr=PDRP&analytics=repParts_1VCE8&position=3', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-3PEG9?opr=PDPBRDSP&analytics=dsbrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE7?opr=APPD&analytics=altItems_1VCE8&position=1', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCE9?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Industrial-Fan-Guard-48-in-2ATB9?opr=PDRP&analytics=repParts_1VCE8&position=2', 'https://www.grainger.com/product/DAYTON-Standard-Duty-Industrial-Fan-1VCG7?opr=PDPRRDSP&analytics=dsrrItems_1VCE8', 'https://www.grainger.com/product/DAYTON-Light-Duty-Industrial-Fan-39UK56?opr=PDPBRDSP&analytics=dsbrItems_1VCE8']
# Crawling URL: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Getting hyperlinks for URL: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 111
#     108     print(f"Clean links: {clean_links}")
#     109     return list(set(hyperlinks))
# --> 111 crawl(start_url)
#     113 driver.quit()
#
# Cell In[2], line 67, in crawl(url)
#      64     print(f"Error crawling URL: {e}")
#      66 try:
# ---> 67     new_links = get_domain_hyperlinks(local_domain, url, clean_links)
#      68     for link in new_links:
#      69         if link not in seen:
#
# Cell In[2], line 82, in get_domain_hyperlinks(local_domain, url, clean_links)
#      78 def get_domain_hyperlinks(local_domain, url, clean_links):
#      79     # regex_pattern = re.compile(r'-[a-zA-Z0-9]+\?.*')
#      80     regex_pattern = re.compile(r'-((?=.*\d.*\d.*\d)[A-Z0-9]{5,7})\?.*')
# ---> 82     hyperlinks = get_hyperlinks(url)
#      83     print(f"Found {len(hyperlinks)} hyperlinks on {url}")
#      84     for link in set(hyperlinks):
#
# Cell In[2], line 24, in get_hyperlinks(url)
#      22 try:
#      23     driver.get(url)
# ---> 24     time.sleep(1)  # Adjust wait time as needed based on page load speed
#      25     html = driver.page_source
#      26     soup = BeautifulSoup(html, 'html.parser')
#
# KeyboardInterrupt:
