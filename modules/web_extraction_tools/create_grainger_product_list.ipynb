# %%
import json

def save_last_visited_url(url):
    filename = 'start_url.json'
    with open(filename, 'w') as file:
        json.dump({'start_url': url}, file)
        print(f"Saved last visited url: {url} to {filename}")

# save_last_visited_url("https://www.grainger.com/category")

# %%
import json
import os

from urllib.parse import urlparse, urljoin

domain = "https://www.grainger.com"
filename = 'start_url.json'
with open(filename, 'r') as file:
    data = json.load(file)
    start_url = data['start_url']
    print(f"start_url: {start_url}")
    
local_domain = urlparse(domain).netloc
# Out:
# start_url: https://www.grainger.com/category

# %%
### WEB CRAWLING THE GRAINGER SITE REQUIRES GRAINGER VPN ACCESS

# %%
# DEPTH FIRST SEARCH
import time
import os
from urllib.parse import urlparse, urljoin
from collections import deque
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import re

# Selenium setup
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to get the hyperlinks from a URL using Selenium
def get_hyperlinks(url):
    print(f"Getting hyperlinks for URL: {url}")
    try:
        driver.get(url)
        time.sleep(1)  # Adjust wait time
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        hyperlinks = [a['href'] for a in soup.find_all('a', href=True)]
        return hyperlinks
    except Exception as e:
        print(f"Error getting hyperlinks: {e}")
        return []

# Function to crawl the website using depth-first strategy
def crawl(url):
    local_domain = urlparse(url).netloc
    stack = [url]  # Use a stack instead of a queue for depth-first
    seen = {url}
    clean_links = []
    last_visited_url = None  # Variable to store the last visited URL

    # Create necessary directories if they don't exist
    if not os.path.exists("text/"):
        os.mkdir("text/")
    if not os.path.exists(f"text/{local_domain}/"):
        os.mkdir(f"text/{local_domain}/")
    if not os.path.exists("processed"):
        os.mkdir("processed")

    while stack and len(clean_links) < 100000:
        url = stack.pop()  # Use pop() to ensure we process URLs in a depth-first manner
        print(f"Crawling URL: {url}")
        try:     
            # Handle absolute URLs
            if url.startswith("http://") or url.startswith("https://"):
                url_domain = urlparse(url).netloc
                if url_domain != local_domain:
                    print(f"Skipping URL: {url} (Not part of {url})")
                    continue
                
            # Construct file path for saving content
            file_path = f"text/{local_domain}/{url[8:].replace('/', '_')}.txt"
            with open(file_path, "w") as f:
                driver.get(url)
                time.sleep(1)  # Adjust wait time as needed based on page load speed
                soup = BeautifulSoup(driver.page_source, "html.parser")
                text = soup.get_text()
                if "You need to enable JavaScript to run this app." in text:
                    print(f"Unable to parse page {url} due to JavaScript being required")
                f.write(text)
            last_visited_url = url  # Update the last visited URL
        except Exception as e:
            print(f"Error crawling URL: {e}")

        try:
            new_links = get_domain_hyperlinks(local_domain, url, clean_links)
            for link in new_links:
                if link not in seen:
                    stack.append(link)
                    seen.add(link)
        except Exception as e:
            print(f"Error processing links: {e}")

    print(f"Collected {len(clean_links)} clean links")
    if last_visited_url:
        print(f"Last visited URL: {last_visited_url}")
        save_last_visited_url(last_visited_url)

# Function to get the hyperlinks from a URL that are within the same domain and base URL
def get_domain_hyperlinks(local_domain, url, clean_links):
    regex_pattern = re.compile(r'/product/.*-[A-Z0-9]{5,7}(?=.*\d.*\d.*\d)\?.*')

    hyperlinks = get_hyperlinks(url)
    print(f"Found {len(hyperlinks)} hyperlinks on {url}")
    for link in set(hyperlinks):
        clean_link = None
        print(f"Checking link: {link}")

        # Handle absolute URLs
        if link.startswith("http"):
            url_obj = urlparse(link)
            if url_obj.netloc == local_domain and link.startswith(url):
                clean_link = link
        else:
            # Handle relative URLs
            clean_link = urljoin(url, link)

        if clean_link is not None and '@' not in clean_link and regex_pattern.search(clean_link):
            if clean_link.endswith("/"):
                clean_link = clean_link[:-1]
            if clean_link not in clean_links:
                print(f"Adding clean link: {clean_link}")
                clean_links.append(clean_link)

        # Stop collecting if we reach n links
        if len(clean_links) >= 100000:
            break

    print(f"Clean links: {clean_links}")
    return list(set(hyperlinks))


crawl(start_url)

driver.quit()
# Out:
# Crawling URL: https://www.grainger.com/category
# Getting hyperlinks for URL: https://www.grainger.com/category
# Found 142 hyperlinks on https://www.grainger.com/category
# Checking link: /category/adhesives-sealants-and-tape?analytics=nav
# Checking link: https://www.youtube.com/grainger
# Checking link: /content/general-catalog
# Checking link: /category/office-supplies?analytics=nav
# Checking link: /category/fasteners
# Checking link: /category/welding?analytics=nav
# Checking link: /category/packaging-shipping?analytics=nav
# Checking link: /category/lubrication
# Checking link: /invoicing
# Checking link: /content/sitemap
# Checking link: /category/plumbing?analytics=nav
# Checking link: /category/electronics-batteries?analytics=nav
# Checking link: /content/user_registration
# Checking link: /content/mc/policies/terms-of-sale
# Checking link: /category/abrasives
# Checking link: /know-how/?cm_sp=CM-Content-_-Footer-_-Gcom-_-page-unkn-_-2019-01
# Checking link: /category/hvac-and-refrigeration?analytics=nav
# Checking link: /category/fasteners?analytics=nav
# Checking link: /category/security?analytics=nav
# Checking link: /category/paints-equipment-and-supplies?analytics=nav
# Checking link: /category/electrical?analytics=nav
# Checking link: /category/test-instruments?analytics=nav
# Checking link: /category/lighting?analytics=nav
# Checking link: /content/custom-product-center
# Checking link: /category/adhesives-sealants-and-tape
# Checking link: /category/safety?analytics=nav
# Checking link: /category/pipe-hose-tube-fittings
# Checking link: /category/packaging-shipping
# Checking link: /content/repair_parts_center
# Checking link: /myaccount/orderhistory?page=1&viewBy=purchasedProducts
# Checking link: /category/hardware?analytics=nav
# Checking link: /category/raw-materials?analytics=nav
# Checking link: /myaccount
# Checking link: /content/mc/serving-customers/mobile-app-features
# Checking link: https://www.twitter.com/grainger
# Checking link: /category/electronics-batteries
# Checking link: https://www.linkedin.com/company/w.w.-grainger/
# Checking link: /content/cat_print?cm_sp=Catalog-_-ordercats-_-digicatalogs
# Checking link: /category/fleet-vehicle-maintenance
# Checking link: /category/cleaning-and-janitorial?analytics=nav
# Checking link: https://www.facebook.com/grainger
# Checking link: /category/fleet-vehicle-maintenance?analytics=nav
# Checking link: /category/cleaning-and-janitorial
# Checking link: /category/tools
# Checking link: /category/pumps
# Checking link: /category/electrical
# Checking link: /category/furnishings-appliances-hospitality
# Checking link: /category/hvac-and-refrigeration
# Checking link: https://jobs.grainger.com/
# Checking link: /category/pneumatics
# Checking link: /category/lab-supplies?analytics=nav
# Checking link: /category/power-transmission
# Checking link: /content/mc/product-collections/industries
# Checking link: /content/mc/policies/delivery
# Checking link: /category/test-instruments
# Checking link: /content/find-branch-location
# Checking link: /content/help
# Checking link: /category/outdoor-equipment?analytics=nav
# Checking link: /category/abrasives?analytics=nav
# Checking link: /
# Checking link: /category/hydraulics
# Checking link: https://play.google.com/store/apps/details?id=com.grainger.mobile.android
# Checking link: /category/pipe-hose-tube-fittings?analytics=nav
# Checking link: https://www.graingeresg.com/
# Checking link: /category?analytics=nav
# Checking link: /category/outdoor-equipment
# Checking link: /category/furnishings-appliances-hospitality?analytics=nav
# Checking link: /content/mc/serving-customers
# Checking link: /category/machining
# Checking link: /category/lab-supplies
# Checking link: /content/mc/policies/return-instructions
# Checking link: /category/raw-materials
# Checking link: /myaccount/signin
# Checking link: /category/material-handling
# Checking link: /category/reference-and-learning-supplies?analytics=nav
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: /category/motors
# Checking link: /apps/keepstock/
# Checking link: /category/office-supplies
# Checking link: /category/reference-and-learning-supplies
# Checking link: /category/safety
# Checking link: /content/mc/policies/accessibility-statement
# Checking link: /cart
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: /category/tools?analytics=nav
# Checking link: /content/mc/supplier-overview
# Checking link: https://apps.apple.com/us/app/w-w-grainger-inc/id526722540?ls=1
# Checking link: /content/mc/serving-customers/extended-protection-plan
# Checking link: /category/machining?analytics=nav
# Checking link: /content/tf_onlinecat?analytics=topNav
# Checking link: /content/mc/product-collections
# Checking link: https://invest.grainger.com/home/default.aspx
# Checking link: https://pressroom.grainger.com/home/default.aspx
# Checking link: /category/lubrication?analytics=nav
# Checking link: tel:1-800-472-4643
# Checking link: /category/motors?analytics=nav
# Checking link: /content/mc/policies/supported-browsers
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://instagram.com/grainger
# Checking link: /category/hardware
# Checking link: /category/security
# Checking link: /category/paints-equipment-and-supplies
# Checking link: /category/welding
# Checking link: /category/plumbing
# Checking link: /content/mc/policies/terms-of-access
# Checking link: /category/hydraulics?analytics=nav
# Checking link: /category/pneumatics?analytics=nav
# Checking link: https://www.google.com/chrome
# Checking link: https://www.microsoft.com/en-us/edge
# Checking link: /content/mc/policies/privacy-policy
# Checking link: /content/bulk-order-pad
# Checking link: /category/power-transmission?analytics=nav
# Checking link: /category/lighting
# Checking link: /content/mc/services-and-solutions
# Checking link: /myaccount/orderhistory#orderHistory
# Checking link: /orders/lookup
# Checking link: /category/material-handling?analytics=nav
# Checking link: /category/pumps?analytics=nav
# Clean links: []
# Crawling URL: /category/pumps?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/pumps?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/pumps?analytics=nav
# Clean links: []
# Crawling URL: /category/material-handling?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/material-handling?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/material-handling?analytics=nav
# Clean links: []
# Crawling URL: /orders/lookup
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /orders/lookup
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /orders/lookup
# Clean links: []
# Crawling URL: /myaccount/orderhistory#orderHistory
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /myaccount/orderhistory#orderHistory
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /myaccount/orderhistory#orderHistory
# Clean links: []
# Crawling URL: /content/mc/services-and-solutions
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/mc/services-and-solutions
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/mc/services-and-solutions
# Clean links: []
# Crawling URL: /category/lighting
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/lighting
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/lighting
# Clean links: []
# Crawling URL: /category/power-transmission?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/power-transmission?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/power-transmission?analytics=nav
# Clean links: []
# Crawling URL: /content/bulk-order-pad
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/bulk-order-pad
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/bulk-order-pad
# Clean links: []
# Crawling URL: /content/mc/policies/privacy-policy
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/mc/policies/privacy-policy
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/mc/policies/privacy-policy
# Clean links: []
# Crawling URL: https://www.microsoft.com/en-us/edge
# Skipping URL: https://www.microsoft.com/en-us/edge (Not part of https://www.microsoft.com/en-us/edge)
# Crawling URL: https://www.google.com/chrome
# Skipping URL: https://www.google.com/chrome (Not part of https://www.google.com/chrome)
# Crawling URL: /category/pneumatics?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/pneumatics?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /category/pneumatics?analytics=nav
# Clean links: []
# Crawling URL: /category/hydraulics?analytics=nav
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /category/hydraulics?analytics=nav
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# ...
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: #generalElectricalSafety
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on #generalElectricalSafety
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/safety-health
# Getting hyperlinks for URL: https://www.grainger.com/know-how/safety-health
# Found 66 hyperlinks on https://www.grainger.com/know-how/safety-health
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/know-how/safety-health/ppe/ppe-safety-quiz
# Checking link: https://www.grainger.com/know-how/safety-health/quick-tips/kh-types-of-moisture-meters-qt-346
# Checking link: /content/grainger/know-how/us/en/safety-health/management
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.grainger.com/know-how/safety-health/ppe/kh-ppe-for-extreme-conditions
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-driving-sustainability-mro-purchasing
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-how-environmental-health-and-safety-fits-esg-strategy
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.grainger.com/know-how/safety-health/quick-tips/kh-forklift-safety-training-guide-106-qt
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://www.grainger.com/know-how
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: /content/grainger/know-how/us/en/safety-health/ppe
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: /content/grainger/know-how/us/en/safety-health/sustainability
# Checking link: https://www.grainger.com/know-how/safety-health/quick-tips/kh-osha-requirements-machine-guarding
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://twitter.com/grainger
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-heat-index-chart-download
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-watch-for-worksite-dehydration
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-abrasive-safety-understanding-hazards
# Checking link: https://www.grainger.com/know-how/safety-health/ppe/kh-4-reasons-workers-wearing-ppe
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-sustainability-podcast
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: /content/grainger/know-how/us/en/safety-health/quick-tips
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-6-tips-to-prepare-for-heat-waves
# Checking link: #
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-5-safety-measures-when-disposing-rechargeable-batteries
# Clean links: []
# Crawling URL: https://www.grainger.com/know-how/safety-health/sustainability/kh-5-safety-measures-when-disposing-rechargeable-batteries
# Getting hyperlinks for URL: https://www.grainger.com/know-how/safety-health/sustainability/kh-5-safety-measures-when-disposing-rechargeable-batteries
# Found 59 hyperlinks on https://www.grainger.com/know-how/safety-health/sustainability/kh-5-safety-measures-when-disposing-rechargeable-batteries
# Checking link: https://www.grainger.com/category/lighting/lamp-light-bulb-disposal-recycling/recycling-kits/battery-recycling?attrs=For Battery Type|Damaged Lithium Ion Batteries&filters=attrs&searchQuery=battery recycling kit&sst=4
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://cen.acs.org/materials/energy-storage/time-serious-recycling-lithium/97/i28
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.grainger.com/category/electronics-batteries/batteries-battery-chargers/disposable-batteries?searchQuery=duracell procell&sst=4&gicid=Q5W8PI:APZ_1
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-driving-sustainability-mro-purchasing
# Checking link: https://www.epa.gov/system/files/documents/2021-08/lithium-ion-battery-report-update-7.01_508.pdf
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://www.grainger.com/know-how
# Checking link: https://www.epa.gov/recycle/used-household-batteries
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: https://www.grainger.com/know-how/equipment/kh-10-factors-to-consider-when-choosing-fasteners
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-hand-tool-safety-quiz?knowhowrecs=true
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://twitter.com/grainger
# Checking link: https://dtsc.ca.gov/how-is-california-doing-with-recycling-rechargeable-batteries/
# Checking link: https://www.grainger.com/know-how/safety-health/sustainability/kh-what-does-that-tshirt-really-cost?knowhowrecs=true
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://www.osha.gov/sites/default/files/publications/shib011819.pdf
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: https://www.grainger.com/know-how/safety-health/management/kh-abrasive-safety-understanding-hazards
# Checking link: mailto:?Subject=&Body=
# Checking link: https://www.call2recycle.org/recycling-laws-by-state/
# Checking link: https://www.sciencedirect.com/science/article/pii/S0301479716303395
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.grainger.com/know-how/safety-health/quick-tips/kh-forklift-safety-training-guide-106-qt?knowhowrecs=true
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: https://www.powertoolinstitute.com/pti_pdfs/IndustryGuidance_TransportingHighEnergyBatteriesForRecycling.pdf
# Checking link: #
# Clean links: []
# Crawling URL: https://www.powertoolinstitute.com/pti_pdfs/IndustryGuidance_TransportingHighEnergyBatteriesForRecycling.pdf
# Skipping URL: https://www.powertoolinstitute.com/pti_pdfs/IndustryGuidance_TransportingHighEnergyBatteriesForRecycling.pdf (Not part of https://www.powertoolinstitute.com/pti_pdfs/IndustryGuidance_TransportingHighEnergyBatteriesForRecycling.pdf)
# Crawling URL: https://www.grainger.com/know-how/safety-health/quick-tips/kh-forklift-safety-training-guide-106-qt?knowhowrecs=true
# Getting hyperlinks for URL: https://www.grainger.com/know-how/safety-health/quick-tips/kh-forklift-safety-training-guide-106-qt?knowhowrecs=true
# Found 45 hyperlinks on https://www.grainger.com/know-how/safety-health/quick-tips/kh-forklift-safety-training-guide-106-qt?knowhowrecs=true
# Checking link: https://www.onetrust.com/products/cookie-consent/
# Checking link: https://www.grainger.com/know-how/inspiration
# Checking link: https://www.grainger.com/know-how/safety-health
# Checking link: https://www.grainger.com/know-how/safety-health/quick-tips
# Checking link: https://www.grainger.com
# Checking link: https://www.grainger.com/know-how/operations
# Checking link: https://www.grainger.com/content/mc/policies/privacy-policy
# Checking link: https://www.grainger.com/know-how
# Checking link: https://www.grainger.com/know-how/equipment
# Checking link: https://www.facebook.com/grainger
# Checking link: https://www.grainger.com?analytics=FM:KnowHow
# Checking link: https://www.grainger.com/know-how/trends
# Checking link: https://www.youtube.com/user/wwgraingerinc
# Checking link: /content/grainger/know-how/us/en/kh-email-signup
# Checking link: https://www.grainger.com/content/terms-of-sale
# Checking link: https://twitter.com/grainger
# Checking link: https://www.linkedin.com/company/w.w.-grainger
# Checking link: https://www.grainger.com/content/privacy-policy
# Checking link: http://www.osha.gov/pls/oshaweb/owadisp.show_document?p_table=STANDARDS&p_id=9828
# Checking link: https://www.grainger.com/content/fraud-alert
# Checking link: https://www.grainger.com/know-how/break-room
# Checking link: mailto:?Subject=&Body=
# Checking link: /rservices/datadisclosure/privacyPortal
# Checking link: https://www.grainger.com/content/terms-of-access
# Checking link: /content/grainger/know-how/us/en/safety-health/quick-tips?gicid=WB407R:APZ_1
# Checking link: #
# Clean links: []
# Crawling URL: /content/grainger/know-how/us/en/safety-health/quick-tips?gicid=WB407R:APZ_1
# Error crawling URL: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Getting hyperlinks for URL: /content/grainger/know-how/us/en/safety-health/quick-tips?gicid=WB407R:APZ_1
# Error getting hyperlinks: Message: invalid argument
#   (Session info: chrome-headless-shell=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000100a6ea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000100a6738c chromedriver + 4354956
# 2   chromedriver                        0x0000000100684970 chromedriver + 280944
# 3   chromedriver                        0x000000010066ea38 chromedriver + 191032
# 4   chromedriver                        0x000000010066d1d4 chromedriver + 184788
# 5   chromedriver                        0x000000010066db18 chromedriver + 187160
# 6   chromedriver                        0x00000001006870a0 chromedriver + 290976
# 7   chromedriver                        0x0000000100700364 chromedriver + 787300
# 8   chromedriver                        0x00000001006ffd24 chromedriver + 785700
# 9   chromedriver                        0x00000001006bbeec chromedriver + 507628
# 10  chromedriver                        0x00000001006bc8c4 chromedriver + 510148
# 11  chromedriver                        0x0000000100a3643c chromedriver + 4154428
# 12  chromedriver                        0x0000000100a3aea0 chromedriver + 4173472
# 13  chromedriver                        0x0000000100a1bff8 chromedriver + 4046840
# 14  chromedriver                        0x0000000100a3b78c chromedriver + 4175756
# 15  chromedriver                        0x0000000100a0efb8 chromedriver + 3993528
# 16  chromedriver                        0x0000000100a5921c chromedriver + 4297244
# 17  chromedriver                        0x0000000100a59398 chromedriver + 4297624
# 18  chromedriver                        0x0000000100a66f84 chromedriver + 4353924
# 19  libsystem_pthread.dylib             0x00000001819d6f94 _pthread_start + 136
# 20  libsystem_pthread.dylib             0x00000001819d1d34 thread_start + 8
#
# Found 0 hyperlinks on /content/grainger/know-how/us/en/safety-health/quick-tips?gicid=WB407R:APZ_1
# Clean links: []
# Crawling URL: http://www.osha.gov/pls/oshaweb/owadisp.show_document?p_table=STANDARDS&p_id=9828
# Skipping URL: http://www.osha.gov/pls/oshaweb/owadisp.show_document?p_table=STANDARDS&p_id=9828 (Not part of http://www.osha.gov/pls/oshaweb/owadisp.show_document?p_table=STANDARDS&p_id=9828)
# Crawling URL: https://www.grainger.com/know-how/safety-health/quick-tips

# %%
def remove_newlines(serie):
    serie = serie.str.replace('\n', ' ')
    serie = serie.str.replace('\\n', ' ')
    serie = serie.str.replace('  ', ' ')
    serie = serie.str.replace('  ', ' ')
    return serie

# %%
"""
Uncomment: df.to_csv('processed/scraped.csv')
to save changes and OVERWRITE current file.
CAUTION: this will overwrite the existing,
and require VPN access in the Grainger System 
to rerun the exhaustive web crawl above.
""" 

import pandas as pd
import os

# Create a list to store the text files
texts=[]

domain_dir = os.path.join("text", local_domain)
abs_domain_dir = os.path.abspath(domain_dir)

if os.path.exists(abs_domain_dir):
    # Get all the text files in the text directory
    for file in os.listdir(abs_domain_dir):
        
        try:
            # Open the file and read the text
            with open("text/" + local_domain + "/" + file, "r") as f:
                text = f.read()
        
                # Omit the first 11 lines and the last 4 lines, then replace -, _, and #update with spaces.
                texts.append((file[11:-4].replace('-',' ').replace('_', ' ').replace('#update',''), text))
        except Exception as e:
            print(f"Exception occurred during reading file '{text}': {e}")       
else:
    print(f"Directory '{abs_domain_dir}' does not exist.")
# Create a dataframe from the list of texts
df = pd.DataFrame(texts, columns = ['fname', 'text'])

# Set the text column to be the raw text with the newlines removed
df['text'] = df.fname + ". " + remove_newlines(df.text)
"""
Uncomment: df.to_csv('processed/scraped.csv')
to save changes and OVERWRITE current file.
CAUTION: this will overwrite the existing,
and require VPN access in the Grainger System 
to rerun the exhaustive web crawl above.
""" 
df.to_csv('processed/scraped.csv')
df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from transformers import GPT2Tokenizer

# Load the dataframe from the CSV file
df = pd.read_csv('processed/scraped.csv')

# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Calculate the number of tokens for each text
df['n_tokens'] = df.text.apply(lambda x: len(tokenizer.encode(x)))

# Visualize the distribution of the number of tokens per row using a histogram
df.n_tokens.hist()
plt.xlabel('Number of Tokens')
plt.ylabel('Frequency')
plt.title('Distribution of Tokens per Text')
plt.show()
